# %%
from sympy import symbols, Symbol, Function, Transpose, sqrt, N
from sympy.matrices import Matrix, eye, zeros, ones, diag
import sympy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We start with a potential
#
# $$
# U(r) = (r - r_0)(a + b r + c r^2 + d r^3)
# $$
#
# and impose the following conditions
#
# $$
# \begin{aligned}
# U(0) & = U_0 & \text{(Barrier height at center)}\\
# U'(0) & = 0 & \text{(Center is extremum)} \\
# U'(r_0) & = 0 & \text{(Transition path is extremum)} \\
# U''(r_0) & = k & \text{(Transition path has width k)}
# \end{aligned}
# $$
#
# we get
#
# $$
# \begin{aligned}
# a = - \frac{U_0}{r_0},\ & b = - \frac{U_0}{r_0^2} \\
# c = \frac{10 U_0 - k r_0^2}{2 r_0^3},\ & d = \frac{k r_0^2 - 6 U_0}{2 r_0^4}
# \end{aligned}
# $$
#
#
# and thus
#
#
# $$
# U(r) = \frac{1}{2 r_0^4} (r - r_0)^2 [ k r^2 r_0^2 - 2 U_0 (r - r_0)(3r + r_0) ]
# $$
#
# In order to ensure that the potential has the appropriate sombrero shape, we must have
#
# $$
# \begin{aligned}
# U''(0) & < 0 & \text{(Center is maximum)}\\
# \lim_{r \to \infty} U(r) & = \infty & \text{(Potential is confining)}
# \end{aligned}
# $$
#
# This imposes the following condition on the curvature of the transition path
#
# $$
# \frac{6 U_0}{r_0^2} \leq k \leq \frac{12 U_0}{r_0^2} \quad (1)
# $$
#
# For $k > \frac{12 U_0}{r_0^2}$ the central extremum becomes a minimum. For $k < \frac{6 U_0}{r_0^2}$, a second maximum emerges after $r_0$, meaning that $U(r) \to -\infty$ as $r \to \infty$.
#
# In other words we must have
#
# $$
# k(\theta) = \frac{6 U_0}{r_0^2} (1 + 2 h( \theta ) )
# $$
#
# where $0 \leq h(\theta) \leq 1$.
#
# We set
#
# $$
# h(\theta) = \frac{1}{4}( \xi_2 + \xi_1 + (\xi_2 - \xi_1) \sin(\theta) )
# $$
#
# such that $h(-\pi/2) = \xi_1$ and $h(\pi/2) = \xi_2$, and thus $k(-\pi/2) = \frac{6 U_0}{r_0^2} (1 + \xi_1)$ and $k(\pi/2) = \frac{6 U_0}{r_0^2} (1 + \xi_2)$.
#
# Finally, we have $\theta = \text{atan2}(x, y)$, and so $\sin(\theta) = \frac{y}{r}$. The final expression for $k$ is
#
# $$
# k = \frac{3 U_0}{r_0^2} \left( 2 + \xi_+ + \xi_- \frac{y}{r} \right)
# $$
#
# where $\xi_\pm = \xi_2 \pm \xi_1$.

# %%
dim = 2

# %%
r = Symbol('r')
U0 = Symbol('U0')
r0 = Symbol('r0')
k = Symbol('k')
r1 = (r0/2) * (k*r0**2 - 12*U0) / (k*r0**2 - 6*U0)

abs_r = sqrt(r**2)
U_radial = (1 / (2*r0**4))*(abs_r - r0)**2 * (k*abs_r**2*r0**2 - 2*U0*(abs_r-r0)*(3*abs_r + r0))
dU_radial = U_radial.diff(r).simplify()
ddU_radial = U_radial.diff(r, 2).simplify()
dddU_radial = U_radial.diff(r, 3).simplify()

# %% [markdown]
# ### Plot radial potential

# %%
_U0 = 1
_r0 = 1
_k = 7*_U0/_r0**2

rs = np.linspace(-2, 2, 1000)

Us = sympy.lambdify([r, U0, r0, k], U_radial)(rs, _U0, _r0, _k)
dUs = sympy.lambdify([r, U0, r0, k], dU_radial)(rs, _U0, _r0, _k)
ddUs = sympy.lambdify([r, U0, r0, k], ddU_radial)(rs, _U0, _r0, _k)
dddUs = sympy.lambdify([r, U0, r0, k], dddU_radial)(rs, _U0, _r0, _k)

fig, ax = plt.subplots(1, 4, figsize=(16, 3), dpi=200)
ax[0].plot(rs, Us, label="$U$"); ax[0].legend(loc="upper center")
ax[1].plot(rs, dUs, label="$U'$"); ax[1].legend(loc="upper center")
ax[2].plot(rs, ddUs, label="$U''$"); ax[2].legend(loc="upper center")
ax[3].plot(rs, dddUs, label="$U'''$"); ax[3].legend(loc="upper center")
plt.show()

# %% [markdown]
# ### Non-equilibrium force

# %%
x = Symbol('x')
y = Symbol('y')
eta = Symbol('eta')
theta = Symbol('theta')

Fneq = Matrix([0, 0])

Fneq[0] = -sympy.cos( sympy.atan2(x, y) )
Fneq[1] = sympy.sin( sympy.atan2(x, y) )
Fneq[0] = -y
Fneq[1] = x
Fneq *= eta

Fneq_r = sympy.exp(-theta*( sqrt(x**2 + y**2) - r0 )**2)
#Fneq[0] = -sympy.cos( sympy.atan2(x, y) )
#Fneq[1] = sympy.sin( sympy.atan2(x, y) )
Fneq[0] = -y
Fneq[1] = x

Fneq[0] = -sympy.cos( sympy.atan2(x, y) )
Fneq[1] = sympy.sin( sympy.atan2(x, y) )
Fneq *= eta * Fneq_r

Fneq
# Out:
# Matrix([
# [-eta*y*exp(-theta*(-r0 + sqrt(x**2 + y**2))**2)/sqrt(x**2 + y**2)],
# [ eta*x*exp(-theta*(-r0 + sqrt(x**2 + y**2))**2)/sqrt(x**2 + y**2)]])

# %%
xlim = (-1.5, 1.5)
ylim = (-1.5, 1.5)

_r0 = 1
_eta = -0.1
_theta = 2

fig = plt.figure(figsize=(6,6))
ax = plt.axes()

Fneq_x_func = sympy.lambdify([x, y, r0, eta, theta], Fneq[0])
Fneq_y_func = sympy.lambdify([x, y, r0, eta, theta], Fneq[1])

xs = np.linspace(xlim[0], xlim[1], 400)
ys = np.linspace(ylim[0], ylim[1], 400)
X, Y = np.meshgrid(xs,  ys)
U, V = Fneq_x_func(X, Y, _r0, _eta, _theta), Fneq_y_func(X, Y, _r0, _eta, _theta)
speed = np.sqrt(U**2 + V**2)
lw = 2*speed / speed.max()

ax.streamplot(X, Y, U, V, density=[2, 2], linewidth=lw)
plt.show()

# %% [markdown]
# ### Plot 2D potential

# %%
x = Symbol('x')
y = Symbol('y')
r = Function('r')(x,y)
xip = Symbol('xi_p')
xim = Symbol('xi_m')
#k = Function('k')(x,y)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))

F = -Matrix([U.diff(x), U.diff(y)])
F = F.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
F[0] = F[0].simplify()
F[1] = F[1].simplify()
divF = (F[0].diff(x) + F[1].diff(y))
divF = divF.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
divF = divF.simplify().simplify()

# %%
_theta = 0

_U0 = 1
_r0 = 1
_xi1 = 0
_xi2 = 1
_xip = _xi2 + _xi1
_xim = _xi2 - _xi1

xlim = (-1.5, 1.5)
ylim = (-1.5, 1.5)
rlim = (-1.5, 1.5)
cbr = 0.1

xs = np.linspace(xlim[0], xlim[1], 400)
ys = np.linspace(ylim[0], ylim[1], 400)
X, Y = np.meshgrid(xs,  ys)
U_xy = U.subs(r, sqrt(x**2 + y**2)).simplify()
divF_xy = divF.subs(r, sqrt(x**2 + y**2)).simplify()
U_func = sympy.lambdify([x, y, U0, r0, xip, xim], U_xy)
divF_func = sympy.lambdify([x, y, U0, r0, xip, xim], divF_xy)
Z = U_func(X, Y, _U0, _r0, _xip, _xim)

zero_path_x, zero_path_y = _r0*np.cos(np.linspace(0, 2*np.pi, 500)), _r0*np.sin(np.linspace(0, 2*np.pi, 500))

line_r = np.linspace(-2, 2, 1000)
line_x = np.cos(_theta) * line_r
line_y = np.sin(_theta) * line_r
U_line = U_func(line_x, line_y, _U0, _r0, _xip, _xim)
divF_line = divF_func(line_x, line_y, _U0, _r0, _xip, _xim)

narrow_cbr_x, narrow_cbr_y = np.cos(_theta)*np.linspace(_r0-cbr, _r0+cbr, 1000), np.sin(_theta)*np.linspace(_r0-cbr, _r0+cbr, 1000)
narrow_cbr_r = np.sqrt(narrow_cbr_x**2 + narrow_cbr_y**2)
broad_cbr_x, broad_cbr_y = np.cos(_theta)*np.linspace(-_r0-cbr, -_r0+cbr, 1000), np.sin(_theta)*np.linspace(-_r0-cbr, -_r0+cbr, 1000)
broad_cbr_r = -np.sqrt(broad_cbr_x**2 + broad_cbr_y**2)

U_narrow_cbr = U_func(narrow_cbr_x, narrow_cbr_y, _U0, _r0, _xip, _xim)
U_broad_cbr = U_func(broad_cbr_x, broad_cbr_y, _U0, _r0, _xip, _xim)

fig, axes = plt.subplots(1, 4, figsize=(16,4))
axes = axes.flatten()

axes[0].contour(X, Y, Z, levels=100)
axes[0].plot(zero_path_x, zero_path_y, "r--")
mask = (line_r >= 0) * (line_r <= rlim[1])
axes[0].plot(line_x[mask], line_y[mask], "orange")
mask = (line_r <= 0) * (line_r >= rlim[0])
axes[0].plot(line_x[mask], line_y[mask], "green")

mask = (line_r >= 0) * (line_r <= rlim[1])
axes[1].plot(line_r[mask], U_line[mask], "orange")
mask = (line_r <= 0) * (line_r >= rlim[0])
axes[1].plot(line_r[mask], U_line[mask], "green")

axes[2].plot(narrow_cbr_r - _r0, U_narrow_cbr, "orange")
axes[2].plot(broad_cbr_r + _r0, U_broad_cbr, "green")

mask = (line_r >= 0) * (line_r <= rlim[1])
axes[3].plot(line_r[mask], divF_line[mask], "orange")
mask = (line_r <= 0) * (line_r >= rlim[0])
axes[3].plot(line_r[mask], divF_line[mask], "green")

axes[1].set_title(r'$U(r \cos \theta, r \sin \theta)$')
axes[2].set_title(r'$U(r \cos \theta, r \sin \theta)$')
axes[2].set_xlabel(r'$r-r_0$')
axes[3].set_title(r'$\nabla \cdot f$')

axes[0].set_xlim(xlim[0], xlim[1])
axes[0].set_ylim(ylim[0], ylim[1])

plt.show()

# %% [markdown]
# ### Streamplot

# %%
x = Symbol('x')
y = Symbol('y')
r = Function('r')(x,y)
xip = Symbol('xi_p')
xim = Symbol('xi_m')
#k = Function('k')(x,y)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))

Feq = -Matrix([U.diff(x), U.diff(y)])
F = Feq + Fneq
F = F.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
F[0] = F[0].simplify()
F[1] = F[1].simplify()
divF = (F[0].diff(x) + F[1].diff(y))
divF = divF.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
divF = divF.simplify().simplify()

# %%
xlim = (-1.2, 1.2)
ylim = (-1.2, 1.2)

_U0 = 1
_r0 = 1
_xi1 = 0
_xi2 = 5
_xip = _xi2 + _xi1
_xim = _xi2 - _xi1
_eta = 5
_theta = 0

fig = plt.figure(figsize=(6,6))
ax = plt.axes()

F_xy = F.subs(r, sqrt(x**2 + y**2))

F_x_func = sympy.lambdify([x, y, U0, r0, xip, xim, eta, theta], F_xy[0])
F_y_func = sympy.lambdify([x, y, U0, r0, xip, xim, eta, theta], F_xy[1])

xs = np.linspace(xlim[0], xlim[1], 400)
ys = np.linspace(ylim[0], ylim[1], 400)
X, Y = np.meshgrid(xs,  ys)
U, V = F_x_func(X, Y, _U0, _r0, _xip, _xim, _eta, _theta), F_y_func(X, Y, _U0, _r0, _xip, _xim, _eta, _theta)
speed = np.sqrt(U**2 + V**2)
lw = 6*speed / speed.max()+0.2

ax.streamplot(X, Y, U, V, density=[2, 2], linewidth=lw)
plt.show()

# %% [markdown]
# ### Generate force functions

# %%
x = Symbol('x')
y = Symbol('y')
r = Function('r')(x,y)
xip = Symbol('xip')
xim = Symbol('xim')
#k = Function('k')(x,y)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))
U = U.subs(r0, 1)

Fneq_r = sympy.exp(-theta*( r - r0 )**2)
Fneq_r = Fneq_r.subs(r0, 1)
Fneq[0] =  - Fneq_r * eta * y / r
Fneq[1] =  Fneq_r * eta * x / r

Feq = -Matrix([U.diff(x), U.diff(y)])
F = Feq + Fneq
F = F.subs(r.diff(x), x/r).subs(r.diff(y), y/r)

F[0] = F[0].simplify()
F[1] = F[1].simplify()
divF = (F[0].diff(x) + F[1].diff(y))
divF = divF.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
divF = divF.simplify().simplify()

U = U.subs(r**2, Symbol('r2')).subs(r, Symbol('r'))
F = F.subs(r**2, Symbol('r2')).subs(r, Symbol('r'))
divF = divF.subs(r**2, Symbol('r2')).subs(r, Symbol('r'))

# %%
U = N(U)
F = N(F)
divF = N(divF)

# %%
from sympy.printing.pycode import NumPyPrinter

py_U = NumPyPrinter().doprint(U).replace("numpy", "np")
py_Fx = NumPyPrinter().doprint(F[0]).replace("numpy", "np")
py_Fy = NumPyPrinter().doprint(F[1]).replace("numpy", "np")
py_div_F = NumPyPrinter().doprint(divF).replace("numpy", "np")

# %%
print(("""
def Upot(x, y):
    r2 = x**2 + y**2
    r = np.sqrt(r2)
    return %s
def force_func(path):
    x, y = path[:, 0], path[:, 1]
    f = np.zeros(path.shape) 
    r2 = x**2 + y**2
    r = np.sqrt(r2)
    f[:,0] = %s
    f[:,1] = %s
    div_f = %s
    return f, div_f
def force_vec(x, y):
    r2 = x**2 + y**2
    r = np.sqrt(r2)
    fx = %s
    fy = %s
    return fx, fy
def divf(x, y):
    r2 = x**2 + y**2
    r = np.sqrt(r2)
    _divf = %s
    return _divf
""" % (py_U, py_Fx, py_Fy, py_div_F, py_Fx, py_Fy, py_div_F)).strip())
# Out:
# def Upot(x, y):
#     r2 = x**2 + y**2
#     r = np.sqrt(r2)
#     return 0.5*(r - 1.0)**2*(3.0*U0*r2*(xip + 2.0 + xim*y/r) - 2.0*U0*(r - 1.0)*(3.0*r + 1.0))
# def force_func(path):
#     x, y = path[:, 0], path[:, 1]
#     f = np.zeros(path.shape)
#     r2 = x**2 + y**2
#     r = np.sqrt(r2)
#     f[:,0] = (0.5*U0*x*(r - 1.0)*(-6.0*r*(r*(xip + 2.0) + xim*y) + 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(-6.0*r*(xip + 2.0) + 12.0*r - 3.0*xim*y - 4.0))*np.exp(theta*(r - 1)**2) - eta*y)*np.exp(-theta*(r - 1)**2)/r
#     f[:,1] = (U0*y*(r - 1.0)*(-3.0*r*(r*(xip + 2.0) + xim*y) + 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) + 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r2 + y**2) + 2.0*y*(-3.0*r*(xip + 2.0) + 6.0*r - 3.0*xim*y - 2.0))*np.exp(theta*(r - 1)**2) + eta*x)*np.exp(-theta*(r - 1)**2)/r
#     div_f = 1.5*U0*(4.0*r**3*(-3.0*r*xim*y + 3.0*r*xip - 2.0*r - 2.0*r2*xip - 2.0*x**2*xip + 4.0*xim*y - 2.0*xip*y**2 - xip + 2.0) + r2*(-3.0*x**2*xim*y + 6.0*x**2*xip - 4.0*x**2 - 3.0*xim*y**3 - 4.0*xim*y + 6.0*xip*y**2 - 4.0*y**2) + xim*y*(x**2 + y**2))/r**3
#     return f, div_f
# def force_vec(x, y):
#     r2 = x**2 + y**2
#     r = np.sqrt(r2)
#     fx = (0.5*U0*x*(r - 1.0)*(-6.0*r*(r*(xip + 2.0) + xim*y) + 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(-6.0*r*(xip + 2.0) + 12.0*r - 3.0*xim*y - 4.0))*np.exp(theta*(r - 1)**2) - eta*y)*np.exp(-theta*(r - 1)**2)/r
#     fy = (U0*y*(r - 1.0)*(-3.0*r*(r*(xip + 2.0) + xim*y) + 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) + 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r2 + y**2) + 2.0*y*(-3.0*r*(xip + 2.0) + 6.0*r - 3.0*xim*y - 2.0))*np.exp(theta*(r - 1)**2) + eta*x)*np.exp(-theta*(r - 1)**2)/r
#     return fx, fy
# def divf(x, y):
#     r2 = x**2 + y**2
#     r = np.sqrt(r2)
#     _divf = 1.5*U0*(4.0*r**3*(-3.0*r*xim*y + 3.0*r*xip - 2.0*r - 2.0*r2*xip - 2.0*x**2*xip + 4.0*xim*y - 2.0*xip*y**2 - xip + 2.0) + r2*(-3.0*x**2*xim*y + 6.0*x**2*xip - 4.0*x**2 - 3.0*xim*y**3 - 4.0*xim*y + 6.0*xip*y**2 - 4.0*y**2) + xim*y*(x**2 + y**2))/r**3
#     return _divf

# %% [markdown]
# ### Gradient of Lagrangian

# %% [markdown]
# $$
# L(\mathbf{x}, \dot{\mathbf{x}}) = \frac{\beta \gamma}{4} \sum_{i=1}^d (\dot{x}_i - \gamma^{-1} f_i)^2 + \frac{1}{2\gamma} \sum_{i=1}^d \nabla_i f_i
# $$
#
# $$
# \frac{\partial L}{\partial x_i} = \frac{\beta}{2} \sum_k  (\gamma^{-1} f_k - \dot{x}_k) \frac{\partial f_k}{\partial x_i} + \frac{1}{2\gamma} \frac{\partial}{\partial x_i} \nabla \cdot f
# $$
#
# $$
# \frac{\partial L}{\partial \dot{x}_i} = \frac{\beta \gamma}{2} (\dot{x}_i - \gamma^{-1}  f_i )
# $$

# %%
x = Symbol('x')
y = Symbol('y')
r = Function('r')(x,y)
xip = Symbol('xip')
xim = Symbol('xim')
#k = Function('k')(x,y)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))
U = U.subs(r0, 1)

Fneq_r = sympy.exp(-theta*( r - r0 )**2)
Fneq_r = Fneq_r.subs(r0, 1)
Fneq[0] =  - Fneq_r * eta * y / r
Fneq[1] =  Fneq_r * eta * x / r

Feq = -Matrix([U.diff(x), U.diff(y)])
F = Feq + Fneq
F = F.subs(r.diff(x), x/r).subs(r.diff(y), y/r)

F[0] = F[0].simplify()
F[1] = F[1].simplify()
divF = (F[0].diff(x) + F[1].diff(y))
divF = divF.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
divF = divF.simplify().simplify()
divF = divF.subs(x**2 + y**2, r**2).simplify()

#U = U.subs(r**2, Symbol('r2')).subs(r, Symbol('r'))
#F = F.subs(r**2, Symbol('r2')).subs(r, Symbol('r'))
#divF = divF.subs(r**2, Symbol('r2')).subs(r, Symbol('r'))

# %% [markdown]
# $$ (df)_{ij} = \frac{\partial f_i}{\partial x_j} $$

# %%
dF = zeros(dim,dim)
deps = [x, y]

for i in range(dim):
    for j in range(dim):
        dF[i,j] = F[i].diff(deps[j]).simplify()
        dF[i,j] = dF[i,j].subs(r.diff(x), x/r).subs(r.diff(y), y/r).simplify()
        dF[i,j] = dF[i,j].subs(x**2 + y**2, r**2).simplify()

# %%
dF_strs = []

for i in range(dim):
    for j in range(dim):
        _dfij = dF[i,j].subs(r**2, Symbol('r2')).subs(r, Symbol('r'))
        dfij_str = NumPyPrinter().doprint(_dfij).replace("numpy", "np")
        dF_strs.append("dF[%s,%s,:]=%s" % ( i, j, dfij_str))
        
dF_str = "\n        ".join(dF_strs)

# %% [markdown]
# $$
# \frac{\partial}{\partial x_i} \nabla \cdot f
# $$

# %%
ddivF = zeros(dim, 1)

for i in range(dim):
    ddivF[i] = divF.diff(deps[i]).simplify()
    ddivF[i] = ddivF[i].subs(r.diff(x), x/r).subs(r.diff(y), y/r).simplify()
    ddivF[i] = ddivF[i].subs(x**2 + y**2, r**2).simplify()

# %%
ddivF_str = []

for i in range(dim):
    _ddivfij = ddivF[i].subs(r**2, Symbol('r2')).subs(r, Symbol('r'))
    ddivf_str = NumPyPrinter().doprint(_ddivfij).replace("numpy", "np")
    ddivF_str.append("ddivF[%s,:]=%s" % ( i, ddivf_str))
        
ddivF_str = "\n        ".join(ddivF_str)

# %%
print(("""
def lagrangian(ls, dxls, dvls, path, us, args):
    xs, vs = path
    vs *= _vs_rescaling
    fs, div_f = force_func(xs.T)
    fs = fs.T
    
    vs_minus_f = vs - fs/gamma
    FW_term = _FW_factor * np.einsum("ij,ij->j", vs_minus_f, vs_minus_f)
    OM_term = _OM_factor * div_f
    
    ls[:] = _time_jacobian_factor * (FW_term + OM_term)
    
    if not dxls is None:
        x, y = xs
        r2 = xs[0,:]**2 + xs[1,:]**2
        r = np.sqrt(r2)
        
        ## Compute dL/dx
        
        dF = np.zeros( (dim, dim, len(us)) )
        # %s
        
        ddivF = np.zeros( (dim, len(us)) )
        # %s
        
        FW_term = - (beta/2) * np.einsum("ik,ijk->jk", vs_minus_f, dF)
        OM_term = _OM_factor*ddivF
        dxls[:] = _time_jacobian_factor * (FW_term + OM_term)
        
        ## Compute dL/dv
        
        dvls[:] = _time_jacobian_factor * _FW_factor * 2 * vs_minus_f
        
""" % (dF_str, ddivF_str)).strip())
# Out:
# def lagrangian(ls, dxls, dvls, path, us, args):
#     xs, vs = path
#     vs *= _vs_rescaling
#     fs, div_f = force_func(xs.T)
#     fs = fs.T
#
#     vs_minus_f = vs - fs/gamma
#     FW_term = _FW_factor * np.einsum("ij,ij->j", vs_minus_f, vs_minus_f)
#     OM_term = _OM_factor * div_f
#
#     ls[:] = _time_jacobian_factor * (FW_term + OM_term)
#
#     if not dxls is None:
#         x, y = xs
#         r2 = xs[0,:]**2 + xs[1,:]**2
#         r = np.sqrt(r2)
#
#         ## Compute dL/dx
#
#         dF = np.zeros( (dim, dim, len(us)) )
#         dF[0,0,:]=(1/2)*(-4*eta*r*theta*x*y + r2*(-3*U0*r*(3*r*xim*y - 6*r*xip + 4*r + 4*r2*xip + 8*x**2*xip - 4*xim*y + 2*xip - 4) - 9*U0*x**2*xim*y + 18*U0*x**2*xip - 12*U0*x**2 - 3*U0*xim*y + 4*eta*theta*x*y*np.exp(theta*(2*r - r2 - 1)))*np.exp(theta*(-2*r + r2 + 1)) + x*y*(3*U0*x*xim*np.exp(theta*(-2*r + r2 + 1)) + 2*eta))*np.exp(-theta*(-2*r + r2 + 1))/r**3
#         dF[0,1,:]=(1/2)*(-4*eta*r*theta*y**2 + r2*(-3*U0*r*x*(3*r*xim - 4*xim + 8*xip*y) - 9*U0*x*xim*y**2 - 3*U0*x*xim + 18*U0*x*xip*y - 12*U0*x*y + 4*eta*theta*y**2*np.exp(theta*(2*r - r2 - 1)) - 2*eta*np.exp(theta*(2*r - r2 - 1)))*np.exp(theta*(-2*r + r2 + 1)) + y**2*(3*U0*x*xim*np.exp(theta*(-2*r + r2 + 1)) + 2*eta))*np.exp(-theta*(-2*r + r2 + 1))/r**3
#         dF[1,0,:]=(1/2)*(4*eta*r*theta*x**2 + r2*(-3*U0*r*x*(3*r*xim - 4*xim + 8*xip*y) - 9*U0*x*xim*y**2 - 3*U0*x*xim + 18*U0*x*xip*y - 12*U0*x*y - 4*eta*theta*x**2*np.exp(theta*(2*r - r2 - 1)) + 2*eta*np.exp(theta*(2*r - r2 - 1)))*np.exp(theta*(-2*r + r2 + 1)) + x*(3*U0*xim*y**2*np.exp(theta*(-2*r + r2 + 1)) - 2*eta*x))*np.exp(-theta*(-2*r + r2 + 1))/r**3
#         dF[1,1,:]=(1/2)*(4*eta*r*theta*x*y - r2*(3*U0*r*(9*r*xim*y - 6*r*xip + 4*r + 4*r2*xip - 12*xim*y + 8*xip*y**2 + 2*xip - 4) + y*(9*U0*xim*y**2 + 9*U0*xim - 18*U0*xip*y + 12*U0*y + 4*eta*theta*x*np.exp(theta*(2*r - r2 - 1))))*np.exp(theta*(-2*r + r2 + 1)) + y*(3*U0*xim*y**2*np.exp(theta*(-2*r + r2 + 1)) - 2*eta*x))*np.exp(-theta*(-2*r + r2 + 1))/r**3
#
#         ddivF = np.zeros( (dim, len(us)) )
#         ddivF[0,:]=(3/2)*U0*x*(r2*(-32*r*xip - 18*xim*y + 24*xip - 16) + 3*x**2*xim*y - 6*x**2*xip + 4*x**2 + 3*xim*y**3 + 3*xim*y - 6*xip*y**2 + 4*y**2)/r**3
#         ddivF[1,:]=(3/2)*U0*(r2*(16*r*xim - 32*r*xip*y - 12*r2*xim - 3*x**2*xim - 21*xim*y**2 - 3*xim + 24*xip*y - 16*y) + 3*x**2*xim*y**2 - 6*x**2*xip*y + 4*x**2*y + 3*xim*y**4 + 3*xim*y**2 - 6*xip*y**3 + 4*y**3)/r**3
#
#         FW_term = - (beta/2) * np.einsum("ik,ijk->jk", vs_minus_f, dF)
#         OM_term = _OM_factor*ddivF
#         dxls[:] = _time_jacobian_factor * (FW_term + OM_term)
#
#         ## Compute dL/dv
#
#         dvls[:] = _time_jacobian_factor * _FW_factor * 2 * vs_minus_f

# %% [markdown]
# ### Gradient of the action

# %%
dim = 2

# %%
g = Symbol('gamma')
b = Symbol('beta')

x, y = symbols('x y')
xdot, ydot = symbols('xdot ydot')

coords = [x, y]
dcoords = [xdot, ydot]

# %%
r = Function('r')(x,y)
xip = Symbol('xip')
xim = Symbol('xim')
#k = Function('k')(x,y)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))
U = U.subs(r0, 1)

Fneq_r = sympy.exp(-theta*( r - r0 )**2)
Fneq_r = Fneq_r.subs(r0, 1)
Fneq[0] =  - Fneq_r * eta * y / r
Fneq[1] =  Fneq_r * eta * x / r

Feq = -Matrix([U.diff(x), U.diff(y)])
F = Feq + Fneq
F = F.subs(r.diff(x), x/r).subs(r.diff(y), y/r)

F[0] = F[0].simplify()
F[1] = F[1].simplify()
divF = (F[0].diff(x) + F[1].diff(y))
divF = divF.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
divF = divF.simplify().simplify()
divF = divF.subs(x**2 + y**2, r**2).simplify()

# %%
L_OM = (b*g/4) * ( (xdot - F[0]/g)**2 + (ydot - F[1]/g)**2 ) + (1/(2*g)) * divF
L_FW = (b*g/4) * ( (xdot - F[0]/g)**2 + (ydot - F[1]/g)**2 ) + (1/(2*g))

L_OM = L_OM.simplify()
L_FW = L_FW.simplify()

L_OM = N(L_OM)
L_FW = N(L_FW)

# %%
def get_L_derivs(L):
    L_x = zeros(dim, 1)
    L_xd = zeros(dim, 1)

    for i in range(dim):
        L_x[i] = L.diff(coords[i]).subs(r.diff(coords[i]), coords[i]/r).simplify()
        L_x[i] = L_x[i].subs(r, Symbol('r'))
        
        L_xd[i] = L.diff(dcoords[i]).simplify()
        L_xd[i] = L_xd[i].subs(r, Symbol('r'))
            
    return L_x, L_xd

L_x_OM, L_xd_OM = get_L_derivs(L_OM)
L_x_FW, L_xd_FW = get_L_derivs(L_FW)

# %%
def to_pycode(s):
    return sympy.printing.pycode(s)

# %%
L_derivs_OM_str = """
def gradL_OM(path, dpath):
    x, y = path[:, 0], path[:, 1]
    xdot, ydot = dpath[:, 0], dpath[:, 1]
    r = np.sqrt(x**2 + y**2)
    L_x = np.zeros((%s, len(path)))
    L_xd = np.zeros((%s, len(path)))
""" % (dim, dim)

for i in range(dim):
    L_derivs_OM_str += "    L_x[%s] = %s\n" % (i, to_pycode(L_x_OM[i]))
    L_derivs_OM_str += "    L_xd[%s] = %s\n" % (i, to_pycode(L_xd_OM[i]))

L_derivs_OM_str = L_derivs_OM_str.replace('math.exp', 'np.exp')
    
L_derivs_OM_str += "    return L_x, L_xd"

# %%
L_derivs_FW_str = """
def gradL_FW(path, dpath):
    x, y = path[:, 0], path[:, 1]
    xdot, ydot = dpath[:, 0], dpath[:, 1]
    r = np.sqrt(x**2 + y**2)
    L_x = np.zeros((%s, len(path)))
    L_xd = np.zeros((%s, len(path)))
""" % (dim, dim)

for i in range(dim):
    L_derivs_FW_str += "    L_x[%s] = %s\n" % (i, to_pycode(L_x_FW[i]))
    L_derivs_FW_str += "    L_xd[%s] = %s\n" % (i, to_pycode(L_xd_FW[i]))

L_derivs_FW_str = L_derivs_FW_str.replace('math.exp', 'np.exp')
    
L_derivs_FW_str += "    return L_x, L_xd"

# %%
print("%s%s" % (L_derivs_OM_str, L_derivs_FW_str))
# Out:
# def gradL_OM(path, dpath):
#     x, y = path[:, 0], path[:, 1]
#     xdot, ydot = dpath[:, 0], dpath[:, 1]
#     r = np.sqrt(x**2 + y**2)
#     L_x = np.zeros((2, len(path)))
#     L_xd = np.zeros((2, len(path)))
#     L_x[0] = (r*(-0.0625*U0*r*x*(96.0*r**2*xip + 144.0*r*xim*y - 144.0*r*xip + 12.0*r*(32.0*r*xip + 18.0*xim*y - 24.0*xip + 16.0) + 96.0*r + 48.0*theta*(r - 1)*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2) + 96.0*x**2*xip - 192.0*xim*y + 96.0*xip*y**2 + 48.0*xip - 96.0)*np.exp(2*theta*(r - 1)**2) - 0.75*U0*x*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2)*np.exp(2*theta*(r - 1)**2) + 0.25*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))*(2.0*U0*theta*x**2*(r - 1)*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)) + U0*x**2*(r - 1.0)*(18.0*r*(xip + 2.0) - 36.0*r + 9.0*xim*y + 6.0*xip*(r - 1.0) + 12.0) + U0*x**2*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)) + 2*gamma*x*xdot + r*(U0*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)) + 4*gamma*theta*x*xdot*(r - 1)))*np.exp(theta*(r - 1)**2) + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))*(4*U0*theta*x*y*(r - 1)*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 2.0*U0*theta*x*(r - 1)*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) + 2*U0*x*y*(r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)*np.exp(theta*(r - 1)**2) + 2*U0*x*y*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) + 6.0*U0*x*(r - 1.0)**2*(r*xim + xip*y)*np.exp(theta*(r - 1)**2) - 2.0*U0*x*(r - 1.0)*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) + 2*gamma*x*ydot*np.exp(theta*(r - 1)**2) + 2*r*(-eta + 2*gamma*theta*x*ydot*(r - 1)*np.exp(theta*(r - 1)**2)))) + 0.25*theta*x*(r - 1)*(12.0*U0*r*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2)*np.exp(2*theta*(r - 1)**2) - 4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))**2))) + 0.125*x*(12.0*U0*r*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2)*np.exp(2*theta*(r - 1)**2) - 4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xi ...
#     L_xd[0] = 0.5*beta*(0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))*np.exp(-theta*(r - 1)**2)/r
#     L_x[1] = (r*(-0.0625*U0*r*(12.0*r*(r*(12.0*r*xim - 16.0*xim + 32.0*xip*y) + 3.0*x**2*xim + 21.0*xim*y**2 + 3.0*xim - 24.0*xip*y + 16.0*y) + 48.0*theta*y*(r - 1)*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2) + 12.0*y*(8.0*r**2*xip + 12.0*r*xim*y - 12.0*r*xip + 8.0*r + 8.0*x**2*xip - 16.0*xim*y + 8.0*xip*y**2 + 4.0*xip - 8.0))*np.exp(2*theta*(r - 1)**2) - 0.75*U0*y*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2)*np.exp(2*theta*(r - 1)**2) + 0.25*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))*(2.0*U0*theta*x*y*(r - 1)*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + U0*x*y*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + U0*x*(r - 1.0)*(6.0*r*(r*xim + y*(xip + 2.0)) - 12.0*y*(r - 1.0) - y*(12.0*r + 4.0) + 6.0*y*(r*(xip + 2.0) + xim*y) + y*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0) + (r - 1.0)*(3.0*r*xim + y*(6.0*xip + 12.0) - 12.0*y))*np.exp(theta*(r - 1)**2) + 2*gamma*xdot*y*np.exp(theta*(r - 1)**2) + 2*r*(eta + 2*gamma*theta*xdot*y*(r - 1)*np.exp(theta*(r - 1)**2))) + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))*(4*U0*theta*y**2*(r - 1)*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - 2.0*U0*theta*y*(r - 1)*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0)) + 2*U0*y**2*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - 2.0*U0*y*(r - 1.0)*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0)) + 2*U0*y*(r - 1.0)*(3.0*r*(r*xim + y*(xip + 2.0)) - 6.0*y*(r - 1.0) - y*(6.0*r + 2.0) + 3.0*y*(r*(xip + 2.0) + xim*y)) + 1.0*U0*(r - 1.0)**2*(r*(6.0*r*(xip + 2.0) - 12.0*r + 6.0*xim*y + 4.0) + 2.0*y*(3.0*r*xim + y*(3.0*xip + 6.0) - 6.0*y)) + 2*gamma*y*ydot + 2*r*(U0*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0)) + 2*gamma*theta*y*ydot*(r - 1)))*np.exp(theta*(r - 1)**2)) + 0.25*theta*y*(r - 1)*(12.0*U0*r*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2)*np.exp(2*theta*(r - 1)**2) - 4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))**2))) + 0.125*y*(12.0*U0*r*(4.0*r*(2.0*r**2*xip + 3.0*r*xim*y - 3.0*r*xip + 2.0*r + 2.0*x**2*xip - 4.0*xim*y + 2.0*xip*y**2 + xip - 2.0) + 3.0*x**2*xim*y - 6.0*x**2*xip + 4.0*x**2 + 3.0*xim*y**3 + 3.0*xim*y - 6.0*xip*y**2 + 4.0*y**2)*np.exp(2*theta*(r - 1)**2) - 4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.e ...
#     L_xd[1] = 0.5*beta*(U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))*np.exp(-theta*(r - 1)**2)/r
#     return L_x, L_xd
# def gradL_FW(path, dpath):
#     x, y = path[:, 0], path[:, 1]
#     xdot, ydot = dpath[:, 0], dpath[:, 1]
#     r = np.sqrt(x**2 + y**2)
#     L_x = np.zeros((2, len(path)))
#     L_xd = np.zeros((2, len(path)))
#     L_x[0] = (r*(0.25*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))*(2.0*U0*theta*x**2*(r - 1)*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)) + U0*x**2*(r - 1.0)*(18.0*r*(xip + 2.0) - 36.0*r + 9.0*xim*y + 6.0*xip*(r - 1.0) + 12.0) + U0*x**2*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)) + 2*gamma*x*xdot + r*(U0*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)) + 4*gamma*theta*x*xdot*(r - 1)))*np.exp(theta*(r - 1)**2) + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))*(4*U0*theta*x*y*(r - 1)*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 2.0*U0*theta*x*(r - 1)*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) + 2*U0*x*y*(r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0)*np.exp(theta*(r - 1)**2) + 2*U0*x*y*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) + 6.0*U0*x*(r - 1.0)**2*(r*xim + xip*y)*np.exp(theta*(r - 1)**2) - 2.0*U0*x*(r - 1.0)*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) + 2*gamma*x*ydot*np.exp(theta*(r - 1)**2) + 2*r*(-eta + 2*gamma*theta*x*ydot*(r - 1)*np.exp(theta*(r - 1)**2)))) + 0.0625*r*x*(32.0*r*theta*(r - 1) + 16.0)*np.exp(2*theta*(r - 1)**2) - 0.25*theta*x*(r - 1)*(4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))**2) + 8.0*r**2*np.exp(2*theta*(r - 1)**2))) - 0.125*x*(4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))**2) + 8.0*r**2*np.exp(2*theta*(r - 1)**2)))*np.exp(-2*theta*(r - 1)**2)/(gamma*r**4)
#     L_xd[0] = 0.5*beta*(0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))*np.exp(-theta*(r - 1)**2)/r
#     L_x[1] = (r*(0.25*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))*(2.0*U0*theta*x*y*(r - 1)*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + U0*x*y*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + U0*x*(r - 1.0)*(6.0*r*(r*xim + y*(xip + 2.0)) - 12.0*y*(r - 1.0) - y*(12.0*r + 4.0) + 6.0*y*(r*(xip + 2.0) + xim*y) + y*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0) + (r - 1.0)*(3.0*r*xim + y*(6.0*xip + 12.0) - 12.0*y))*np.exp(theta*(r - 1)**2) + 2*gamma*xdot*y*np.exp(theta*(r - 1)**2) + 2*r*(eta + 2*gamma*theta*xdot*y*(r - 1)*np.exp(theta*(r - 1)**2))) + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))*(4*U0*theta*y**2*(r - 1)*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - 2.0*U0*theta*y*(r - 1)*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0)) + 2*U0*y**2*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - 2.0*U0*y*(r - 1.0)*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0)) + 2*U0*y*(r - 1.0)*(3.0*r*(r*xim + y*(xip + 2.0)) - 6.0*y*(r - 1.0) - y*(6.0*r + 2.0) + 3.0*y*(r*(xip + 2.0) + xim*y)) + 1.0*U0*(r - 1.0)**2*(r*(6.0*r*(xip + 2.0) - 12.0*r + 6.0*xim*y + 4.0) + 2.0*y*(3.0*r*xim + y*(3.0*xip + 6.0) - 6.0*y)) + 2*gamma*y*ydot + 2*r*(U0*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0)) + 2*gamma*theta*y*ydot*(r - 1)))*np.exp(theta*(r - 1)**2)) + 0.0625*r*y*(32.0*r*theta*(r - 1) + 16.0)*np.exp(2*theta*(r - 1)**2) - 0.25*theta*y*(r - 1)*(4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))**2) + 8.0*r**2*np.exp(2*theta*(r - 1)**2))) - 0.125*y*(4.0*beta*((0.5*U0*x*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*y) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*y + 4.0))*np.exp(theta*(r - 1)**2) + eta*y + gamma*r*xdot*np.exp(theta*(r - 1)**2))**2 + (U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))**2) + 8.0*r**2*np.exp(2*theta*(r - 1)**2)))*np.exp(-2*theta*(r - 1)**2)/(gamma*r**4)
#     L_xd[1] = 0.5*beta*(U0*y*(r - 1.0)*(3.0*r*(r*(xip + 2.0) + xim*y) - 2.0*(r - 1.0)*(3.0*r + 1.0))*np.exp(theta*(r - 1)**2) - 0.5*U0*(r - 1.0)**2*(3.0*xim*(-r**2 + y**2) - 2.0*y*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*y + 2.0))*np.exp(theta*(r - 1)**2) - eta*x + gamma*r*ydot*np.exp(theta*(r - 1)**2))*np.exp(-theta*(r - 1)**2)/r
#     return L_x, L_xd

# %% [markdown]
# ### Second variation

# %%
dim = 2

# %%
g = Symbol('gamma')
b = Symbol('beta')

x, y = symbols('x y')
xdot, ydot = symbols('xdot ydot')

coords = [x, y]
dcoords = [xdot, ydot]

# %%
r = Function('r')(x,y)
xip = Symbol('xip')
xim = Symbol('xim')
#k = Function('k')(x,y)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))
U = U.subs(r0, 1)

Fneq_r = sympy.exp(-theta*( r - r0 )**2)
Fneq_r = Fneq_r.subs(r0, 1)
Fneq[0] =  - Fneq_r * eta * y / r
Fneq[1] =  Fneq_r * eta * x / r

Feq = -Matrix([U.diff(x), U.diff(y)])
F = Feq + Fneq
F = F.subs(r.diff(x), x/r).subs(r.diff(y), y/r)

F[0] = F[0].simplify()
F[1] = F[1].simplify()
divF = (F[0].diff(x) + F[1].diff(y))
divF = divF.subs(r.diff(x), x/r).subs(r.diff(y), y/r)
divF = divF.simplify().simplify()
divF = divF.subs(x**2 + y**2, r**2).simplify()

# %%
L_OM = (b*g/4) * ( (xdot - F[0]/g)**2 + (ydot - F[1]/g)**2 ) + (1/(2*g)) * divF
L_FW = (b*g/4) * ( (xdot - F[0]/g)**2 + (ydot - F[1]/g)**2 ) + (1/(2*g))

L_OM = L_OM.simplify()
L_FW = L_FW.simplify()

L_OM = N(L_OM)
L_FW = N(L_FW)

# %%
def get_L_2nd_derivs(L):
    L_x_x = zeros(dim,dim)
    L_xd_x = zeros(dim,dim)
    L_xd_xd = zeros(dim,dim)

    for i in range(dim):
        for j in range(dim):
            foo = L.diff(coords[i]).subs(r.diff(coords[i]), coords[i]/r).simplify()
            foo = foo.diff(coords[j]).subs(r.diff(coords[j]), coords[j]/r).simplify()
            L_x_x[i,j] = foo#.subs(r.diff(coords[i]), coords[i]/r).subs(r.diff(coords[j]), coords[j]/r)
            L_x_x[i,j] = L_x_x[i,j].subs(r, Symbol('r'))

            foo = L.diff(dcoords[i]).simplify()
            foo = foo.diff(coords[j]).subs(r.diff(coords[j]), coords[j]/r).simplify()
            L_xd_x[i,j] = foo#.subs(r.diff(coords[j]), coords[j]/r)
            L_xd_x[i,j] = L_xd_x[i,j].subs(r, Symbol('r'))

            foo = L.diff(dcoords[i]).simplify()
            foo = foo.diff(dcoords[j]).simplify()
            L_xd_xd[i,j] = foo
            L_xd_xd[i,j] = L_xd_xd[i,j].subs(r, Symbol('r'))
            
    return L_x_x, L_xd_x, L_xd_xd

L_x_x_OM, L_xd_x_OM, L_xd_xd_OM = get_L_2nd_derivs(L_OM)
L_x_x_FW, L_xd_x_FW, L_xd_xd_FW = get_L_2nd_derivs(L_FW)

# %%
def to_pycode(s):
    return sympy.printing.pycode(s)

# %%
L_2nd_derivs_OM_str = """
def hessL_OM(path, dpath):
    x, y = path[:, 0], path[:, 1]
    xdot, ydot = dpath[:, 0], dpath[:, 1]
    r = np.sqrt(x**2 + y**2)
    L_x_x = np.zeros((%s, %s, len(path)))
    L_xd_x = np.zeros((%s, %s, len(path)))
    L_xd_xd = np.zeros((%s, %s, len(path)))
""" % (dim, dim, dim, dim, dim, dim)

for i in range(dim):
    for j in range(dim):
        L_2nd_derivs_OM_str += "    L_x_x[%s,%s] = %s\n" % (i,j, to_pycode(L_x_x_OM[i,j]))
        L_2nd_derivs_OM_str += "    L_xd_x[%s,%s] = %s\n" % (i,j, to_pycode(L_xd_x_OM[i,j]))
        L_2nd_derivs_OM_str += "    L_xd_xd[%s,%s] = %s\n" % (i,j, to_pycode(L_xd_xd_OM[i,j]))

L_2nd_derivs_OM_str = L_2nd_derivs_OM_str.replace('math.exp', 'np.exp')
        
L_2nd_derivs_OM_str += "    return L_x_x, L_xd_x, L_xd_xd"

# %%
L_2nd_derivs_FW_str = """
def hessL_FW(path, dpath):
    x, y = path[:, 0], path[:, 1]
    xdot, ydot = dpath[:, 0], dpath[:, 1]
    r = np.sqrt(x**2 + y**2)
    L_x_x = np.zeros((%s, %s, len(path)))
    L_xd_x = np.zeros((%s, %s, len(path)))
    L_xd_xd = np.zeros((%s, %s, len(path)))
""" % (dim, dim, dim, dim, dim, dim)

for i in range(dim):
    for j in range(dim):
        L_2nd_derivs_FW_str += "    L_x_x[%s,%s] = %s\n" % (i,j, to_pycode(L_x_x_FW[i,j]))
        L_2nd_derivs_FW_str += "    L_xd_x[%s,%s] = %s\n" % (i,j, to_pycode(L_xd_x_FW[i,j]))
        L_2nd_derivs_FW_str += "    L_xd_xd[%s,%s] = %s\n" % (i,j, to_pycode(L_xd_xd_FW[i,j]))
        
L_2nd_derivs_FW_str = L_2nd_derivs_FW_str.replace('math.exp', 'np.exp')
        
L_2nd_derivs_FW_str += "    return L_x_x, L_xd_x, L_xd_xd"

# %%
print("%s%s" % (L_2nd_derivs_OM_str, L_2nd_derivs_FW_str))
# Out:
# def hessL_OM(path, dpath):
#     x, y = path[:, 0], path[:, 1]
#     xdot, ydot = dpath[:, 0], dpath[:, 1]
#     r = np.sqrt(x**2 + y**2)
#     L_x_x = np.zeros((2, 2, len(path)))
#     L_xd_x = np.zeros((2, 2, len(path)))
#     L_xd_xd = np.zeros((2, 2, len(path)))
#     L_x_x[0,0] = 3.375*U0**2*beta*r**4*xim**2/gamma + 18.0*U0**2*beta*r**4*xip**2/gamma - 11.25*U0**2*beta*r**3*xim**2/gamma + 49.5*U0**2*beta*r**3*xim*xip*y/gamma - 54.0*U0**2*beta*r**3*xip**2/gamma + 36.0*U0**2*beta*r**3*xip/gamma + 13.5*U0**2*beta*r**2*x**2*xim**2/gamma + 180.0*U0**2*beta*r**2*x**2*xip**2/gamma + 23.625*U0**2*beta*r**2*xim**2*y**2/gamma + 13.5*U0**2*beta*r**2*xim**2/gamma - 139.5*U0**2*beta*r**2*xim*xip*y/gamma + 45.0*U0**2*beta*r**2*xim*y/gamma + 36.0*U0**2*beta*r**2*xip**2*y**2/gamma + 58.5*U0**2*beta*r**2*xip**2/gamma - 90.0*U0**2*beta*r**2*xip/gamma + 18.0*U0**2*beta*r**2/gamma - 33.75*U0**2*beta*r*x**2*xim**2/gamma + 270.0*U0**2*beta*r*x**2*xim*xip*y/gamma - 405.0*U0**2*beta*r*x**2*xip**2/gamma + 270.0*U0**2*beta*r*x**2*xip/gamma - 60.75*U0**2*beta*r*xim**2*y**2/gamma - 6.75*U0**2*beta*r*xim**2/gamma + 40.5*U0**2*beta*r*xim*xip*y**3/gamma + 137.25*U0**2*beta*r*xim*xip*y/gamma - 103.5*U0**2*beta*r*xim*y/gamma - 81.0*U0**2*beta*r*xip**2*y**2/gamma - 27.0*U0**2*beta*r*xip**2/gamma + 54.0*U0**2*beta*r*xip*y**2/gamma + 72.0*U0**2*beta*r*xip/gamma - 36.0*U0**2*beta*r/gamma + 72.0*U0**2*beta*x**4*xip**2/gamma + 77.625*U0**2*beta*x**2*xim**2*y**2/gamma + 27.0*U0**2*beta*x**2*xim**2/gamma - 508.5*U0**2*beta*x**2*xim*xip*y/gamma + 171.0*U0**2*beta*x**2*xim*y/gamma + 72.0*U0**2*beta*x**2*xip**2*y**2/gamma + 292.5*U0**2*beta*x**2*xip**2/gamma - 450.0*U0**2*beta*x**2*xip/gamma + 90.0*U0**2*beta*x**2/gamma + 10.125*U0**2*beta*xim**2*y**4/gamma + 51.75*U0**2*beta*xim**2*y**2/gamma + 1.125*U0**2*beta*xim**2/gamma - 76.5*U0**2*beta*xim*xip*y**3/gamma - 54.0*U0**2*beta*xim*xip*y/gamma + 27.0*U0**2*beta*xim*y**3/gamma + 72.0*U0**2*beta*xim*y/gamma + 58.5*U0**2*beta*xip**2*y**2/gamma + 4.5*U0**2*beta*xip**2/gamma - 90.0*U0**2*beta*xip*y**2/gamma - 18.0*U0**2*beta*xip/gamma + 18.0*U0**2*beta*y**2/gamma + 18.0*U0**2*beta/gamma + 40.5*U0**2*beta*x**4*xim*xip*y/(gamma*r) - 81.0*U0**2*beta*x**4*xip**2/(gamma*r) + 54.0*U0**2*beta*x**4*xip/(gamma*r) - 101.25*U0**2*beta*x**2*xim**2*y**2/(gamma*r) - 6.75*U0**2*beta*x**2*xim**2/(gamma*r) + 40.5*U0**2*beta*x**2*xim*xip*y**3/(gamma*r) + 252.0*U0**2*beta*x**2*xim*xip*y/(gamma*r) - 198.0*U0**2*beta*x**2*xim*y/(gamma*r) - 81.0*U0**2*beta*x**2*xip**2*y**2/(gamma*r) - 67.5*U0**2*beta*x**2*xip**2/(gamma*r) + 54.0*U0**2*beta*x**2*xip*y**2/(gamma*r) + 180.0*U0**2*beta*x**2*xip/(gamma*r) - 90.0*U0**2*beta*x**2/(gamma*r) - 13.5*U0**2*beta*xim**2*y**4/(gamma*r) - 15.75*U0**2*beta*xim**2*y**2/(gamma*r) + 38.25*U0**2*beta*xim*xip*y**3/(gamma*r) + 6.75*U0**2*beta*xim*xip*y/(gamma*r) - 31.5*U0**2*beta*xim*y**3/(gamma*r) - 13.5*U0**2*beta*xim*y/(gamma*r) - 13.5*U0**2*beta*xip**2*y**2/(gamma*r) + 36.0*U0**2*beta*xip*y**2/(gamma*r) - 18.0*U0**2*beta*y**2/(gamma*r) + 1.125*U0**2*beta*xim**2*y**2/(gamma*r**2) + 13.5*U0**2*beta*x**4*xim**2*y**2/(gamma*r**3) - 38.25*U0**2*beta*x**4*xim*xip*y/(gamma*r**3) + 31.5*U0**2*beta*x**4*xim*y/(gamma*r**3) + 13.5*U0**2*beta*x**4*xip**2/(gamma*r**3) - 36.0*U0**2*beta*x**4*xip/(gamma*r**3) + 18.0*U0**2*beta*x**4/(gamma*r**3) + 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**3) + 29.25*U0**2*beta*x**2*xim**2*y**2/(gamma*r**3) - 38.25*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**3) - 13.5*U0**2*beta*x**2*xim*xip*y/(gamma*r**3) + 31.5*U0**2*beta*x**2*xim*y**3/(gamma*r**3) + 27.0*U0**2*beta*x**2*xim*y/(gamma*r**3) + 13.5*U0**2*beta*x**2*xip**2*y**2/(gamma*r**3) - 36.0*U0**2*beta*x**2*xip*y**2/(gamma*r**3) + 18.0*U0**2*beta*x**2*y**2/(gamma*r**3) + 4.5*U0**2*beta*xim**2*y**4/(gamma*r**3) - 2.25*U0**2*beta*xim*xip*y**3/(gamma*r**3) + 4.5*U0**2*beta*xim*y**3/(gamma*r**3) - 5.625*U0**2*beta*x**2*xim**2*y**2/(gamma*r**4) - 1.125*U0**2*beta*xim**2*y**4/(gamma*r**4) - 13.5*U0**2*beta*x**4*xim**2*y**2/(gamma*r**5) + 6.75*U0**2*beta*x**4*xim*xip*y/(gamma*r**5) - 13.5*U0**2*beta*x**4*xim*y/(gamma*r**5) - 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**5) + 6.75*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**5) - 13.5*U0**2*beta*x**2*xim*y**3/(gamma*r**5) + 4.5*U0**2*beta*x**4*xim**2*y**2/(gamma*r**6) + 4. ...
#     L_xd_x[0,0] = 3.0*U0*beta*r**2*xip + 2.25*U0*beta*r*xim*y - 4.5*U0*beta*r*xip + 3.0*U0*beta*r + 6.0*U0*beta*x**2*xip - 3.0*U0*beta*xim*y + 1.5*U0*beta*xip - 3.0*U0*beta + 2.25*U0*beta*x**2*xim*y/r - 4.5*U0*beta*x**2*xip/r + 3.0*U0*beta*x**2/r + 0.75*U0*beta*xim*y/r - 0.75*U0*beta*x**2*xim*y/r**3 - 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r + 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 - 0.5*beta*eta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[0,0] = 0.5*beta*gamma
#     L_x_x[0,1] = 49.5*U0**2*beta*r**3*x*xim*xip/gamma + 60.75*U0**2*beta*r**2*x*xim**2*y/gamma - 139.5*U0**2*beta*r**2*x*xim*xip/gamma + 45.0*U0**2*beta*r**2*x*xim/gamma + 144.0*U0**2*beta*r**2*x*xip**2*y/gamma + 40.5*U0**2*beta*r*x**3*xim*xip/gamma - 155.25*U0**2*beta*r*x*xim**2*y/gamma + 270.0*U0**2*beta*r*x*xim*xip*y**2/gamma + 137.25*U0**2*beta*r*x*xim*xip/gamma - 103.5*U0**2*beta*r*x*xim/gamma - 324.0*U0**2*beta*r*x*xip**2*y/gamma + 216.0*U0**2*beta*r*x*xip*y/gamma + 20.25*U0**2*beta*x**3*xim**2*y/gamma - 76.5*U0**2*beta*x**3*xim*xip/gamma + 27.0*U0**2*beta*x**3*xim/gamma + 72.0*U0**2*beta*x**3*xip**2*y/gamma + 87.75*U0**2*beta*x*xim**2*y**3/gamma + 130.5*U0**2*beta*x*xim**2*y/gamma - 508.5*U0**2*beta*x*xim*xip*y**2/gamma - 54.0*U0**2*beta*x*xim*xip/gamma + 171.0*U0**2*beta*x*xim*y**2/gamma + 72.0*U0**2*beta*x*xim/gamma + 72.0*U0**2*beta*x*xip**2*y**3/gamma + 234.0*U0**2*beta*x*xip**2*y/gamma - 360.0*U0**2*beta*x*xip*y/gamma + 72.0*U0**2*beta*x*y/gamma - 27.0*U0**2*beta*x**3*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x**3*xim*xip*y**2/(gamma*r) + 38.25*U0**2*beta*x**3*xim*xip/(gamma*r) - 31.5*U0**2*beta*x**3*xim/(gamma*r) - 81.0*U0**2*beta*x**3*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x**3*xip*y/(gamma*r) - 114.75*U0**2*beta*x*xim**2*y**3/(gamma*r) - 38.25*U0**2*beta*x*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x*xim*xip*y**4/(gamma*r) + 252.0*U0**2*beta*x*xim*xip*y**2/(gamma*r) + 6.75*U0**2*beta*x*xim*xip/(gamma*r) - 198.0*U0**2*beta*x*xim*y**2/(gamma*r) - 13.5*U0**2*beta*x*xim/(gamma*r) - 81.0*U0**2*beta*x*xip**2*y**3/(gamma*r) - 54.0*U0**2*beta*x*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x*xip*y**3/(gamma*r) + 144.0*U0**2*beta*x*xip*y/(gamma*r) - 72.0*U0**2*beta*x*y/(gamma*r) + 2.25*U0**2*beta*x*xim**2*y/(gamma*r**2) + 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**3) + 9.0*U0**2*beta*x**3*xim**2*y/(gamma*r**3) - 38.25*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim*xip/(gamma*r**3) + 31.5*U0**2*beta*x**3*xim*y**2/(gamma*r**3) + 4.5*U0**2*beta*x**3*xim/(gamma*r**3) + 13.5*U0**2*beta*x**3*xip**2*y/(gamma*r**3) - 36.0*U0**2*beta*x**3*xip*y/(gamma*r**3) + 18.0*U0**2*beta*x**3*y/(gamma*r**3) + 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**3) + 33.75*U0**2*beta*x*xim**2*y**3/(gamma*r**3) - 38.25*U0**2*beta*x*xim*xip*y**4/(gamma*r**3) - 13.5*U0**2*beta*x*xim*xip*y**2/(gamma*r**3) + 31.5*U0**2*beta*x*xim*y**4/(gamma*r**3) + 27.0*U0**2*beta*x*xim*y**2/(gamma*r**3) + 13.5*U0**2*beta*x*xip**2*y**3/(gamma*r**3) - 36.0*U0**2*beta*x*xip*y**3/(gamma*r**3) + 18.0*U0**2*beta*x*y**3/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim**2*y/(gamma*r**4) - 6.75*U0**2*beta*x*xim**2*y**3/(gamma*r**4) - 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**5) + 6.75*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**5) - 13.5*U0**2*beta*x**3*xim*y**2/(gamma*r**5) - 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**5) + 6.75*U0**2*beta*x*xim*xip*y**4/(gamma*r**5) - 13.5*U0**2*beta*x*xim*y**4/(gamma*r**5) + 4.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**6) + 4.5*U0**2*beta*x*xim**2*y**5/(gamma*r**6) - 3.0*U0*beta*eta*r**2*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 1.5*U0*beta*eta*r**2*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*r*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 4.5*U0*beta*eta*r*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 18.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 6.0*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 4.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 10.5*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 1.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) + 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 3.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(- ...
#     L_xd_x[0,1] = 2.25*U0*beta*r*x*xim - 3.0*U0*beta*x*xim + 6.0*U0*beta*x*xip*y + 2.25*U0*beta*x*xim*y**2/r + 0.75*U0*beta*x*xim/r - 4.5*U0*beta*x*xip*y/r + 3.0*U0*beta*x*y/r - 0.75*U0*beta*x*xim*y**2/r**3 - 1.0*beta*eta*theta*y**2*np.exp(-r**2*theta + 2*r*theta - theta)/r + 0.5*beta*eta*np.exp(-r**2*theta + 2*r*theta - theta)/r + 1.0*beta*eta*theta*y**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 - 0.5*beta*eta*y**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[0,1] = 0
#     L_x_x[1,0] = 49.5*U0**2*beta*r**3*x*xim*xip/gamma + 60.75*U0**2*beta*r**2*x*xim**2*y/gamma - 139.5*U0**2*beta*r**2*x*xim*xip/gamma + 45.0*U0**2*beta*r**2*x*xim/gamma + 144.0*U0**2*beta*r**2*x*xip**2*y/gamma + 40.5*U0**2*beta*r*x**3*xim*xip/gamma - 155.25*U0**2*beta*r*x*xim**2*y/gamma + 270.0*U0**2*beta*r*x*xim*xip*y**2/gamma + 137.25*U0**2*beta*r*x*xim*xip/gamma - 103.5*U0**2*beta*r*x*xim/gamma - 324.0*U0**2*beta*r*x*xip**2*y/gamma + 216.0*U0**2*beta*r*x*xip*y/gamma + 20.25*U0**2*beta*x**3*xim**2*y/gamma - 76.5*U0**2*beta*x**3*xim*xip/gamma + 27.0*U0**2*beta*x**3*xim/gamma + 72.0*U0**2*beta*x**3*xip**2*y/gamma + 87.75*U0**2*beta*x*xim**2*y**3/gamma + 130.5*U0**2*beta*x*xim**2*y/gamma - 508.5*U0**2*beta*x*xim*xip*y**2/gamma - 54.0*U0**2*beta*x*xim*xip/gamma + 171.0*U0**2*beta*x*xim*y**2/gamma + 72.0*U0**2*beta*x*xim/gamma + 72.0*U0**2*beta*x*xip**2*y**3/gamma + 234.0*U0**2*beta*x*xip**2*y/gamma - 360.0*U0**2*beta*x*xip*y/gamma + 72.0*U0**2*beta*x*y/gamma - 27.0*U0**2*beta*x**3*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x**3*xim*xip*y**2/(gamma*r) + 38.25*U0**2*beta*x**3*xim*xip/(gamma*r) - 31.5*U0**2*beta*x**3*xim/(gamma*r) - 81.0*U0**2*beta*x**3*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x**3*xip*y/(gamma*r) - 114.75*U0**2*beta*x*xim**2*y**3/(gamma*r) - 38.25*U0**2*beta*x*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x*xim*xip*y**4/(gamma*r) + 252.0*U0**2*beta*x*xim*xip*y**2/(gamma*r) + 6.75*U0**2*beta*x*xim*xip/(gamma*r) - 198.0*U0**2*beta*x*xim*y**2/(gamma*r) - 13.5*U0**2*beta*x*xim/(gamma*r) - 81.0*U0**2*beta*x*xip**2*y**3/(gamma*r) - 54.0*U0**2*beta*x*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x*xip*y**3/(gamma*r) + 144.0*U0**2*beta*x*xip*y/(gamma*r) - 72.0*U0**2*beta*x*y/(gamma*r) + 2.25*U0**2*beta*x*xim**2*y/(gamma*r**2) + 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**3) + 9.0*U0**2*beta*x**3*xim**2*y/(gamma*r**3) - 38.25*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim*xip/(gamma*r**3) + 31.5*U0**2*beta*x**3*xim*y**2/(gamma*r**3) + 4.5*U0**2*beta*x**3*xim/(gamma*r**3) + 13.5*U0**2*beta*x**3*xip**2*y/(gamma*r**3) - 36.0*U0**2*beta*x**3*xip*y/(gamma*r**3) + 18.0*U0**2*beta*x**3*y/(gamma*r**3) + 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**3) + 33.75*U0**2*beta*x*xim**2*y**3/(gamma*r**3) - 38.25*U0**2*beta*x*xim*xip*y**4/(gamma*r**3) - 13.5*U0**2*beta*x*xim*xip*y**2/(gamma*r**3) + 31.5*U0**2*beta*x*xim*y**4/(gamma*r**3) + 27.0*U0**2*beta*x*xim*y**2/(gamma*r**3) + 13.5*U0**2*beta*x*xip**2*y**3/(gamma*r**3) - 36.0*U0**2*beta*x*xip*y**3/(gamma*r**3) + 18.0*U0**2*beta*x*y**3/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim**2*y/(gamma*r**4) - 6.75*U0**2*beta*x*xim**2*y**3/(gamma*r**4) - 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**5) + 6.75*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**5) - 13.5*U0**2*beta*x**3*xim*y**2/(gamma*r**5) - 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**5) + 6.75*U0**2*beta*x*xim*xip*y**4/(gamma*r**5) - 13.5*U0**2*beta*x*xim*y**4/(gamma*r**5) + 4.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**6) + 4.5*U0**2*beta*x*xim**2*y**5/(gamma*r**6) - 3.0*U0*beta*eta*r**2*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 1.5*U0*beta*eta*r**2*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*r*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 4.5*U0*beta*eta*r*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 18.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 6.0*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 4.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 10.5*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 1.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) + 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 3.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(- ...
#     L_xd_x[1,0] = 2.25*U0*beta*r*x*xim - 3.0*U0*beta*x*xim + 6.0*U0*beta*x*xip*y + 2.25*U0*beta*x*xim*y**2/r + 0.75*U0*beta*x*xim/r - 4.5*U0*beta*x*xip*y/r + 3.0*U0*beta*x*y/r - 0.75*U0*beta*x*xim*y**2/r**3 + 1.0*beta*eta*theta*x**2*np.exp(-r**2*theta + 2*r*theta - theta)/r - 0.5*beta*eta*np.exp(-r**2*theta + 2*r*theta - theta)/r - 1.0*beta*eta*theta*x**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 + 0.5*beta*eta*x**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[1,0] = 0
#     L_x_x[1,1] = 10.125*U0**2*beta*r**4*xim**2/gamma + 18.0*U0**2*beta*r**4*xip**2/gamma - 33.75*U0**2*beta*r**3*xim**2/gamma + 148.5*U0**2*beta*r**3*xim*xip*y/gamma - 54.0*U0**2*beta*r**3*xip**2/gamma + 36.0*U0**2*beta*r**3*xip/gamma + 10.125*U0**2*beta*r**2*x**2*xim**2/gamma + 36.0*U0**2*beta*r**2*x**2*xip**2/gamma + 141.75*U0**2*beta*r**2*xim**2*y**2/gamma + 40.5*U0**2*beta*r**2*xim**2/gamma - 418.5*U0**2*beta*r**2*xim*xip*y/gamma + 135.0*U0**2*beta*r**2*xim*y/gamma + 180.0*U0**2*beta*r**2*xip**2*y**2/gamma + 58.5*U0**2*beta*r**2*xip**2/gamma - 90.0*U0**2*beta*r**2*xip/gamma + 18.0*U0**2*beta*r**2/gamma - 27.0*U0**2*beta*r*x**2*xim**2/gamma + 121.5*U0**2*beta*r*x**2*xim*xip*y/gamma - 81.0*U0**2*beta*r*x**2*xip**2/gamma + 54.0*U0**2*beta*r*x**2*xip/gamma - 364.5*U0**2*beta*r*xim**2*y**2/gamma - 20.25*U0**2*beta*r*xim**2/gamma + 351.0*U0**2*beta*r*xim*xip*y**3/gamma + 411.75*U0**2*beta*r*xim*xip*y/gamma - 310.5*U0**2*beta*r*xim*y/gamma - 405.0*U0**2*beta*r*xip**2*y**2/gamma - 27.0*U0**2*beta*r*xip**2/gamma + 270.0*U0**2*beta*r*xip*y**2/gamma + 72.0*U0**2*beta*r*xip/gamma - 36.0*U0**2*beta*r/gamma + 50.625*U0**2*beta*x**2*xim**2*y**2/gamma + 24.75*U0**2*beta*x**2*xim**2/gamma - 229.5*U0**2*beta*x**2*xim*xip*y/gamma + 81.0*U0**2*beta*x**2*xim*y/gamma + 72.0*U0**2*beta*x**2*xip**2*y**2/gamma + 58.5*U0**2*beta*x**2*xip**2/gamma - 90.0*U0**2*beta*x**2*xip/gamma + 18.0*U0**2*beta*x**2/gamma + 118.125*U0**2*beta*xim**2*y**4/gamma + 310.5*U0**2*beta*xim**2*y**2/gamma + 3.375*U0**2*beta*xim**2/gamma - 661.5*U0**2*beta*xim*xip*y**3/gamma - 162.0*U0**2*beta*xim*xip*y/gamma + 225.0*U0**2*beta*xim*y**3/gamma + 216.0*U0**2*beta*xim*y/gamma + 72.0*U0**2*beta*xip**2*y**4/gamma + 292.5*U0**2*beta*xip**2*y**2/gamma + 4.5*U0**2*beta*xip**2/gamma - 450.0*U0**2*beta*xip*y**2/gamma - 18.0*U0**2*beta*xip/gamma + 90.0*U0**2*beta*y**2/gamma + 18.0*U0**2*beta/gamma - 67.5*U0**2*beta*x**2*xim**2*y**2/(gamma*r) - 9.0*U0**2*beta*x**2*xim**2/(gamma*r) + 40.5*U0**2*beta*x**2*xim*xip*y**3/(gamma*r) + 114.75*U0**2*beta*x**2*xim*xip*y/(gamma*r) - 94.5*U0**2*beta*x**2*xim*y/(gamma*r) - 81.0*U0**2*beta*x**2*xip**2*y**2/(gamma*r) - 13.5*U0**2*beta*x**2*xip**2/(gamma*r) + 54.0*U0**2*beta*x**2*xip*y**2/(gamma*r) + 36.0*U0**2*beta*x**2*xip/(gamma*r) - 18.0*U0**2*beta*x**2/(gamma*r) - 155.25*U0**2*beta*xim**2*y**4/(gamma*r) - 94.5*U0**2*beta*xim**2*y**2/(gamma*r) + 40.5*U0**2*beta*xim*xip*y**5/(gamma*r) + 328.5*U0**2*beta*xim*xip*y**3/(gamma*r) + 20.25*U0**2*beta*xim*xip*y/(gamma*r) - 261.0*U0**2*beta*xim*y**3/(gamma*r) - 40.5*U0**2*beta*xim*y/(gamma*r) - 81.0*U0**2*beta*xip**2*y**4/(gamma*r) - 67.5*U0**2*beta*xip**2*y**2/(gamma*r) + 54.0*U0**2*beta*xip*y**4/(gamma*r) + 180.0*U0**2*beta*xip*y**2/(gamma*r) - 90.0*U0**2*beta*y**2/(gamma*r) + 1.125*U0**2*beta*x**2*xim**2/(gamma*r**2) + 6.75*U0**2*beta*xim**2*y**2/(gamma*r**2) + 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**3) + 22.5*U0**2*beta*x**2*xim**2*y**2/(gamma*r**3) - 38.25*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**3) - 6.75*U0**2*beta*x**2*xim*xip*y/(gamma*r**3) + 31.5*U0**2*beta*x**2*xim*y**3/(gamma*r**3) + 13.5*U0**2*beta*x**2*xim*y/(gamma*r**3) + 13.5*U0**2*beta*x**2*xip**2*y**2/(gamma*r**3) - 36.0*U0**2*beta*x**2*xip*y**2/(gamma*r**3) + 18.0*U0**2*beta*x**2*y**2/(gamma*r**3) + 13.5*U0**2*beta*xim**2*y**6/(gamma*r**3) + 47.25*U0**2*beta*xim**2*y**4/(gamma*r**3) - 38.25*U0**2*beta*xim*xip*y**5/(gamma*r**3) - 18.0*U0**2*beta*xim*xip*y**3/(gamma*r**3) + 31.5*U0**2*beta*xim*y**5/(gamma*r**3) + 36.0*U0**2*beta*xim*y**3/(gamma*r**3) + 13.5*U0**2*beta*xip**2*y**4/(gamma*r**3) - 36.0*U0**2*beta*xip*y**4/(gamma*r**3) + 18.0*U0**2*beta*y**4/(gamma*r**3) - 5.625*U0**2*beta*x**2*xim**2*y**2/(gamma*r**4) - 10.125*U0**2*beta*xim**2*y**4/(gamma*r**4) - 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**5) + 6.75*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**5) - 13.5*U0**2*beta*x**2*xim*y**3/(gamma*r**5) - 13.5*U0**2*beta*xim**2*y**6/(gamma*r**5) + 6.75*U0**2*beta*xim*xip*y**5/(gamma*r**5) - 13.5*U0**2*beta*xim*y**5/(gamma*r**5) + 4.5*U0**2*be ...
#     L_xd_x[1,1] = 3.0*U0*beta*r**2*xip + 6.75*U0*beta*r*xim*y - 4.5*U0*beta*r*xip + 3.0*U0*beta*r - 9.0*U0*beta*xim*y + 6.0*U0*beta*xip*y**2 + 1.5*U0*beta*xip - 3.0*U0*beta + 2.25*U0*beta*xim*y**3/r + 2.25*U0*beta*xim*y/r - 4.5*U0*beta*xip*y**2/r + 3.0*U0*beta*y**2/r - 0.75*U0*beta*xim*y**3/r**3 + 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r - 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 + 0.5*beta*eta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[1,1] = 0.5*beta*gamma
#     return L_x_x, L_xd_x, L_xd_xd
# def hessL_FW(path, dpath):
#     x, y = path[:, 0], path[:, 1]
#     xdot, ydot = dpath[:, 0], dpath[:, 1]
#     r = np.sqrt(x**2 + y**2)
#     L_x_x = np.zeros((2, 2, len(path)))
#     L_xd_x = np.zeros((2, 2, len(path)))
#     L_xd_xd = np.zeros((2, 2, len(path)))
#     L_x_x[0,0] = 3.375*U0**2*beta*r**4*xim**2/gamma + 18.0*U0**2*beta*r**4*xip**2/gamma - 11.25*U0**2*beta*r**3*xim**2/gamma + 49.5*U0**2*beta*r**3*xim*xip*y/gamma - 54.0*U0**2*beta*r**3*xip**2/gamma + 36.0*U0**2*beta*r**3*xip/gamma + 13.5*U0**2*beta*r**2*x**2*xim**2/gamma + 180.0*U0**2*beta*r**2*x**2*xip**2/gamma + 23.625*U0**2*beta*r**2*xim**2*y**2/gamma + 13.5*U0**2*beta*r**2*xim**2/gamma - 139.5*U0**2*beta*r**2*xim*xip*y/gamma + 45.0*U0**2*beta*r**2*xim*y/gamma + 36.0*U0**2*beta*r**2*xip**2*y**2/gamma + 58.5*U0**2*beta*r**2*xip**2/gamma - 90.0*U0**2*beta*r**2*xip/gamma + 18.0*U0**2*beta*r**2/gamma - 33.75*U0**2*beta*r*x**2*xim**2/gamma + 270.0*U0**2*beta*r*x**2*xim*xip*y/gamma - 405.0*U0**2*beta*r*x**2*xip**2/gamma + 270.0*U0**2*beta*r*x**2*xip/gamma - 60.75*U0**2*beta*r*xim**2*y**2/gamma - 6.75*U0**2*beta*r*xim**2/gamma + 40.5*U0**2*beta*r*xim*xip*y**3/gamma + 137.25*U0**2*beta*r*xim*xip*y/gamma - 103.5*U0**2*beta*r*xim*y/gamma - 81.0*U0**2*beta*r*xip**2*y**2/gamma - 27.0*U0**2*beta*r*xip**2/gamma + 54.0*U0**2*beta*r*xip*y**2/gamma + 72.0*U0**2*beta*r*xip/gamma - 36.0*U0**2*beta*r/gamma + 72.0*U0**2*beta*x**4*xip**2/gamma + 77.625*U0**2*beta*x**2*xim**2*y**2/gamma + 27.0*U0**2*beta*x**2*xim**2/gamma - 508.5*U0**2*beta*x**2*xim*xip*y/gamma + 171.0*U0**2*beta*x**2*xim*y/gamma + 72.0*U0**2*beta*x**2*xip**2*y**2/gamma + 292.5*U0**2*beta*x**2*xip**2/gamma - 450.0*U0**2*beta*x**2*xip/gamma + 90.0*U0**2*beta*x**2/gamma + 10.125*U0**2*beta*xim**2*y**4/gamma + 51.75*U0**2*beta*xim**2*y**2/gamma + 1.125*U0**2*beta*xim**2/gamma - 76.5*U0**2*beta*xim*xip*y**3/gamma - 54.0*U0**2*beta*xim*xip*y/gamma + 27.0*U0**2*beta*xim*y**3/gamma + 72.0*U0**2*beta*xim*y/gamma + 58.5*U0**2*beta*xip**2*y**2/gamma + 4.5*U0**2*beta*xip**2/gamma - 90.0*U0**2*beta*xip*y**2/gamma - 18.0*U0**2*beta*xip/gamma + 18.0*U0**2*beta*y**2/gamma + 18.0*U0**2*beta/gamma + 40.5*U0**2*beta*x**4*xim*xip*y/(gamma*r) - 81.0*U0**2*beta*x**4*xip**2/(gamma*r) + 54.0*U0**2*beta*x**4*xip/(gamma*r) - 101.25*U0**2*beta*x**2*xim**2*y**2/(gamma*r) - 6.75*U0**2*beta*x**2*xim**2/(gamma*r) + 40.5*U0**2*beta*x**2*xim*xip*y**3/(gamma*r) + 252.0*U0**2*beta*x**2*xim*xip*y/(gamma*r) - 198.0*U0**2*beta*x**2*xim*y/(gamma*r) - 81.0*U0**2*beta*x**2*xip**2*y**2/(gamma*r) - 67.5*U0**2*beta*x**2*xip**2/(gamma*r) + 54.0*U0**2*beta*x**2*xip*y**2/(gamma*r) + 180.0*U0**2*beta*x**2*xip/(gamma*r) - 90.0*U0**2*beta*x**2/(gamma*r) - 13.5*U0**2*beta*xim**2*y**4/(gamma*r) - 15.75*U0**2*beta*xim**2*y**2/(gamma*r) + 38.25*U0**2*beta*xim*xip*y**3/(gamma*r) + 6.75*U0**2*beta*xim*xip*y/(gamma*r) - 31.5*U0**2*beta*xim*y**3/(gamma*r) - 13.5*U0**2*beta*xim*y/(gamma*r) - 13.5*U0**2*beta*xip**2*y**2/(gamma*r) + 36.0*U0**2*beta*xip*y**2/(gamma*r) - 18.0*U0**2*beta*y**2/(gamma*r) + 1.125*U0**2*beta*xim**2*y**2/(gamma*r**2) + 13.5*U0**2*beta*x**4*xim**2*y**2/(gamma*r**3) - 38.25*U0**2*beta*x**4*xim*xip*y/(gamma*r**3) + 31.5*U0**2*beta*x**4*xim*y/(gamma*r**3) + 13.5*U0**2*beta*x**4*xip**2/(gamma*r**3) - 36.0*U0**2*beta*x**4*xip/(gamma*r**3) + 18.0*U0**2*beta*x**4/(gamma*r**3) + 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**3) + 29.25*U0**2*beta*x**2*xim**2*y**2/(gamma*r**3) - 38.25*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**3) - 13.5*U0**2*beta*x**2*xim*xip*y/(gamma*r**3) + 31.5*U0**2*beta*x**2*xim*y**3/(gamma*r**3) + 27.0*U0**2*beta*x**2*xim*y/(gamma*r**3) + 13.5*U0**2*beta*x**2*xip**2*y**2/(gamma*r**3) - 36.0*U0**2*beta*x**2*xip*y**2/(gamma*r**3) + 18.0*U0**2*beta*x**2*y**2/(gamma*r**3) + 4.5*U0**2*beta*xim**2*y**4/(gamma*r**3) - 2.25*U0**2*beta*xim*xip*y**3/(gamma*r**3) + 4.5*U0**2*beta*xim*y**3/(gamma*r**3) - 5.625*U0**2*beta*x**2*xim**2*y**2/(gamma*r**4) - 1.125*U0**2*beta*xim**2*y**4/(gamma*r**4) - 13.5*U0**2*beta*x**4*xim**2*y**2/(gamma*r**5) + 6.75*U0**2*beta*x**4*xim*xip*y/(gamma*r**5) - 13.5*U0**2*beta*x**4*xim*y/(gamma*r**5) - 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**5) + 6.75*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**5) - 13.5*U0**2*beta*x**2*xim*y**3/(gamma*r**5) + 4.5*U0**2*beta*x**4*xim**2*y**2/(gamma*r**6) + 4. ...
#     L_xd_x[0,0] = 3.0*U0*beta*r**2*xip + 2.25*U0*beta*r*xim*y - 4.5*U0*beta*r*xip + 3.0*U0*beta*r + 6.0*U0*beta*x**2*xip - 3.0*U0*beta*xim*y + 1.5*U0*beta*xip - 3.0*U0*beta + 2.25*U0*beta*x**2*xim*y/r - 4.5*U0*beta*x**2*xip/r + 3.0*U0*beta*x**2/r + 0.75*U0*beta*xim*y/r - 0.75*U0*beta*x**2*xim*y/r**3 - 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r + 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 - 0.5*beta*eta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[0,0] = 0.5*beta*gamma
#     L_x_x[0,1] = 49.5*U0**2*beta*r**3*x*xim*xip/gamma + 60.75*U0**2*beta*r**2*x*xim**2*y/gamma - 139.5*U0**2*beta*r**2*x*xim*xip/gamma + 45.0*U0**2*beta*r**2*x*xim/gamma + 144.0*U0**2*beta*r**2*x*xip**2*y/gamma + 40.5*U0**2*beta*r*x**3*xim*xip/gamma - 155.25*U0**2*beta*r*x*xim**2*y/gamma + 270.0*U0**2*beta*r*x*xim*xip*y**2/gamma + 137.25*U0**2*beta*r*x*xim*xip/gamma - 103.5*U0**2*beta*r*x*xim/gamma - 324.0*U0**2*beta*r*x*xip**2*y/gamma + 216.0*U0**2*beta*r*x*xip*y/gamma + 20.25*U0**2*beta*x**3*xim**2*y/gamma - 76.5*U0**2*beta*x**3*xim*xip/gamma + 27.0*U0**2*beta*x**3*xim/gamma + 72.0*U0**2*beta*x**3*xip**2*y/gamma + 87.75*U0**2*beta*x*xim**2*y**3/gamma + 130.5*U0**2*beta*x*xim**2*y/gamma - 508.5*U0**2*beta*x*xim*xip*y**2/gamma - 54.0*U0**2*beta*x*xim*xip/gamma + 171.0*U0**2*beta*x*xim*y**2/gamma + 72.0*U0**2*beta*x*xim/gamma + 72.0*U0**2*beta*x*xip**2*y**3/gamma + 234.0*U0**2*beta*x*xip**2*y/gamma - 360.0*U0**2*beta*x*xip*y/gamma + 72.0*U0**2*beta*x*y/gamma - 27.0*U0**2*beta*x**3*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x**3*xim*xip*y**2/(gamma*r) + 38.25*U0**2*beta*x**3*xim*xip/(gamma*r) - 31.5*U0**2*beta*x**3*xim/(gamma*r) - 81.0*U0**2*beta*x**3*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x**3*xip*y/(gamma*r) - 114.75*U0**2*beta*x*xim**2*y**3/(gamma*r) - 38.25*U0**2*beta*x*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x*xim*xip*y**4/(gamma*r) + 252.0*U0**2*beta*x*xim*xip*y**2/(gamma*r) + 6.75*U0**2*beta*x*xim*xip/(gamma*r) - 198.0*U0**2*beta*x*xim*y**2/(gamma*r) - 13.5*U0**2*beta*x*xim/(gamma*r) - 81.0*U0**2*beta*x*xip**2*y**3/(gamma*r) - 54.0*U0**2*beta*x*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x*xip*y**3/(gamma*r) + 144.0*U0**2*beta*x*xip*y/(gamma*r) - 72.0*U0**2*beta*x*y/(gamma*r) + 2.25*U0**2*beta*x*xim**2*y/(gamma*r**2) + 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**3) + 9.0*U0**2*beta*x**3*xim**2*y/(gamma*r**3) - 38.25*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim*xip/(gamma*r**3) + 31.5*U0**2*beta*x**3*xim*y**2/(gamma*r**3) + 4.5*U0**2*beta*x**3*xim/(gamma*r**3) + 13.5*U0**2*beta*x**3*xip**2*y/(gamma*r**3) - 36.0*U0**2*beta*x**3*xip*y/(gamma*r**3) + 18.0*U0**2*beta*x**3*y/(gamma*r**3) + 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**3) + 33.75*U0**2*beta*x*xim**2*y**3/(gamma*r**3) - 38.25*U0**2*beta*x*xim*xip*y**4/(gamma*r**3) - 13.5*U0**2*beta*x*xim*xip*y**2/(gamma*r**3) + 31.5*U0**2*beta*x*xim*y**4/(gamma*r**3) + 27.0*U0**2*beta*x*xim*y**2/(gamma*r**3) + 13.5*U0**2*beta*x*xip**2*y**3/(gamma*r**3) - 36.0*U0**2*beta*x*xip*y**3/(gamma*r**3) + 18.0*U0**2*beta*x*y**3/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim**2*y/(gamma*r**4) - 6.75*U0**2*beta*x*xim**2*y**3/(gamma*r**4) - 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**5) + 6.75*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**5) - 13.5*U0**2*beta*x**3*xim*y**2/(gamma*r**5) - 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**5) + 6.75*U0**2*beta*x*xim*xip*y**4/(gamma*r**5) - 13.5*U0**2*beta*x*xim*y**4/(gamma*r**5) + 4.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**6) + 4.5*U0**2*beta*x*xim**2*y**5/(gamma*r**6) - 3.0*U0*beta*eta*r**2*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 1.5*U0*beta*eta*r**2*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*r*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 4.5*U0*beta*eta*r*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 18.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 6.0*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 4.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 10.5*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 1.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) + 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 3.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(- ...
#     L_xd_x[0,1] = 2.25*U0*beta*r*x*xim - 3.0*U0*beta*x*xim + 6.0*U0*beta*x*xip*y + 2.25*U0*beta*x*xim*y**2/r + 0.75*U0*beta*x*xim/r - 4.5*U0*beta*x*xip*y/r + 3.0*U0*beta*x*y/r - 0.75*U0*beta*x*xim*y**2/r**3 - 1.0*beta*eta*theta*y**2*np.exp(-r**2*theta + 2*r*theta - theta)/r + 0.5*beta*eta*np.exp(-r**2*theta + 2*r*theta - theta)/r + 1.0*beta*eta*theta*y**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 - 0.5*beta*eta*y**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[0,1] = 0
#     L_x_x[1,0] = 49.5*U0**2*beta*r**3*x*xim*xip/gamma + 60.75*U0**2*beta*r**2*x*xim**2*y/gamma - 139.5*U0**2*beta*r**2*x*xim*xip/gamma + 45.0*U0**2*beta*r**2*x*xim/gamma + 144.0*U0**2*beta*r**2*x*xip**2*y/gamma + 40.5*U0**2*beta*r*x**3*xim*xip/gamma - 155.25*U0**2*beta*r*x*xim**2*y/gamma + 270.0*U0**2*beta*r*x*xim*xip*y**2/gamma + 137.25*U0**2*beta*r*x*xim*xip/gamma - 103.5*U0**2*beta*r*x*xim/gamma - 324.0*U0**2*beta*r*x*xip**2*y/gamma + 216.0*U0**2*beta*r*x*xip*y/gamma + 20.25*U0**2*beta*x**3*xim**2*y/gamma - 76.5*U0**2*beta*x**3*xim*xip/gamma + 27.0*U0**2*beta*x**3*xim/gamma + 72.0*U0**2*beta*x**3*xip**2*y/gamma + 87.75*U0**2*beta*x*xim**2*y**3/gamma + 130.5*U0**2*beta*x*xim**2*y/gamma - 508.5*U0**2*beta*x*xim*xip*y**2/gamma - 54.0*U0**2*beta*x*xim*xip/gamma + 171.0*U0**2*beta*x*xim*y**2/gamma + 72.0*U0**2*beta*x*xim/gamma + 72.0*U0**2*beta*x*xip**2*y**3/gamma + 234.0*U0**2*beta*x*xip**2*y/gamma - 360.0*U0**2*beta*x*xip*y/gamma + 72.0*U0**2*beta*x*y/gamma - 27.0*U0**2*beta*x**3*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x**3*xim*xip*y**2/(gamma*r) + 38.25*U0**2*beta*x**3*xim*xip/(gamma*r) - 31.5*U0**2*beta*x**3*xim/(gamma*r) - 81.0*U0**2*beta*x**3*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x**3*xip*y/(gamma*r) - 114.75*U0**2*beta*x*xim**2*y**3/(gamma*r) - 38.25*U0**2*beta*x*xim**2*y/(gamma*r) + 40.5*U0**2*beta*x*xim*xip*y**4/(gamma*r) + 252.0*U0**2*beta*x*xim*xip*y**2/(gamma*r) + 6.75*U0**2*beta*x*xim*xip/(gamma*r) - 198.0*U0**2*beta*x*xim*y**2/(gamma*r) - 13.5*U0**2*beta*x*xim/(gamma*r) - 81.0*U0**2*beta*x*xip**2*y**3/(gamma*r) - 54.0*U0**2*beta*x*xip**2*y/(gamma*r) + 54.0*U0**2*beta*x*xip*y**3/(gamma*r) + 144.0*U0**2*beta*x*xip*y/(gamma*r) - 72.0*U0**2*beta*x*y/(gamma*r) + 2.25*U0**2*beta*x*xim**2*y/(gamma*r**2) + 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**3) + 9.0*U0**2*beta*x**3*xim**2*y/(gamma*r**3) - 38.25*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim*xip/(gamma*r**3) + 31.5*U0**2*beta*x**3*xim*y**2/(gamma*r**3) + 4.5*U0**2*beta*x**3*xim/(gamma*r**3) + 13.5*U0**2*beta*x**3*xip**2*y/(gamma*r**3) - 36.0*U0**2*beta*x**3*xip*y/(gamma*r**3) + 18.0*U0**2*beta*x**3*y/(gamma*r**3) + 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**3) + 33.75*U0**2*beta*x*xim**2*y**3/(gamma*r**3) - 38.25*U0**2*beta*x*xim*xip*y**4/(gamma*r**3) - 13.5*U0**2*beta*x*xim*xip*y**2/(gamma*r**3) + 31.5*U0**2*beta*x*xim*y**4/(gamma*r**3) + 27.0*U0**2*beta*x*xim*y**2/(gamma*r**3) + 13.5*U0**2*beta*x*xip**2*y**3/(gamma*r**3) - 36.0*U0**2*beta*x*xip*y**3/(gamma*r**3) + 18.0*U0**2*beta*x*y**3/(gamma*r**3) - 2.25*U0**2*beta*x**3*xim**2*y/(gamma*r**4) - 6.75*U0**2*beta*x*xim**2*y**3/(gamma*r**4) - 13.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**5) + 6.75*U0**2*beta*x**3*xim*xip*y**2/(gamma*r**5) - 13.5*U0**2*beta*x**3*xim*y**2/(gamma*r**5) - 13.5*U0**2*beta*x*xim**2*y**5/(gamma*r**5) + 6.75*U0**2*beta*x*xim*xip*y**4/(gamma*r**5) - 13.5*U0**2*beta*x*xim*y**4/(gamma*r**5) + 4.5*U0**2*beta*x**3*xim**2*y**3/(gamma*r**6) + 4.5*U0**2*beta*x*xim**2*y**5/(gamma*r**6) - 3.0*U0*beta*eta*r**2*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 1.5*U0*beta*eta*r**2*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*r*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 4.5*U0*beta*eta*r*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 18.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 6.0*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 4.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma - 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/gamma + 12.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 10.5*U0*beta*eta*theta*x**2*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 1.5*U0*beta*eta*theta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) + 1.5*U0*beta*eta*xim*y*np.exp(-r**2*theta + 2*r*theta - theta)/(gamma*r) - 3.0*U0*beta*eta*theta**2*x**2*xim*y*np.exp(- ...
#     L_xd_x[1,0] = 2.25*U0*beta*r*x*xim - 3.0*U0*beta*x*xim + 6.0*U0*beta*x*xip*y + 2.25*U0*beta*x*xim*y**2/r + 0.75*U0*beta*x*xim/r - 4.5*U0*beta*x*xip*y/r + 3.0*U0*beta*x*y/r - 0.75*U0*beta*x*xim*y**2/r**3 + 1.0*beta*eta*theta*x**2*np.exp(-r**2*theta + 2*r*theta - theta)/r - 0.5*beta*eta*np.exp(-r**2*theta + 2*r*theta - theta)/r - 1.0*beta*eta*theta*x**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 + 0.5*beta*eta*x**2*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[1,0] = 0
#     L_x_x[1,1] = 10.125*U0**2*beta*r**4*xim**2/gamma + 18.0*U0**2*beta*r**4*xip**2/gamma - 33.75*U0**2*beta*r**3*xim**2/gamma + 148.5*U0**2*beta*r**3*xim*xip*y/gamma - 54.0*U0**2*beta*r**3*xip**2/gamma + 36.0*U0**2*beta*r**3*xip/gamma + 10.125*U0**2*beta*r**2*x**2*xim**2/gamma + 36.0*U0**2*beta*r**2*x**2*xip**2/gamma + 141.75*U0**2*beta*r**2*xim**2*y**2/gamma + 40.5*U0**2*beta*r**2*xim**2/gamma - 418.5*U0**2*beta*r**2*xim*xip*y/gamma + 135.0*U0**2*beta*r**2*xim*y/gamma + 180.0*U0**2*beta*r**2*xip**2*y**2/gamma + 58.5*U0**2*beta*r**2*xip**2/gamma - 90.0*U0**2*beta*r**2*xip/gamma + 18.0*U0**2*beta*r**2/gamma - 27.0*U0**2*beta*r*x**2*xim**2/gamma + 121.5*U0**2*beta*r*x**2*xim*xip*y/gamma - 81.0*U0**2*beta*r*x**2*xip**2/gamma + 54.0*U0**2*beta*r*x**2*xip/gamma - 364.5*U0**2*beta*r*xim**2*y**2/gamma - 20.25*U0**2*beta*r*xim**2/gamma + 351.0*U0**2*beta*r*xim*xip*y**3/gamma + 411.75*U0**2*beta*r*xim*xip*y/gamma - 310.5*U0**2*beta*r*xim*y/gamma - 405.0*U0**2*beta*r*xip**2*y**2/gamma - 27.0*U0**2*beta*r*xip**2/gamma + 270.0*U0**2*beta*r*xip*y**2/gamma + 72.0*U0**2*beta*r*xip/gamma - 36.0*U0**2*beta*r/gamma + 50.625*U0**2*beta*x**2*xim**2*y**2/gamma + 24.75*U0**2*beta*x**2*xim**2/gamma - 229.5*U0**2*beta*x**2*xim*xip*y/gamma + 81.0*U0**2*beta*x**2*xim*y/gamma + 72.0*U0**2*beta*x**2*xip**2*y**2/gamma + 58.5*U0**2*beta*x**2*xip**2/gamma - 90.0*U0**2*beta*x**2*xip/gamma + 18.0*U0**2*beta*x**2/gamma + 118.125*U0**2*beta*xim**2*y**4/gamma + 310.5*U0**2*beta*xim**2*y**2/gamma + 3.375*U0**2*beta*xim**2/gamma - 661.5*U0**2*beta*xim*xip*y**3/gamma - 162.0*U0**2*beta*xim*xip*y/gamma + 225.0*U0**2*beta*xim*y**3/gamma + 216.0*U0**2*beta*xim*y/gamma + 72.0*U0**2*beta*xip**2*y**4/gamma + 292.5*U0**2*beta*xip**2*y**2/gamma + 4.5*U0**2*beta*xip**2/gamma - 450.0*U0**2*beta*xip*y**2/gamma - 18.0*U0**2*beta*xip/gamma + 90.0*U0**2*beta*y**2/gamma + 18.0*U0**2*beta/gamma - 67.5*U0**2*beta*x**2*xim**2*y**2/(gamma*r) - 9.0*U0**2*beta*x**2*xim**2/(gamma*r) + 40.5*U0**2*beta*x**2*xim*xip*y**3/(gamma*r) + 114.75*U0**2*beta*x**2*xim*xip*y/(gamma*r) - 94.5*U0**2*beta*x**2*xim*y/(gamma*r) - 81.0*U0**2*beta*x**2*xip**2*y**2/(gamma*r) - 13.5*U0**2*beta*x**2*xip**2/(gamma*r) + 54.0*U0**2*beta*x**2*xip*y**2/(gamma*r) + 36.0*U0**2*beta*x**2*xip/(gamma*r) - 18.0*U0**2*beta*x**2/(gamma*r) - 155.25*U0**2*beta*xim**2*y**4/(gamma*r) - 94.5*U0**2*beta*xim**2*y**2/(gamma*r) + 40.5*U0**2*beta*xim*xip*y**5/(gamma*r) + 328.5*U0**2*beta*xim*xip*y**3/(gamma*r) + 20.25*U0**2*beta*xim*xip*y/(gamma*r) - 261.0*U0**2*beta*xim*y**3/(gamma*r) - 40.5*U0**2*beta*xim*y/(gamma*r) - 81.0*U0**2*beta*xip**2*y**4/(gamma*r) - 67.5*U0**2*beta*xip**2*y**2/(gamma*r) + 54.0*U0**2*beta*xip*y**4/(gamma*r) + 180.0*U0**2*beta*xip*y**2/(gamma*r) - 90.0*U0**2*beta*y**2/(gamma*r) + 1.125*U0**2*beta*x**2*xim**2/(gamma*r**2) + 6.75*U0**2*beta*xim**2*y**2/(gamma*r**2) + 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**3) + 22.5*U0**2*beta*x**2*xim**2*y**2/(gamma*r**3) - 38.25*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**3) - 6.75*U0**2*beta*x**2*xim*xip*y/(gamma*r**3) + 31.5*U0**2*beta*x**2*xim*y**3/(gamma*r**3) + 13.5*U0**2*beta*x**2*xim*y/(gamma*r**3) + 13.5*U0**2*beta*x**2*xip**2*y**2/(gamma*r**3) - 36.0*U0**2*beta*x**2*xip*y**2/(gamma*r**3) + 18.0*U0**2*beta*x**2*y**2/(gamma*r**3) + 13.5*U0**2*beta*xim**2*y**6/(gamma*r**3) + 47.25*U0**2*beta*xim**2*y**4/(gamma*r**3) - 38.25*U0**2*beta*xim*xip*y**5/(gamma*r**3) - 18.0*U0**2*beta*xim*xip*y**3/(gamma*r**3) + 31.5*U0**2*beta*xim*y**5/(gamma*r**3) + 36.0*U0**2*beta*xim*y**3/(gamma*r**3) + 13.5*U0**2*beta*xip**2*y**4/(gamma*r**3) - 36.0*U0**2*beta*xip*y**4/(gamma*r**3) + 18.0*U0**2*beta*y**4/(gamma*r**3) - 5.625*U0**2*beta*x**2*xim**2*y**2/(gamma*r**4) - 10.125*U0**2*beta*xim**2*y**4/(gamma*r**4) - 13.5*U0**2*beta*x**2*xim**2*y**4/(gamma*r**5) + 6.75*U0**2*beta*x**2*xim*xip*y**3/(gamma*r**5) - 13.5*U0**2*beta*x**2*xim*y**3/(gamma*r**5) - 13.5*U0**2*beta*xim**2*y**6/(gamma*r**5) + 6.75*U0**2*beta*xim*xip*y**5/(gamma*r**5) - 13.5*U0**2*beta*xim*y**5/(gamma*r**5) + 4.5*U0**2*be ...
#     L_xd_x[1,1] = 3.0*U0*beta*r**2*xip + 6.75*U0*beta*r*xim*y - 4.5*U0*beta*r*xip + 3.0*U0*beta*r - 9.0*U0*beta*xim*y + 6.0*U0*beta*xip*y**2 + 1.5*U0*beta*xip - 3.0*U0*beta + 2.25*U0*beta*xim*y**3/r + 2.25*U0*beta*xim*y/r - 4.5*U0*beta*xip*y**2/r + 3.0*U0*beta*y**2/r - 0.75*U0*beta*xim*y**3/r**3 + 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r - 1.0*beta*eta*theta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**2 + 0.5*beta*eta*x*y*np.exp(-r**2*theta + 2*r*theta - theta)/r**3
#     L_xd_xd[1,1] = 0.5*beta*gamma
#     return L_x_x, L_xd_x, L_xd_xd
