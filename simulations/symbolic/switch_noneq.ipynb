# %%
from sympy import Symbol, Function, diff, Matrix, zeros, symbols, N, sqrt, Pow, Mul, Add, log, exp, sin, cos, tan
import sympy
import numpy as np
import matplotlib.pyplot as plt
import expr_optimiser

# %% [markdown]
# ## Define system

# %%
dim = 2

# %%
t = Symbol('t')
T = Symbol('T', nonnegative=True)
g = Symbol('gamma')
b = Symbol('beta')

coords = symbols('x y')
dcoords = symbols('xdot ydot')

x, y = coords
xdot, ydot = dcoords

r = Function('r')(x,y)
coord_functions = {
    r : sqrt(x**2 + y**2)
}

# %%
coord_func_derivative_rules = {
    diff(r,x) : x/r,
    diff(r,y) : y/r
}

# %%
params = symbols('U0 xip xim eta theta')
r0 = Symbol('r0')
U0, xip, xim, eta, theta = params

# %%
#r = sqrt(x**2 + y**2)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))
U = U.subs(r0, 1)

# %%
def cdiff(expr, coord):
    dexpr = diff(expr, coord)
    
    for df, df_expr in coord_func_derivative_rules.items():
        dexpr = dexpr.subs(df, df_expr)
        
    return dexpr

# %%
F_eq = zeros(dim, 1)
for i in range(dim):
    F_eq[i] = -cdiff(U, coords[i])
    F_eq[i] = F_eq[i].simplify()
    
F_neq_r = sympy.exp(-theta*( r - r0 )**2)
F_neq_r = F_neq_r.subs(r0, 1)
F_neq = zeros(dim, 1)
F_neq[0] =  - F_neq_r * eta * y / r
F_neq[1] =  F_neq_r * eta * x / r

F = F_eq + F_neq

# %%
div_F = 0
for i in range(dim):
    div_F += cdiff(F[i], coords[i])
div_F = div_F.simplify()
    
L_OM = (1/(2*g)) * div_F
L_FW = 0
for i in range(dim):
    L_OM += (b*g/4) * (dcoords[i] - F[i]/g)**2
    L_FW += (b*g/4) * (dcoords[i] - F[i]/g)**2
L_OM = L_OM.simplify()
L_FW = L_FW.simplify()

# %%
def compute_gradL(L):
    L_x = zeros(dim, 1)
    L_xd = zeros(dim, 1)
    for i in range(dim):
        cdiff(L, coords[i])
        L_x[i] = cdiff(L, coords[i]).simplify()
        L_xd[i] = cdiff(L, dcoords[i]).simplify()
    return L_x, L_xd
def compute_hessL(L):
    L_x_x = zeros(dim, dim)
    L_xd_x = zeros(dim, dim)
    L_xd_xd = zeros(dim, dim)
    for i in range(dim):
        for j in range(dim):
            L_x_x[i,j] = cdiff(cdiff(L, coords[i]), coords[j]).simplify()
            L_xd_x[i,j] = cdiff(cdiff(L, dcoords[i]), coords[j]).simplify()
            L_xd_xd[i,j] = cdiff(cdiff(L, dcoords[i]), dcoords[j]).simplify()
    return L_x_x, L_xd_x, L_xd_xd

# %%
L_x_OM, L_xd_OM = compute_gradL(L_OM)
L_x_FW, L_xd_FW = compute_gradL(L_FW)

# %%
L_x_x_OM, L_xd_x_OM, L_xd_xd_OM = compute_hessL(L_OM)
L_x_x_FW, L_xd_x_FW, L_xd_xd_FW = compute_hessL(L_FW)

# %% [markdown]
# ## Plots and Analysis

# %% [markdown]
# ## Generate code

# %% [markdown]
# Pre-process the symbolic expressions

# %%
U = N(U)
F = N(F)
div_F = N(div_F)
L_OM = N(L_OM)
L_FW = N(L_FW)

L_x_OM = N(L_x_OM)
L_xd_OM = N(L_xd_OM)

L_x_FW = N(L_x_FW)
L_xd_FW = N(L_xd_FW)

L_x_x_OM = N(L_x_x_OM)
L_xd_x_OM = N(L_xd_x_OM)
L_xd_xd_OM = N(L_xd_xd_OM)

L_x_x_FW = N(L_x_x_FW)
L_xd_x_FW = N(L_xd_x_FW)
L_xd_xd_FW = N(L_xd_xd_FW)

# %%
substitution_rules = {
    sqrt(x**2 + y**2) : r,
    x**2 + y**2 : r**2
}

def apply_substs(expr):
    for a, b in substitution_rules.items():
        expr = expr.subs(a,b)
    return expr

U = apply_substs(U)
F = apply_substs(F)
div_F = apply_substs(div_F)
L_OM = apply_substs(L_OM)
L_FW = apply_substs(L_FW)

L_x_OM = apply_substs(L_x_OM)
L_xd_OM = apply_substs(L_xd_OM)

L_x_FW = apply_substs(L_x_FW)
L_xd_FW = apply_substs(L_xd_FW)

L_x_x_OM = apply_substs(L_x_x_OM)
L_xd_x_OM = apply_substs(L_xd_x_OM)
L_xd_xd_OM = apply_substs(L_xd_xd_OM)

L_x_x_FW = apply_substs(L_x_x_FW)
L_xd_x_FW = apply_substs(L_xd_x_FW)
L_xd_xd_FW = apply_substs(L_xd_xd_FW)

# %%
for i in range(len(coords)):
    coords[i].name = 'x[%s,i]' % i

for i in range(len(dcoords)):
    dcoords[i].name = 'xd[%s,i]' % i

# %%
# Add the coord functions to the coords
coords_and_coord_functions = list(coords) + list(coord_functions.keys())

# %%
str_substitutions = {
}

# %%
expr_optimiser.set_coords(coords_and_coord_functions, dcoords)

# %%
def to_ccode(sym):
    # Replace coordinate functions with symbols
    for cf in coord_functions:
        sym = sym.subs(cf, Symbol(cf.name))
    
    code = sympy.printing.ccode(sym)
    
    for k in str_substitutions:
        code = code.replace(k, str_substitutions[k])
        
    return code

# %%
def function_formatter(function_name, lines):
    code_lines =  [function_name]
    tab = '    '
    
    for tabs, code_line in lines:
        code_lines.append( tabs*tab + code_line )
        
    return '\n'.join(code_lines).strip()

# %%
coord_func_ccode_declarations = []
for cf, cf_expr in coord_functions.items():
    decl = '%s = %s' % (cf.name, to_ccode(cf_expr))
    coord_func_ccode_declarations.append(decl)

# %%
def get_params_cdef(exprs, params, include_beta_gamma=True):
    cdef_params = []
    cdef_params.append((1, 'cdef:'))
    cdef_params.append((2, 'int i'))
    cdef_params.append((2, 'int dim = x.shape[0]'))
    cdef_params.append((2, 'int Nt = x.shape[1]'))
    
    if include_beta_gamma:
        cdef_params.append((2, 'DTYPE_t beta = self.beta'))
        cdef_params.append((2, 'DTYPE_t gamma = self.gamma'))
    for p in params:
        cdef_params.append( (2, 'DTYPE_t %s = self.%s' % (p, p)) )
    for cf, cf_expr in coord_functions.items():
        cdef_params.append( (2, 'DTYPE_t %s' % cf.name) )
    for var in expr_optimiser.get_used_vars(exprs):
        const_expr = expr_optimiser.const_lookup[var][1]
        cdef_params.append( (2, 'DTYPE_t %s = %s' % (var, expr_optimiser.dereference_expr(const_expr) ) ) )
        
    return cdef_params

# %%
U = expr_optimiser.sym_formatter(U)
F = expr_optimiser.sym_formatter(F)
div_F = expr_optimiser.sym_formatter(div_F)
L_OM = expr_optimiser.sym_formatter(L_OM)
L_FW = expr_optimiser.sym_formatter(L_FW)

print(1)
L_x_OM = expr_optimiser.sym_formatter(L_x_OM)
L_xd_OM = expr_optimiser.sym_formatter(L_xd_OM)

print(2)
L_x_FW = expr_optimiser.sym_formatter(L_x_FW)
L_xd_FW = expr_optimiser.sym_formatter(L_xd_FW)

print(3)
L_x_x_OM = expr_optimiser.sym_formatter(L_x_x_OM)
L_xd_x_OM = expr_optimiser.sym_formatter(L_xd_x_OM)
L_xd_xd_OM = expr_optimiser.sym_formatter(L_xd_xd_OM)

print(4)
L_x_x_FW = expr_optimiser.sym_formatter(L_x_x_FW)
L_xd_x_FW = expr_optimiser.sym_formatter(L_xd_x_FW)
L_xd_xd_FW = expr_optimiser.sym_formatter(L_xd_xd_FW)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Potential

# %%
code_potential = [] + coord_func_ccode_declarations
code_potential.append('potential[i] = %s' % to_ccode(U))
cdef_potential = get_params_cdef(U, params, include_beta_gamma=False)

# %% [markdown]
# ### Force and div Force

# %%
code_force = []
code_div_force = None

code_force += coord_func_ccode_declarations

for j in range(dim):
    code_line = 'force[%s,i] = %s' % (j, to_ccode(F[j]))
    code_force.append(code_line)

code_div_force = 'div_force[i] = %s' % to_ccode(div_F)

# %%
cdef_force = get_params_cdef(F, params, include_beta_gamma=False)
cdef_force_and_div_force = get_params_cdef([F, div_F], params, include_beta_gamma=False)

# %% [markdown]
# ### Gradient of Lagrangian

# %%
def get_gradL_code(L_x, L_xd):
    code_L_x = [] + coord_func_ccode_declarations
    code_L_xd = [] 

    for j in range(dim):
        code_line = 'L_x[%s,i] = %s' % (j, to_ccode(L_x[j]))
        code_L_x.append(code_line)
        
        code_line = 'L_xd[%s,i] = %s' % (j, to_ccode(L_xd[j]))
        code_L_xd.append(code_line)
            
    return code_L_x, code_L_xd
            
code_L_x_OM, code_L_xd_OM = get_gradL_code(L_x_OM, L_xd_OM)
code_L_x_FW, code_L_xd_FW = get_gradL_code(L_x_FW, L_xd_FW)

# %%
cdef_gradL_OM = get_params_cdef([L_x_OM, L_xd_OM], params, include_beta_gamma=True)
cdef_gradL_FW = get_params_cdef([L_x_FW, L_xd_FW], params, include_beta_gamma=True)

# %% [markdown]
# ### Hessian of Lagrangian

# %%
def get_hessL_code(L_x_x, L_xd_x, L_xd_xd):
    code_L_x_x = [] + coord_func_ccode_declarations
    code_L_xd_x = [] 
    code_L_xd_xd = []

    for j in range(dim):
        for k in range(dim):
            code_line = 'L_x_x[%s,%s,i] = %s' % (j, k, to_ccode(L_x_x[j,k]))
            code_L_x_x.append(code_line)
            
            code_line = 'L_xd_x[%s,%s,i] = %s' % (j, k, to_ccode(L_xd_x[j,k]))
            code_L_xd_x.append(code_line)
            
            code_line = 'L_xd_xd[%s,%s,i] = %s' % (j, k, to_ccode(L_xd_xd[j,k]))
            code_L_xd_xd.append(code_line)
            
    return code_L_x_x, code_L_xd_x, code_L_xd_xd
            
code_L_x_x_OM, code_L_xd_x_OM, code_L_xd_xd_OM = get_hessL_code(L_x_x_OM, L_xd_x_OM, L_xd_xd_OM)
code_L_x_x_FW, code_L_xd_x_FW, code_L_xd_xd_FW = get_hessL_code(L_x_x_FW, L_xd_x_FW, L_xd_xd_FW)

# %%
cdef_hessL_OM = get_params_cdef([L_x_x_OM, L_xd_x_OM, L_xd_xd_OM], params, include_beta_gamma=True)
cdef_hessL_FW = get_params_cdef([L_x_x_FW, L_xd_x_FW, L_xd_xd_FW], params, include_beta_gamma=True)

# %% [markdown]
# ### Cython functions

# %%
function_name = 'cdef DTYPE_t _compute_potential(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:] potential):'

lines = []
lines += cdef_potential
lines += [(1, '')]
lines += [(1, 'for i in range(Nt):')]
lines += [(2, l) for l in code_potential]

_compute_potential = function_formatter(function_name, lines)

# %%
function_name = 'cdef DTYPE_t _compute_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force):'

lines = []
lines += cdef_force
lines += [(1, '')]
lines += [(1, 'for i in range(Nt):')]
lines += [(2, l) for l in code_force]

_compute_force = function_formatter(function_name, lines)

# %%
function_name = 'cdef DTYPE_t _compute_force_and_div_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force, DTYPE_t[:] div_force):'

lines = []
lines += cdef_force_and_div_force
lines += [(1, '')]
lines += [(1, 'for i in range(Nt):')]
lines += [(2, l) for l in code_force]
lines += [(2, code_div_force)]

_compute_force_and_div_force = function_formatter(function_name, lines)

# %%
def get_gradL_function(code_L_x, code_L_xd, cdef_params, func_postfix):
    function_name = 'cdef DTYPE_t _compute_gradL_%s(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:] L_x, DTYPE_t[:,:] L_xd):' % func_postfix

    lines = []
    lines += cdef_params
    lines += [(1, '')]
    lines += [(1, 'for i in range(Nt):')]
    lines += [(2, l) for l in code_L_x]
    lines += [(2, l) for l in code_L_xd]
    
    return function_formatter(function_name, lines)

_compute_gradL_OM = get_gradL_function(code_L_x_OM, code_L_xd_OM, cdef_gradL_OM, 'OM')
_compute_gradL_FW = get_gradL_function(code_L_x_FW, code_L_xd_FW, cdef_gradL_FW, 'FW')

# %%
def get_hessL_function(code_L_x_x, code_L_xd_x, code_L_xd_xd, cdef_params, func_postfix):
    function_name = 'cdef DTYPE_t _compute_hessL_%s(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] L_x_x, DTYPE_t[:,:,:] L_xd_x, DTYPE_t[:,:,:] L_xd_xd):' % func_postfix

    lines = []
    lines += cdef_params
    lines += [(1, '')]
    lines += [(1, 'for i in range(Nt):')]
    lines += [(2, l) for l in code_L_x_x]
    lines += [(2, l) for l in code_L_xd_x]
    lines += [(2, l) for l in code_L_xd_xd]
    
    return function_formatter(function_name, lines)

_compute_hessL_OM = get_hessL_function(code_L_x_x_OM, code_L_xd_x_OM, code_L_xd_xd_OM, cdef_hessL_OM, 'OM')
_compute_hessL_FW = get_hessL_function(code_L_x_x_FW, code_L_xd_x_FW, code_L_xd_xd_FW, cdef_hessL_FW, 'FW')

# %%
print('\n\n'.join([
    _compute_potential,
    _compute_force,
    _compute_force_and_div_force,
    _compute_gradL_OM,
    _compute_gradL_FW,
    _compute_hessL_OM,
    _compute_hessL_FW
]))
# Out:
# cdef DTYPE_t _compute_potential(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:] potential):
#     cdef:
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#         DTYPE_t var_1p5_tim_U0_tim_xim = 1.5*U0*xim
#         DTYPE_t var_3p0_tim_U0_tim_xim = 3.0*U0*xim
#         DTYPE_t var_2p0_tim_U0 = 2.0*U0
#         DTYPE_t var_1p0_tim_U0 = 1.0*U0
#         DTYPE_t var_3p0_tim_U0 = 3.0*U0
#         DTYPE_t var_3p0_tim_U0_tim_xip = 3.0*U0*xip
#         DTYPE_t var_1p5_tim_U0_tim_xip = 1.5*U0*xip
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         potential[i] = pow(r, 4)*var_1p5_tim_U0_tim_xip + pow(r, 3)*var_1p5_tim_U0_tim_xim*x[1,i] + pow(r, 3)*var_2p0_tim_U0 - pow(r, 3)*var_3p0_tim_U0_tim_xip + pow(r, 2)*var_1p5_tim_U0_tim_xip - pow(r, 2)*var_3p0_tim_U0 - pow(r, 2)*var_3p0_tim_U0_tim_xim*x[1,i] + r*var_1p5_tim_U0_tim_xim*x[1,i] + var_1p0_tim_U0
#
# cdef DTYPE_t _compute_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force):
#     cdef:
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#         DTYPE_t var_6p0_tim_U0_tim_xip = 6.0*U0*xip
#         DTYPE_t var_1p5_tim_U0_tim_xim = 1.5*U0*xim
#         DTYPE_t var_3p0_tim_U0_tim_xim = 3.0*U0*xim
#         DTYPE_t var_2_tim_theta = 2*theta
#         DTYPE_t var_6p0_tim_U0_tim_xim = 6.0*U0*xim
#         DTYPE_t var_9p0_tim_U0_tim_xip = 9.0*U0*xip
#         DTYPE_t var_3p0_tim_U0_tim_xip = 3.0*U0*xip
#         DTYPE_t var_4p5_tim_U0_tim_xim = 4.5*U0*xim
#         DTYPE_t var_6p0_tim_U0 = 6.0*U0
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         force[0,i] = -(eta*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + r*x[0,i]*(pow(r, 2)*var_6p0_tim_U0_tim_xip + r*var_4p5_tim_U0_tim_xim*x[1,i] + r*var_6p0_tim_U0 - r*var_9p0_tim_U0_tim_xip + var_3p0_tim_U0_tim_xip - var_6p0_tim_U0 - var_6p0_tim_U0_tim_xim*x[1,i]) + var_1p5_tim_U0_tim_xim*x[0,i]*x[1,i])/r
#         force[1,i] = (eta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) - r*(pow(r, 3)*var_1p5_tim_U0_tim_xim - pow(r, 2)*var_3p0_tim_U0_tim_xim + pow(r, 2)*var_6p0_tim_U0_tim_xip*x[1,i] + r*var_1p5_tim_U0_tim_xim + r*var_4p5_tim_U0_tim_xim*pow(x[1,i], 2) + r*var_6p0_tim_U0*x[1,i] - r*var_9p0_tim_U0_tim_xip*x[1,i] + var_3p0_tim_U0_tim_xip*x[1,i] - var_6p0_tim_U0*x[1,i] - var_6p0_tim_U0_tim_xim*pow(x[1,i], 2)) - var_1p5_tim_U0_tim_xim*pow(x[1,i], 2))/r
#
# cdef DTYPE_t _compute_force_and_div_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force, DTYPE_t[:] div_force):
#     cdef:
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#         DTYPE_t var_24p0_tim_U0_tim_xim = 24.0*U0*xim
#         DTYPE_t var_18p0_tim_U0_tim_xim = 18.0*U0*xim
#         DTYPE_t var_6p0_tim_U0_tim_xip = 6.0*U0*xip
#         DTYPE_t var_1p5_tim_U0_tim_xim = 1.5*U0*xim
#         DTYPE_t var_3p0_tim_U0_tim_xim = 3.0*U0*xim
#         DTYPE_t var_2_tim_theta = 2*theta
#         DTYPE_t var_6p0_tim_U0_tim_xim = 6.0*U0*xim
#         DTYPE_t var_9p0_tim_U0_tim_xip = 9.0*U0*xip
#         DTYPE_t var_12p0_tim_U0 = 12.0*U0
#         DTYPE_t var_3p0_tim_U0_tim_xip = 3.0*U0*xip
#         DTYPE_t var_18p0_tim_U0_tim_xip = 18.0*U0*xip
#         DTYPE_t var_4p5_tim_U0_tim_xim = 4.5*U0*xim
#         DTYPE_t var_6p0_tim_U0 = 6.0*U0
#         DTYPE_t var_12p0_tim_U0_tim_xip = 12.0*U0*xip
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         force[0,i] = -(eta*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + r*x[0,i]*(pow(r, 2)*var_6p0_tim_U0_tim_xip + r*var_4p5_tim_U0_tim_xim*x[1,i] + r*var_6p0_tim_U0 - r*var_9p0_tim_U0_tim_xip + var_3p0_tim_U0_tim_xip - var_6p0_tim_U0 - var_6p0_tim_U0_tim_xim*x[1,i]) + var_1p5_tim_U0_tim_xim*x[0,i]*x[1,i])/r
#         force[1,i] = (eta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) - r*(pow(r, 3)*var_1p5_tim_U0_tim_xim - pow(r, 2)*var_3p0_tim_U0_tim_xim + pow(r, 2)*var_6p0_tim_U0_tim_xip*x[1,i] + r*var_1p5_tim_U0_tim_xim + r*var_4p5_tim_U0_tim_xim*pow(x[1,i], 2) + r*var_6p0_tim_U0*x[1,i] - r*var_9p0_tim_U0_tim_xip*x[1,i] + var_3p0_tim_U0_tim_xip*x[1,i] - var_6p0_tim_U0*x[1,i] - var_6p0_tim_U0_tim_xim*pow(x[1,i], 2)) - var_1p5_tim_U0_tim_xim*pow(x[1,i], 2))/r
#         div_force[i] = (pow(r, 3)*(-pow(r, 2)*var_12p0_tim_U0_tim_xip - r*var_12p0_tim_U0 - r*var_18p0_tim_U0_tim_xim*x[1,i] + r*var_18p0_tim_U0_tim_xip + var_12p0_tim_U0 - var_12p0_tim_U0_tim_xip*pow(x[0,i], 2) - var_12p0_tim_U0_tim_xip*pow(x[1,i], 2) + var_24p0_tim_U0_tim_xim*x[1,i] - var_6p0_tim_U0_tim_xip) + pow(r, 2)*(-var_4p5_tim_U0_tim_xim*pow(x[0,i], 2)*x[1,i] - var_4p5_tim_U0_tim_xim*pow(x[1,i], 3) - var_6p0_tim_U0*pow(x[0,i], 2) - var_6p0_tim_U0*pow(x[1,i], 2) - var_6p0_tim_U0_tim_xim*x[1,i] + var_9p0_tim_U0_tim_xip*pow(x[0,i], 2) + var_9p0_tim_U0_tim_xip*pow(x[1,i], 2)) + var_1p5_tim_U0_tim_xim*x[1,i]*(pow(x[0,i], 2) + pow(x[1,i], 2)))/pow(r, 3)
#
# cdef DTYPE_t _compute_gradL_OM(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:] L_x, DTYPE_t[:,:] L_xd):
#     cdef:
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#         DTYPE_t var_var_18p0_tim_beta_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta*xip/gamma
#         DTYPE_t var_0p5_tim_beta_tim_eta = 0.5*beta*eta
#         DTYPE_t var_var_0p5_tim_beta_tim_var_1_div_gamma_tim_var_eta_pow_2 = 0.5*beta*eta**2/gamma
#         DTYPE_t var_4_tim_theta = 4*theta
#         DTYPE_t var_2_tim_var_2_tim_theta = 4*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_24p0_tim_U0_tim_xip = 24.0*U0*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_9p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 9.0*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 10.125*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_11p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 11.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_xim = 1.5*U0*beta*xim
#         DTYPE_t var_4p5_tim_U0_tim_beta_tim_xip = 4.5*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 40.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_3p0_tim_U0_tim_beta = 3.0*U0*beta
#         DTYPE_t var_0p5_tim_beta_tim_gamma = 0.5*beta*gamma
#         DTYPE_t var_2p25_tim_beta = 2.25*beta
#         DTYPE_t var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 54.0*U0**2*beta*xip/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 13.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_1p125_tim_beta = 1.125*beta
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_xip = 1.5*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_51p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 51.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_9p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 9.0*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 36.0*U0**2*beta*xip/gamma
#         DTYPE_t var_0p75_tim_U0_tim_beta_tim_eta_tim_xim = 0.75*U0*beta*eta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 33.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_3p0_tim_U0_tim_beta_tim_xim = 3.0*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 72.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_38p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 38.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_11p25_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 11.25*U0**2*beta*xim**2/gamma
#         DTYPE_t var_1p0_tim_beta_tim_eta_tim_theta = 1.0*beta*eta*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_1p0_tim_beta_tim_theta_tim_var_eta_pow_2 = 1.0*beta*eta**2*theta/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_31p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 31.5*U0**2*beta*xim/gamma
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 1.5*U0*beta*eta*theta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 54.0*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_2p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 2.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_U0_tim_xip = 4.5*U0*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_2p25_tim_U0_tim_xim = 2.25*U0*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 1.5*U0*beta*eta*theta*xim/gamma
#         DTYPE_t var_var_18p0_tim_U0_tim_xip_tim_var_1_div_gamma = 18.0*U0*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 27.0*U0**2*beta*xim**2/gamma
#         DTYPE_t var_2_tim_theta = 2*theta
#         DTYPE_t var_6p0_tim_U0_tim_beta_tim_xip = 6.0*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_76p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 76.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_eta_tim_xim = 1.5*U0*beta*eta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_60p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 60.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_3_tim_var_2_tim_theta = 6*theta
#         DTYPE_t var_var_137p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 137.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 20.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 58.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 81.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_1_div_gamma = 1/gamma
#         DTYPE_t var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 4.5*U0*beta*eta*theta*xim
#         DTYPE_t var_3_tim_theta = 3*theta
#         DTYPE_t var_var_12p0_tim_U0_tim_xim_tim_var_1_div_gamma = 12.0*U0*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_6p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 6.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_103p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 103.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_eta_pow_2 = eta**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_23p625_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 23.625*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_1p125_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 1.125*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_15p75_tim_U0_tim_xim_tim_var_1_div_gamma = 15.75*U0*xim/gamma
#         DTYPE_t var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta/gamma
#         DTYPE_t var_var_139p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 139.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_94p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 94.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 13.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 90.0*U0**2*beta*xip/gamma
#         DTYPE_t var_9p0_tim_U0_tim_beta_tim_xim = 9.0*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_3p0_tim_U0 = 3.0*U0/gamma
#         DTYPE_t var_var_177p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 177.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_45p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 45.0*U0**2*beta*xim/gamma
#         DTYPE_t var_1p0_tim_beta_tim_theta = 1.0*beta*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 4.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_2_tim_var_2_tim_theta_pls_var_4_tim_theta = 8*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = U0**2*xim**2/gamma
#         DTYPE_t var_var_3_tim_theta_pls_var_3_tim_var_2_tim_theta = 9*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_24p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 24.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_9p0_tim_U0_tim_xim = 9.0*U0*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2 = 36.0*U0**2*beta/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_xim = 1.5*U0*beta*eta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 4.5*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 40.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_2p25_tim_U0_tim_beta_tim_xim = 2.25*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 54.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 58.5*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 36.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_69p75_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 69.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_76p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 76.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 20.25*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_175p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 175.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_15p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 15.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_12p0_tim_U0_tim_var_1_div_gamma = 12.0*U0/gamma
#         DTYPE_t var_3p0_tim_U0_tim_beta_tim_xip = 3.0*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 72.0*U0**2*beta*xip/gamma
#         DTYPE_t var_var_3_tim_var_2_tim_theta_pls_var_4_tim_theta = 10*theta
#         DTYPE_t var_6p75_tim_U0_tim_beta_tim_xim = 6.75*U0*beta*xim
#         DTYPE_t var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2 = 18.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2 = 13.5*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 13.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 4.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_49p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 49.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 4.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_0p75_tim_U0_tim_beta_tim_xim = 0.75*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 27.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_3p375_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 3.375*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_135p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 135.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_18p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_13p5_tim_U0_tim_xim_tim_var_1_div_gamma = 13.5*U0*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_87p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 87.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_0p5_tim_beta = 0.5*beta
#         DTYPE_t var_var_1_div_gamma_tim_var_63p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 63.0*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_6p75_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 6.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_22p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 22.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_15p75_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 15.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 27.0*U0**2*beta*xim/gamma
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         L_x[0,i] = (-pow(r, 4)*var_1_div_gamma*(pow(r, 2)*var_0p75_tim_U0_tim_beta_tim_eta_tim_xim - pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2) - r*var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2) + var_0p75_tim_U0_tim_beta_tim_eta_tim_xim + var_1p5_tim_U0_tim_beta_tim_eta_tim_xim*pow(x[0,i], 2) - var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2))*exp(pow(r, 2)*var_3_tim_theta + pow(r, 2)*var_3_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_3_tim_theta_pls_var_3_tim_var_2_tim_theta) - pow(r, 4)*(-pow(r, 4)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] - pow(r, 4)*var_var_1_div_gamma_tim_var_3p375_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] + pow(r, 3)*var_var_11p25_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_49p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*x[1,i] + pow(r, 3)*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] - pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*xd[0,i] + pow(r, 2)*var_var_139p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*x[1,i] - pow(r, 2)*var_var_13p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] - pow(r, 2)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] - pow(r, 2)*var_var_1_div_gamma_tim_var_23p625_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 2) - pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 3) - pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*pow(x[1,i], 2) - pow(r, 2)*var_var_1_div_gamma_tim_var_45p0_tim_beta_tim_xim_tim_var_U0_pow_2*x[0,i]*x[1,i] - pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i] - r*var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*xd[1,i] - r*var_2p25_tim_U0_tim_beta_tim_xim*xd[0,i]*x[1,i] - r*var_3p0_tim_U0_tim_beta*xd[0,i] + r*var_4p5_tim_U0_tim_beta_tim_xip*xd[0,i] + r*var_var_103p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*x[1,i] - r*var_var_137p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] + r*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2*x[0,i] - r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3)*x[1,i] - r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 3) - r*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3) - r*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) + r*var_var_1_div_gamma_tim_var_60p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 2) + r*var_var_1_div_gamma_tim_var_6p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] - r*var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i] + r*var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 3) + r*var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*pow(x[1,i], 2) - var_1p5_tim_U0_tim_beta_tim_xip*xd[0,i] + var_3p0_tim_U0_tim_beta*xd[0,i] + var_3p0_tim_U0_tim_beta_tim_xim*x[0,i]*xd[1,i] + var_3p0_tim_U0_tim_beta_tim_xim*xd[0,i]*x[1,i] - var_6p0_tim_U0_tim_beta_tim_xip*pow(x[0,i], 2)*xd[0,i] - var_6p0_tim_U0_tim_beta_tim_xip*x[0,i]*x[1,i]*xd[1,i] - var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 3)*pow(x[1,i], 2) - var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 4) - var_var_18 ...
#         L_x[1,i] = (pow(r, 4)*var_1_div_gamma*x[0,i]*x[1,i]*(pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim)*exp(pow(r, 2)*var_3_tim_theta + pow(r, 2)*var_3_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_3_tim_theta_pls_var_3_tim_var_2_tim_theta) + pow(r, 4)*(pow(r, 5)*var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 + pow(r, 4)*var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] - pow(r, 4)*var_var_15p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 4)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + pow(r, 4)*var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_var_U0_pow_2 - pow(r, 3)*var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 3)*var_var_13p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[0,i], 2) + pow(r, 3)*var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 - pow(r, 3)*var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] + pow(r, 3)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[1,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + pow(r, 3)*var_var_1_div_gamma_tim_var_63p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[1,i], 2) + pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*xd[1,i] + pow(r, 2)*var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 2)*x[1,i] - pow(r, 2)*var_var_11p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 2)*var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[0,i], 2) + pow(r, 2)*var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 - pow(r, 2)*var_var_177p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[1,i], 2) + pow(r, 2)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[1,i], 3) + pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 2)*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[1,i], 3) - pow(r, 2)*var_var_1_div_gamma_tim_var_38p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2) + pow(r, 2)*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_xim_tim_var_U0_pow_2*pow(x[1,i], 2) - pow(r, 2)*var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[1,i] + r*var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*xd[0,i] + r*var_3p0_tim_U0_tim_beta*xd[1,i] - r*var_4p5_tim_U0_tim_beta_tim_xip*xd[1,i] + r*var_6p75_tim_U0_tim_beta_tim_xim*x[1,i]*xd[1,i] - r*var_var_135p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[1,i], 2) + r*var_var_175p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[1,i], 2) - r*var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] - r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 2)*x[1,i] - r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + r*var_var_1_div_gamma_tim_var_2p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 - r*var_var_1_div_gamma_tim_var_31p5_tim_beta_tim_xim_tim_var_U0_pow_2*pow(x[0,i], 2) - r*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2*x[1,i] + r*var_var_1_div_gamma_tim_var_38p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2) + r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2)*pow(x[1,i ...
#         L_xd[0,i] = (r*(pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*x[0,i] + r*var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*x[1,i] + r*var_3p0_tim_U0_tim_beta*x[0,i] - r*var_4p5_tim_U0_tim_beta_tim_xip*x[0,i] + var_0p5_tim_beta_tim_gamma*xd[0,i] + var_1p5_tim_U0_tim_beta_tim_xip*x[0,i] - var_3p0_tim_U0_tim_beta*x[0,i] - var_3p0_tim_U0_tim_beta_tim_xim*x[0,i]*x[1,i]) + var_0p5_tim_beta_tim_eta*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*x[0,i]*x[1,i])/r
#         L_xd[1,i] = (r*(pow(r, 3)*var_0p75_tim_U0_tim_beta_tim_xim - pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_xim + pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*x[1,i] + r*var_0p75_tim_U0_tim_beta_tim_xim + r*var_2p25_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2) + r*var_3p0_tim_U0_tim_beta*x[1,i] - r*var_4p5_tim_U0_tim_beta_tim_xip*x[1,i] + var_0p5_tim_beta_tim_gamma*xd[1,i] + var_1p5_tim_U0_tim_beta_tim_xip*x[1,i] - var_3p0_tim_U0_tim_beta*x[1,i] - var_3p0_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2)) - var_0p5_tim_beta_tim_eta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2))/r
#
# cdef DTYPE_t _compute_gradL_FW(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:] L_x, DTYPE_t[:,:] L_xd):
#     cdef:
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#         DTYPE_t var_var_18p0_tim_beta_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta*xip/gamma
#         DTYPE_t var_0p5_tim_beta_tim_eta = 0.5*beta*eta
#         DTYPE_t var_var_0p5_tim_beta_tim_var_1_div_gamma_tim_var_eta_pow_2 = 0.5*beta*eta**2/gamma
#         DTYPE_t var_4_tim_theta = 4*theta
#         DTYPE_t var_2_tim_var_2_tim_theta = 4*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_9p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 9.0*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 10.125*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_11p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 11.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_xim = 1.5*U0*beta*xim
#         DTYPE_t var_4p5_tim_U0_tim_beta_tim_xip = 4.5*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 40.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_3p0_tim_U0_tim_beta = 3.0*U0*beta
#         DTYPE_t var_0p5_tim_beta_tim_gamma = 0.5*beta*gamma
#         DTYPE_t var_2p25_tim_beta = 2.25*beta
#         DTYPE_t var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 54.0*U0**2*beta*xip/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 13.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_1p125_tim_beta = 1.125*beta
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_xip = 1.5*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_51p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 51.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_9p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 9.0*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 36.0*U0**2*beta*xip/gamma
#         DTYPE_t var_0p75_tim_U0_tim_beta_tim_eta_tim_xim = 0.75*U0*beta*eta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 33.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_3p0_tim_U0_tim_beta_tim_xim = 3.0*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 72.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_38p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 38.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_11p25_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 11.25*U0**2*beta*xim**2/gamma
#         DTYPE_t var_1p0_tim_beta_tim_eta_tim_theta = 1.0*beta*eta*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_1p0_tim_beta_tim_theta_tim_var_eta_pow_2 = 1.0*beta*eta**2*theta/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_31p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 31.5*U0**2*beta*xim/gamma
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 1.5*U0*beta*eta*theta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 54.0*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_2p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 2.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 1.5*U0*beta*eta*theta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 27.0*U0**2*beta*xim**2/gamma
#         DTYPE_t var_2_tim_theta = 2*theta
#         DTYPE_t var_6p0_tim_U0_tim_beta_tim_xip = 6.0*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_76p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 76.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_1p5_tim_U0_tim_beta_tim_eta_tim_xim = 1.5*U0*beta*eta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_60p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 60.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_3_tim_var_2_tim_theta = 6*theta
#         DTYPE_t var_var_137p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 137.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 20.25*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 58.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 81.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_1_div_gamma = 1/gamma
#         DTYPE_t var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 4.5*U0*beta*eta*theta*xim
#         DTYPE_t var_3_tim_theta = 3*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_6p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 6.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_103p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 103.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_eta_pow_2 = eta**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_23p625_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 23.625*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_1p125_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 1.125*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta/gamma
#         DTYPE_t var_var_139p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 139.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_94p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 94.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 13.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 90.0*U0**2*beta*xip/gamma
#         DTYPE_t var_9p0_tim_U0_tim_beta_tim_xim = 9.0*U0*beta*xim
#         DTYPE_t var_var_177p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 177.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_45p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 45.0*U0**2*beta*xim/gamma
#         DTYPE_t var_1p0_tim_beta_tim_theta = 1.0*beta*theta
#         DTYPE_t var_var_2_tim_var_2_tim_theta_pls_var_4_tim_theta = 8*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 4.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = U0**2*xim**2/gamma
#         DTYPE_t var_var_3_tim_theta_pls_var_3_tim_var_2_tim_theta = 9*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_24p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 24.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2 = 36.0*U0**2*beta/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_xim = 1.5*U0*beta*eta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 4.5*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 40.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_2p25_tim_U0_tim_beta_tim_xim = 2.25*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 54.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 58.5*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 36.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_69p75_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 69.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_76p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 76.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 20.25*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_175p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 175.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_15p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 15.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_3p0_tim_U0_tim_beta_tim_xip = 3.0*U0*beta*xip
#         DTYPE_t var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xip_tim_var_U0_pow_2 = 72.0*U0**2*beta*xip/gamma
#         DTYPE_t var_var_3_tim_var_2_tim_theta_pls_var_4_tim_theta = 10*theta
#         DTYPE_t var_6p75_tim_U0_tim_beta_tim_xim = 6.75*U0*beta*xim
#         DTYPE_t var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2 = 18.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2 = 13.5*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_13p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 13.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 4.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_49p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 49.5*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 4.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_0p75_tim_U0_tim_beta_tim_xim = 0.75*U0*beta*xim
#         DTYPE_t var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 27.0*U0**2*beta*xip**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_3p375_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 3.375*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_135p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 135.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_18p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_87p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 87.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_0p5_tim_beta = 0.5*beta
#         DTYPE_t var_var_1_div_gamma_tim_var_63p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 63.0*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_6p75_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 = 6.75*U0**2*beta*xim*xip/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_22p5_tim_beta_tim_xim_tim_var_U0_pow_2 = 22.5*U0**2*beta*xim/gamma
#         DTYPE_t var_var_15p75_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 15.75*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 27.0*U0**2*beta*xim/gamma
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         L_x[0,i] = (-pow(r, 4)*var_1_div_gamma*(pow(r, 2)*var_0p75_tim_U0_tim_beta_tim_eta_tim_xim - pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2) - r*var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2) + var_0p75_tim_U0_tim_beta_tim_eta_tim_xim + var_1p5_tim_U0_tim_beta_tim_eta_tim_xim*pow(x[0,i], 2) - var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2))*exp(pow(r, 2)*var_3_tim_theta + pow(r, 2)*var_3_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_3_tim_theta_pls_var_3_tim_var_2_tim_theta) - pow(r, 4)*(-pow(r, 4)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] - pow(r, 4)*var_var_1_div_gamma_tim_var_3p375_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] + pow(r, 3)*var_var_11p25_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_49p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*x[1,i] + pow(r, 3)*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] - pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*xd[0,i] + pow(r, 2)*var_var_139p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*x[1,i] - pow(r, 2)*var_var_13p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] - pow(r, 2)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] - pow(r, 2)*var_var_1_div_gamma_tim_var_23p625_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 2) - pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 3) - pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*pow(x[1,i], 2) - pow(r, 2)*var_var_1_div_gamma_tim_var_45p0_tim_beta_tim_xim_tim_var_U0_pow_2*x[0,i]*x[1,i] - pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i] - r*var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*xd[1,i] - r*var_2p25_tim_U0_tim_beta_tim_xim*xd[0,i]*x[1,i] - r*var_3p0_tim_U0_tim_beta*xd[0,i] + r*var_4p5_tim_U0_tim_beta_tim_xip*xd[0,i] + r*var_var_103p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*x[1,i] - r*var_var_137p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i] + r*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2*x[0,i] - r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3)*x[1,i] - r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 3) - r*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3) - r*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) + r*var_var_1_div_gamma_tim_var_60p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 2) + r*var_var_1_div_gamma_tim_var_6p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i] - r*var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i] + r*var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 3) + r*var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*pow(x[1,i], 2) - var_1p5_tim_U0_tim_beta_tim_xip*xd[0,i] + var_3p0_tim_U0_tim_beta*xd[0,i] + var_3p0_tim_U0_tim_beta_tim_xim*x[0,i]*xd[1,i] + var_3p0_tim_U0_tim_beta_tim_xim*xd[0,i]*x[1,i] - var_6p0_tim_U0_tim_beta_tim_xip*pow(x[0,i], 2)*xd[0,i] - var_6p0_tim_U0_tim_beta_tim_xip*x[0,i]*x[1,i]*xd[1,i] - var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 3)*pow(x[1,i], 2) - var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 4) - var_var_18 ...
#         L_x[1,i] = (pow(r, 4)*var_1_div_gamma*x[0,i]*x[1,i]*(pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim)*exp(pow(r, 2)*var_3_tim_theta + pow(r, 2)*var_3_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_3_tim_theta_pls_var_3_tim_var_2_tim_theta) + pow(r, 4)*(pow(r, 5)*var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 + pow(r, 4)*var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] - pow(r, 4)*var_var_15p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 4)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + pow(r, 4)*var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_xim_tim_var_U0_pow_2 - pow(r, 3)*var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 3)*var_var_13p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[0,i], 2) + pow(r, 3)*var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 - pow(r, 3)*var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] + pow(r, 3)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[1,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + pow(r, 3)*var_var_1_div_gamma_tim_var_63p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[1,i], 2) + pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*xd[1,i] + pow(r, 2)*var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 2)*x[1,i] - pow(r, 2)*var_var_11p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 2)*var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[0,i], 2) + pow(r, 2)*var_var_13p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2 - pow(r, 2)*var_var_177p75_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[1,i], 2) + pow(r, 2)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[1,i], 3) + pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 2)*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[1,i], 3) - pow(r, 2)*var_var_1_div_gamma_tim_var_38p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2) + pow(r, 2)*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_xim_tim_var_U0_pow_2*pow(x[1,i], 2) - pow(r, 2)*var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[1,i] + r*var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*xd[0,i] + r*var_3p0_tim_U0_tim_beta*xd[1,i] - r*var_4p5_tim_U0_tim_beta_tim_xip*xd[1,i] + r*var_6p75_tim_U0_tim_beta_tim_xim*x[1,i]*xd[1,i] - r*var_var_135p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[1,i], 2) + r*var_var_175p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[1,i], 2) - r*var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[1,i] - r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 2)*x[1,i] - r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[1,i] + r*var_var_1_div_gamma_tim_var_2p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2 - r*var_var_1_div_gamma_tim_var_31p5_tim_beta_tim_xim_tim_var_U0_pow_2*pow(x[0,i], 2) - r*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2*x[1,i] + r*var_var_1_div_gamma_tim_var_38p25_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2) + r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2)*pow(x[1,i ...
#         L_xd[0,i] = (r*(pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*x[0,i] + r*var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*x[1,i] + r*var_3p0_tim_U0_tim_beta*x[0,i] - r*var_4p5_tim_U0_tim_beta_tim_xip*x[0,i] + var_0p5_tim_beta_tim_gamma*xd[0,i] + var_1p5_tim_U0_tim_beta_tim_xip*x[0,i] - var_3p0_tim_U0_tim_beta*x[0,i] - var_3p0_tim_U0_tim_beta_tim_xim*x[0,i]*x[1,i]) + var_0p5_tim_beta_tim_eta*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*x[0,i]*x[1,i])/r
#         L_xd[1,i] = (r*(pow(r, 3)*var_0p75_tim_U0_tim_beta_tim_xim - pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_xim + pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip*x[1,i] + r*var_0p75_tim_U0_tim_beta_tim_xim + r*var_2p25_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2) + r*var_3p0_tim_U0_tim_beta*x[1,i] - r*var_4p5_tim_U0_tim_beta_tim_xip*x[1,i] + var_0p5_tim_beta_tim_gamma*xd[1,i] + var_1p5_tim_U0_tim_beta_tim_xip*x[1,i] - var_3p0_tim_U0_tim_beta*x[1,i] - var_3p0_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2)) - var_0p5_tim_beta_tim_eta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2))/r
#
# cdef DTYPE_t _compute_hessL_OM(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] L_x_x, DTYPE_t[:,:,:] L_xd_x, DTYPE_t[:,:,:] L_xd_xd):
#     cdef:
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#         DTYPE_t var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xim_tim_var_U0_pow_2 = 36.0*U0**2*beta*xim/gamma
#         DTYPE_t var_var_11p25_tim_U0_tim_xim_tim_var_1_div_gamma = 11.25*U0*xim/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_364p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 364.5*U0**2*beta*xim**2/gamma
#         DTYPE_t var_var_180p0_tim_beta_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 180.0*U0**2*beta*xip/gamma
#         DTYPE_t var_var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_pls_var_var_1_div_gamma_tim_var_3p375_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2_pls_var_var_1_div_gamma_tim_var_4p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 = 3.375*U0**2*beta*xim**2/gamma + 4.5*U0**2*beta*xip**2/gamma + 18.0*U0**2*beta/gamma
#         DTYPE_t var_var_18p0_tim_beta_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 = 18.0*U0**2*beta*xip/gamma
#         DTYPE_t var_0p5_tim_beta_tim_eta = 0.5*beta*eta
#         DTYPE_t var_var_1_div_gamma_tim_var_9p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 = 9.0*U0**2*beta*xim**2/gamma
#         DTYPE_t var_4_tim_theta = 4*theta
#         DTYPE_t var_var_1_div_gamma_tim_var_24p0_tim_U0_tim_xip = 24.0*U0*xip/gamma
#         DTYPE_t var_6p0_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim = 6.0*U0*beta*eta*theta*xim
#         DTYPE_t var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 = 10.125*U0**2*beta*xim**2/gamma
#         DTYPE_t var_5p625_tim_beta = 5.625*beta
#         DTYPE_t var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2 = 72.0*U0**2*beta/gamma
#         DTYPE_t var_var_1_div_gamma_tim_var_2p0_tim_beta_tim_var_eta_pow_2 = 2.0*beta*eta**2/gamma
# ...
#         L_x_x[0,1,i] = (pow(r, 6)*var_1_div_gamma*x[1,i]*(pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - pow(r, 2)*var_var_3p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[0,i], 2) - r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim + r*var_var_12p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[0,i], 2) - var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim + var_6p0_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2) - var_var_18p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[0,i], 2))*exp(pow(r, 2)*var_5_tim_theta + pow(r, 2)*var_5_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_5_tim_theta_pls_var_5_tim_var_2_tim_theta) + pow(r, 6)*(pow(r, 3)*var_var_1_div_gamma_tim_var_49p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i] - pow(r, 2)*var_var_139p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] + pow(r, 2)*var_var_144p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_45p0_tim_beta_tim_xim_tim_var_U0_pow_2*x[0,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_60p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*x[1,i] + r*var_2p25_tim_U0_tim_beta_tim_xim*xd[0,i] - r*var_var_103p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] + r*var_var_137p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] - r*var_var_155p25_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_216p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_270p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) - r*var_var_1_div_gamma_tim_var_324p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3) - var_3p0_tim_U0_tim_beta_tim_xim*xd[0,i] + var_6p0_tim_U0_tim_beta_tim_xip*x[0,i]*xd[1,i] + var_6p0_tim_U0_tim_beta_tim_xip*xd[0,i]*x[1,i] + var_var_130p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*x[1,i] + var_var_171p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) + var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 3)*x[1,i] + var_var_1_div_gamma_tim_var_234p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*x[1,i] + var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_xim_tim_var_U0_pow_2*pow(x[0,i], 3) - var_var_1_div_gamma_tim_var_360p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i]*x[1,i] - var_var_1_div_gamma_tim_var_508p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) - var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i] + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2*x[0,i]*x[1,i] + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 3)*x[1,i] + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*pow(x[1,i], 3) + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xim_tim_var_U0_pow_2*x[0,i] - var_var_1_div_gamma_tim_var_76p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3) + var_var_1_div_gamma_tim_var_87p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 3))*exp(pow(r, 2)*var_5_tim_var_2_tim_theta + pow(r, 2)*var_6_tim_theta + var_var_5_tim_var_2_tim_theta_pls_var_6_tim_theta) + pow(r, 5)*(-var_1p0_tim_beta_tim_eta_tim_theta*x[0,i]*xd[0,i] + var_1p0_tim_beta_tim_eta_tim_theta*x[1,i]*xd[1,i] - var_var_10p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim_tim_var_1_div_gamma*pow(x[0,i], 2)*x[1,i] + var_var_12p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_1_div_gamma_tim_var_theta_pow_2*pow(x[0,i], 2)*x[1,i] - var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*x[1,i] + var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_xim*x[1,i] - var_var_2p0_tim_beta_tim_eta_tim_var_theta_pow_2*pow(x[0,i], 2 ...
#         L_x_x[1,0,i] = (pow(r, 6)*var_1_div_gamma*x[1,i]*(pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - pow(r, 2)*var_var_3p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[0,i], 2) - r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim + r*var_var_12p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[0,i], 2) - var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim + var_6p0_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[0,i], 2) - var_var_18p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[0,i], 2))*exp(pow(r, 2)*var_5_tim_theta + pow(r, 2)*var_5_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_5_tim_theta_pls_var_5_tim_var_2_tim_theta) + pow(r, 6)*(pow(r, 3)*var_var_1_div_gamma_tim_var_49p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i] - pow(r, 2)*var_var_139p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] + pow(r, 2)*var_var_144p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_45p0_tim_beta_tim_xim_tim_var_U0_pow_2*x[0,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_60p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*x[1,i] + r*var_2p25_tim_U0_tim_beta_tim_xim*xd[0,i] - r*var_var_103p5_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] + r*var_var_137p25_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i] - r*var_var_155p25_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_216p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_270p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) - r*var_var_1_div_gamma_tim_var_324p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*x[1,i] + r*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3) - var_3p0_tim_U0_tim_beta_tim_xim*xd[0,i] + var_6p0_tim_U0_tim_beta_tim_xip*x[0,i]*xd[1,i] + var_6p0_tim_U0_tim_beta_tim_xip*xd[0,i]*x[1,i] + var_var_130p5_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*x[1,i] + var_var_171p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) + var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 3)*x[1,i] + var_var_1_div_gamma_tim_var_234p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*x[1,i] + var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_xim_tim_var_U0_pow_2*pow(x[0,i], 3) - var_var_1_div_gamma_tim_var_360p0_tim_beta_tim_xip_tim_var_U0_pow_2*x[0,i]*x[1,i] - var_var_1_div_gamma_tim_var_508p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i]*pow(x[1,i], 2) - var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[0,i] + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2*x[0,i]*x[1,i] + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 3)*x[1,i] + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*x[0,i]*pow(x[1,i], 3) + var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xim_tim_var_U0_pow_2*x[0,i] - var_var_1_div_gamma_tim_var_76p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 3) + var_var_1_div_gamma_tim_var_87p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*x[0,i]*pow(x[1,i], 3))*exp(pow(r, 2)*var_5_tim_var_2_tim_theta + pow(r, 2)*var_6_tim_theta + var_var_5_tim_var_2_tim_theta_pls_var_6_tim_theta) + pow(r, 5)*(-var_1p0_tim_beta_tim_eta_tim_theta*x[0,i]*xd[0,i] + var_1p0_tim_beta_tim_eta_tim_theta*x[1,i]*xd[1,i] - var_var_10p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim_tim_var_1_div_gamma*pow(x[0,i], 2)*x[1,i] + var_var_12p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_1_div_gamma_tim_var_theta_pow_2*pow(x[0,i], 2)*x[1,i] - var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*x[1,i] + var_var_1_div_gamma_tim_var_1p5_tim_U0_tim_beta_tim_eta_tim_xim*x[1,i] - var_var_2p0_tim_beta_tim_eta_tim_var_theta_pow_2*pow(x[0,i], 2 ...
#         L_x_x[1,1,i] = (pow(r, 6)*var_1_div_gamma*x[0,i]*(pow(r, 2)*var_1p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim - pow(r, 2)*var_var_3p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[1,i], 2) - r*var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim + r*var_var_12p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[1,i], 2) - var_1p5_tim_U0_tim_beta_tim_eta_tim_xim + var_4p5_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim + var_6p0_tim_U0_tim_beta_tim_eta_tim_theta_tim_xim*pow(x[1,i], 2) - var_var_18p0_tim_U0_tim_beta_tim_eta_tim_xim_tim_var_theta_pow_2*pow(x[1,i], 2))*exp(pow(r, 2)*var_5_tim_theta + pow(r, 2)*var_5_tim_var_2_tim_theta + r*var_2_tim_theta + var_var_5_tim_theta_pls_var_5_tim_var_2_tim_theta) + pow(r, 6)*(pow(r, 4)*var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2 + pow(r, 4)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2 + pow(r, 3)*var_var_148p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[1,i] - pow(r, 3)*var_var_1_div_gamma_tim_var_33p75_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 + pow(r, 3)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_xip_tim_var_U0_pow_2 - pow(r, 3)*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 + pow(r, 2)*var_var_10p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 2) + pow(r, 2)*var_var_135p0_tim_beta_tim_xim_tim_var_1_div_gamma_tim_var_U0_pow_2*x[1,i] + pow(r, 2)*var_var_141p75_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[1,i], 2) + pow(r, 2)*var_var_180p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[1,i], 2) + pow(r, 2)*var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2 + pow(r, 2)*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 2) + pow(r, 2)*var_var_1_div_gamma_tim_var_40p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 - pow(r, 2)*var_var_1_div_gamma_tim_var_418p5_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[1,i] + pow(r, 2)*var_var_1_div_gamma_tim_var_58p5_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 - pow(r, 2)*var_var_1_div_gamma_tim_var_90p0_tim_beta_tim_xip_tim_var_U0_pow_2 + r*var_6p75_tim_U0_tim_beta_tim_xim*xd[1,i] + r*var_var_121p5_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[0,i], 2)*x[1,i] - r*var_var_1_div_gamma_tim_var_20p25_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2 + r*var_var_1_div_gamma_tim_var_270p0_tim_beta_tim_xip_tim_var_U0_pow_2*pow(x[1,i], 2) - r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[0,i], 2) - r*var_var_1_div_gamma_tim_var_27p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2 - r*var_var_1_div_gamma_tim_var_310p5_tim_beta_tim_xim_tim_var_U0_pow_2*x[1,i] + r*var_var_1_div_gamma_tim_var_351p0_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*pow(x[1,i], 3) - r*var_var_1_div_gamma_tim_var_364p5_tim_beta_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[1,i], 2) - r*var_var_1_div_gamma_tim_var_36p0_tim_beta_tim_var_U0_pow_2 - r*var_var_1_div_gamma_tim_var_405p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[1,i], 2) + r*var_var_1_div_gamma_tim_var_411p75_tim_beta_tim_xim_tim_xip_tim_var_U0_pow_2*x[1,i] + r*var_var_1_div_gamma_tim_var_54p0_tim_beta_tim_xip_tim_var_U0_pow_2*pow(x[0,i], 2) + r*var_var_1_div_gamma_tim_var_72p0_tim_beta_tim_xip_tim_var_U0_pow_2 - r*var_var_1_div_gamma_tim_var_81p0_tim_beta_tim_var_U0_pow_2_tim_var_xip_pow_2*pow(x[0,i], 2) + var_18p0_tim_U0_tim_beta_tim_xip*x[1,i]*xd[1,i] + var_6p0_tim_U0_tim_beta_tim_xip*x[0,i]*xd[0,i] - var_9p0_tim_U0_tim_beta_tim_xim*xd[1,i] + var_var_118p125_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2_tim_var_xim_pow_2*pow(x[1,i], 4) - var_var_162p0_tim_beta_tim_xim_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2*x[1,i] + var_var_18p0_tim_beta_tim_var_1_div_gamma_tim_var_U0_pow_2*pow(x[0,i], 2) - var_var_18p0_tim_beta_tim_xip_tim_var_1_div_gamma_tim_var_U0_pow_2 + var_var_1_div_gamma_tim_var_216p0_tim_beta_tim_xim_tim_var ...
#         L_xd_x[0,0,i] = (pow(r, 3)*(pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip + r*var_2p25_tim_U0_tim_beta_tim_xim*x[1,i] + r*var_3p0_tim_U0_tim_beta - r*var_4p5_tim_U0_tim_beta_tim_xip + var_1p5_tim_U0_tim_beta_tim_xip - var_3p0_tim_U0_tim_beta - var_3p0_tim_U0_tim_beta_tim_xim*x[1,i] + var_6p0_tim_U0_tim_beta_tim_xip*pow(x[0,i], 2)) + pow(r, 2)*(var_0p75_tim_U0_tim_beta_tim_xim*x[1,i] - var_1p0_tim_beta_tim_eta_tim_theta*x[0,i]*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_2p25_tim_U0_tim_beta_tim_xim*pow(x[0,i], 2)*x[1,i] + var_3p0_tim_U0_tim_beta*pow(x[0,i], 2) - var_4p5_tim_U0_tim_beta_tim_xip*pow(x[0,i], 2)) + r*var_1p0_tim_beta_tim_eta_tim_theta*x[0,i]*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) - x[0,i]*x[1,i]*(var_0p5_tim_beta_tim_eta*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*x[0,i]))/pow(r, 3)
#         L_xd_x[0,1,i] = (pow(r, 3)*x[0,i]*(r*var_2p25_tim_U0_tim_beta_tim_xim - var_3p0_tim_U0_tim_beta_tim_xim + var_6p0_tim_U0_tim_beta_tim_xip*x[1,i]) + pow(r, 2)*(var_0p5_tim_beta_tim_eta*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*x[0,i] - var_1p0_tim_beta_tim_eta_tim_theta*pow(x[1,i], 2)*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*pow(x[1,i], 2) + var_3p0_tim_U0_tim_beta*x[0,i]*x[1,i] - var_4p5_tim_U0_tim_beta_tim_xip*x[0,i]*x[1,i]) + r*var_1p0_tim_beta_tim_eta_tim_theta*pow(x[1,i], 2)*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) - pow(x[1,i], 2)*(var_0p5_tim_beta_tim_eta*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*x[0,i]))/pow(r, 3)
#         L_xd_x[1,0,i] = (pow(r, 3)*x[0,i]*(r*var_2p25_tim_U0_tim_beta_tim_xim - var_3p0_tim_U0_tim_beta_tim_xim + var_6p0_tim_U0_tim_beta_tim_xip*x[1,i]) + pow(r, 2)*(-var_0p5_tim_beta_tim_eta*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_0p75_tim_U0_tim_beta_tim_xim*x[0,i] + var_1p0_tim_beta_tim_eta_tim_theta*pow(x[0,i], 2)*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_2p25_tim_U0_tim_beta_tim_xim*x[0,i]*pow(x[1,i], 2) + var_3p0_tim_U0_tim_beta*x[0,i]*x[1,i] - var_4p5_tim_U0_tim_beta_tim_xip*x[0,i]*x[1,i]) - r*var_1p0_tim_beta_tim_eta_tim_theta*pow(x[0,i], 2)*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + x[0,i]*(var_0p5_tim_beta_tim_eta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) - var_0p75_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2)))/pow(r, 3)
#         L_xd_x[1,1,i] = (pow(r, 3)*(pow(r, 2)*var_3p0_tim_U0_tim_beta_tim_xip + r*var_3p0_tim_U0_tim_beta - r*var_4p5_tim_U0_tim_beta_tim_xip + r*var_6p75_tim_U0_tim_beta_tim_xim*x[1,i] + var_1p5_tim_U0_tim_beta_tim_xip - var_3p0_tim_U0_tim_beta + var_6p0_tim_U0_tim_beta_tim_xip*pow(x[1,i], 2) - var_9p0_tim_U0_tim_beta_tim_xim*x[1,i]) + pow(r, 2)*x[1,i]*(var_1p0_tim_beta_tim_eta_tim_theta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + var_2p25_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2) + var_2p25_tim_U0_tim_beta_tim_xim + var_3p0_tim_U0_tim_beta*x[1,i] - var_4p5_tim_U0_tim_beta_tim_xip*x[1,i]) - r*var_1p0_tim_beta_tim_eta_tim_theta*x[0,i]*x[1,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) + x[1,i]*(var_0p5_tim_beta_tim_eta*x[0,i]*exp(-pow(r, 2)*theta + r*var_2_tim_theta - theta) - var_0p75_tim_U0_tim_beta_tim_xim*pow(x[1,i], 2)))/pow(r, 3)
#         L_xd_xd[0,0,i] = var_0p5_tim_beta_tim_gamma
#         L_xd_xd[0,1,i] = 0
#         L_xd_xd[1,0,i] = 0
#         L_xd_xd[1,1,i] = var_0p5_tim_beta_tim_gamma
