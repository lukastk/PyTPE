# %%
from sympy import Symbol, Function, diff, Matrix, zeros, symbols, N, sqrt, Pow, Mul, Add, log, exp, sin, cos, tan, lambdify
import sympy
import numpy as np
import matplotlib.pyplot as plt
import expr_optimiser

# %% [markdown]
# ## Define system

# %%
dim = 2

# %%
t = Symbol('t')
T = Symbol('T', nonnegative=True)
g = Symbol('gamma')
b = Symbol('beta')

coords = symbols('x y')
dcoords = symbols('xdot ydot')

x, y = coords
xdot, ydot = dcoords

r = Function('r')(x,y)
coord_functions = {
    r : sqrt(x**2 + y**2)
}

# %%
coord_func_derivative_rules = {
    diff(r,x) : x/r,
    diff(r,y) : y/r
}

# %%
params = symbols('U0 xip xim')
r0 = Symbol('r0')
U0, xip, xim = params

# %%
#r = sqrt(x**2 + y**2)
k = (3*U0 / r0**2) * (2 + xip + xim*y/r)

U = (1 / (2*r0**4))*(r - r0)**2 * (k*r**2*r0**2 - 2*U0*(r-r0)*(3*r + r0))
U = U.subs(r0, 1)

# %%
def cdiff(expr, coord):
    dexpr = diff(expr, coord)
    
    for df, df_expr in coord_func_derivative_rules.items():
        dexpr = dexpr.subs(df, df_expr)
        
    return dexpr

# %%
F = zeros(dim, 1)
for i in range(dim):
    F[i] = -cdiff(U, coords[i])
    F[i] = F[i].simplify()
    
div_F = 0
for i in range(dim):
    div_F += cdiff(F[i], coords[i])
div_F = div_F.simplify()
    
L_OM = (1/(2*g)) * div_F
L_FW = 0
for i in range(dim):
    L_OM += (b*g/4) * (dcoords[i] - F[i]/g)**2
    L_FW += (b*g/4) * (dcoords[i] - F[i]/g)**2
L_OM = L_OM.simplify()
L_FW = L_FW.simplify()

# %%
def compute_gradL(L):
    L_x = zeros(dim, 1)
    L_xd = zeros(dim, 1)
    for i in range(dim):
        cdiff(L, coords[i])
        L_x[i] = cdiff(L, coords[i]).simplify()
        L_xd[i] = cdiff(L, dcoords[i]).simplify()
    return L_x, L_xd
def compute_hessL(L):
    L_x_x = zeros(dim, dim)
    L_xd_x = zeros(dim, dim)
    L_xd_xd = zeros(dim, dim)
    for i in range(dim):
        for j in range(dim):
            L_x_x[i,j] = cdiff(cdiff(L, coords[i]), coords[j]).simplify()
            L_xd_x[i,j] = cdiff(cdiff(L, dcoords[i]), coords[j]).simplify()
            L_xd_xd[i,j] = cdiff(cdiff(L, dcoords[i]), dcoords[j]).simplify()
    return L_x_x, L_xd_x, L_xd_xd

# %%
L_x_OM, L_xd_OM = compute_gradL(L_OM)
L_x_FW, L_xd_FW = compute_gradL(L_FW)

# %%
L_x_x_OM, L_xd_x_OM, L_xd_xd_OM = compute_hessL(L_OM)
L_x_x_FW, L_xd_x_FW, L_xd_xd_FW = compute_hessL(L_FW)

# %%
xfunc = Function(x)(t)
yfunc = Function(y)(t)
rsym = Symbol('r')
rfunc = Function(rsym)(t)

# %%
def differentiate_in_time(arr):
    darr = zeros(dim, dim)
    
    for i in range(dim):
        for j in range(dim):
            f = arr[i,j]
            
            _f = f.subs(r, rfunc).subs(x, xfunc).subs(y, yfunc) #xdot and ydot would not be in there

            df = _f.diff(t)
            df = df.subs(rfunc.diff(t), (x * xdot + y * ydot) / r)
            df = df.subs(xfunc.diff(t), xdot)
            df = df.subs(yfunc.diff(t), ydot)
            df = df.subs(xfunc, x)
            df = df.subs(yfunc, y)
            df = df.subs(rfunc, r)

            df = df.simplify()

            darr[i,j] = df
            
    return darr

# %%
dot_L_xd_x_OM = differentiate_in_time(L_xd_x_OM)
dot_L_xd_x_FW = differentiate_in_time(L_xd_x_FW)

# %%
plot_params = {
    U0 : 3,
    xim : 3,
    xip : 3,
    b : 2,
}


f = L_xd_x_OM[0,0].subs(r, sqrt(x**2 + y**2))
df = dot_L_xd_x_OM[0,0].subs(r, sqrt(x**2 + y**2))

for k, v in plot_params.items():
    f = f.subs(k, v)
    df = df.subs(k, v)
    
f = lambdify([x,y,xdot,ydot], f)
df = lambdify([x,y,xdot,ydot], df)

# %%
ts = np.linspace(0, 2, 10000)
xs = np.cos(ts**2) + np.sin(ts)
ys = ts**2
xdots = -2*ts*np.sin(ts**2) + np.cos(ts)
ydots = 2*ts

fs = f(xs, ys, xdots, ydots)

dfs1 = np.gradient(fs, ts)
dfs2 = df(xs, ys, xdots, ydots)

# %%
plt.plot(ts, dfs1)
plt.plot(ts, dfs2)

# %% [markdown]
# ## Plots and Analysis

# %%
plot_params = {
    U0 : 3,
    xim : 3,
    xip : 3,
}

U_plot = U.subs(r, sqrt(x**2 + y**2))

for k, v in plot_params.items():
    U_plot = U_plot.subs(k, v)

U_plot_func = lambdify([x,y], U_plot)

# %%
xs = np.linspace(-1.4, 1.4, 400)
ys = np.linspace(-1.4, 1.4, 400)
X, Y = np.meshgrid(xs,  ys)
Z = U_plot_func(X, Y)

fig, ax = plt.subplots(figsize=(6,6))

ax.contour(X, Y, Z, levels=150)

ax.set_xlabel('x')
ax.set_ylabel('y')

# Plot minimum
thetas = np.linspace(0, 2*np.pi, 1000)
ax.plot(np.cos(thetas), np.sin(thetas), '--', color='green', label='Minimum')

plt.plot(-1, 0, 'o', color='red', label=r'$x_0$')
plt.plot(1, 0, 'x', color='red', label=r'$x_T$')

plt.legend(fontsize=12)

fig.savefig('switch_potential.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# ## Generate code

# %% [markdown]
# Pre-process the symbolic expressions

# %%
U = N(U)
F = N(F)
div_F = N(div_F)
L_OM = N(L_OM)
L_FW = N(L_FW)

L_x_OM = N(L_x_OM)
L_xd_OM = N(L_xd_OM)

L_x_FW = N(L_x_FW)
L_xd_FW = N(L_xd_FW)

L_x_x_OM = N(L_x_x_OM)
L_xd_x_OM = N(L_xd_x_OM)
L_xd_xd_OM = N(L_xd_xd_OM)

L_x_x_FW = N(L_x_x_FW)
L_xd_x_FW = N(L_xd_x_FW)
L_xd_xd_FW = N(L_xd_xd_FW)

dot_L_xd_x_OM = N(dot_L_xd_x_OM)
dot_L_xd_x_FW = N(dot_L_xd_x_FW)

# %%
substitution_rules = {
    sqrt(x**2 + y**2) : r,
    x**2 + y**2 : r**2
}

def apply_substs(expr):
    for a, b in substitution_rules.items():
        expr = expr.subs(a,b)
    return expr

U = apply_substs(U)
F = apply_substs(F)
div_F = apply_substs(div_F)
L_OM = apply_substs(L_OM)
L_FW = apply_substs(L_FW)

L_x_OM = apply_substs(L_x_OM)
L_xd_OM = apply_substs(L_xd_OM)

L_x_FW = apply_substs(L_x_FW)
L_xd_FW = apply_substs(L_xd_FW)

L_x_x_OM = apply_substs(L_x_x_OM)
L_xd_x_OM = apply_substs(L_xd_x_OM)
L_xd_xd_OM = apply_substs(L_xd_xd_OM)

L_x_x_FW = apply_substs(L_x_x_FW)
L_xd_x_FW = apply_substs(L_xd_x_FW)
L_xd_xd_FW = apply_substs(L_xd_xd_FW)

dot_L_xd_x_OM = apply_substs(dot_L_xd_x_OM)
dot_L_xd_x_FW = apply_substs(dot_L_xd_x_FW)

# %%
for i in range(len(coords)):
    coords[i].name = 'x[%s,i]' % i

for i in range(len(dcoords)):
    dcoords[i].name = 'xd[%s,i]' % i

# %%
# Add the coord functions to the coords
coords_and_coord_functions = list(coords) + list(coord_functions.keys())

# %%
str_substitutions = {
}

# %%
expr_optimiser.set_coords(coords_and_coord_functions, dcoords)

# %%
def to_ccode(sym):
    # Replace coordinate functions with symbols
    for cf in coord_functions:
        sym = sym.subs(cf, Symbol(cf.name))
    
    code = sympy.printing.ccode(sym)
    
    for k in str_substitutions:
        code = code.replace(k, str_substitutions[k])
        
    return code

# %%
def function_formatter(function_name, lines):
    code_lines =  [function_name]
    tab = '    '
    
    for tabs, code_line in lines:
        code_lines.append( tabs*tab + code_line )
        
    return '\n'.join(code_lines).strip()

# %%
coord_func_ccode_declarations = []
for cf, cf_expr in coord_functions.items():
    decl = '%s = %s' % (cf.name, to_ccode(cf_expr))
    coord_func_ccode_declarations.append(decl)

# %%
def get_params_cdef(exprs, params, include_beta_gamma=True):
    cdef_params = []
    cdef_params.append((1, 'cdef:'))
    cdef_params.append((2, 'int i'))
    cdef_params.append((2, 'int dim = x.shape[0]'))
    cdef_params.append((2, 'int Nt = x.shape[1]'))
    
    if include_beta_gamma:
        cdef_params.append((2, 'DTYPE_t beta = self.beta'))
        cdef_params.append((2, 'DTYPE_t gamma = self.gamma'))
    for p in params:
        cdef_params.append( (2, 'DTYPE_t %s = self.%s' % (p, p)) )
    for cf, cf_expr in coord_functions.items():
        cdef_params.append( (2, 'DTYPE_t %s' % cf.name) )
    for var in expr_optimiser.get_used_vars(exprs):
        const_expr = expr_optimiser.const_lookup[var][1]
        cdef_params.append( (2, 'DTYPE_t %s = %s' % (var, expr_optimiser.dereference_expr(const_expr) ) ) )
        
    return cdef_params

# %%
U = expr_optimiser.sym_formatter(U)
F = expr_optimiser.sym_formatter(F)
div_F = expr_optimiser.sym_formatter(div_F)
L_OM = expr_optimiser.sym_formatter(L_OM)
L_FW = expr_optimiser.sym_formatter(L_FW)

print(1)
L_x_OM = expr_optimiser.sym_formatter(L_x_OM)
L_xd_OM = expr_optimiser.sym_formatter(L_xd_OM)

print(2)
L_x_FW = expr_optimiser.sym_formatter(L_x_FW)
L_xd_FW = expr_optimiser.sym_formatter(L_xd_FW)

print(3)
L_x_x_OM = expr_optimiser.sym_formatter(L_x_x_OM)
L_xd_x_OM = expr_optimiser.sym_formatter(L_xd_x_OM)
L_xd_xd_OM = expr_optimiser.sym_formatter(L_xd_xd_OM)

print(4)
L_x_x_FW = expr_optimiser.sym_formatter(L_x_x_FW)
L_xd_x_FW = expr_optimiser.sym_formatter(L_xd_x_FW)
L_xd_xd_FW = expr_optimiser.sym_formatter(L_xd_xd_FW)

print(5)
dot_L_xd_x_OM = expr_optimiser.sym_formatter(dot_L_xd_x_OM)
dot_L_xd_x_FW = expr_optimiser.sym_formatter(dot_L_xd_x_FW)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Potential

# %%
code_potential = [] + coord_func_ccode_declarations
code_potential.append('potential[i] = %s' % to_ccode(U))
cdef_potential = get_params_cdef(U, params, include_beta_gamma=False)

# %% [markdown]
# ### Force and div Force

# %%
code_force = []
code_div_force = None

code_force += coord_func_ccode_declarations

for j in range(dim):
    code_line = 'force[%s,i] = %s' % (j, to_ccode(F[j]))
    code_force.append(code_line)

code_div_force = 'div_force[i] = %s' % to_ccode(div_F)

# %%
cdef_force = get_params_cdef(F, params, include_beta_gamma=False)
cdef_force_and_div_force = get_params_cdef([F, div_F], params, include_beta_gamma=False)

# %% [markdown]
# ### Gradient of Lagrangian

# %%
def get_gradL_code(L_x, L_xd):
    code_L_x = [] + coord_func_ccode_declarations
    code_L_xd = [] 

    for j in range(dim):
        code_line = 'L_x[%s,i] = %s' % (j, to_ccode(L_x[j]))
        code_L_x.append(code_line)
        
        code_line = 'L_xd[%s,i] = %s' % (j, to_ccode(L_xd[j]))
        code_L_xd.append(code_line)
            
    return code_L_x, code_L_xd
            
code_L_x_OM, code_L_xd_OM = get_gradL_code(L_x_OM, L_xd_OM)
code_L_x_FW, code_L_xd_FW = get_gradL_code(L_x_FW, L_xd_FW)

# %%
cdef_gradL_OM = get_params_cdef([L_x_OM, L_xd_OM], params, include_beta_gamma=True)
cdef_gradL_FW = get_params_cdef([L_x_FW, L_xd_FW], params, include_beta_gamma=True)

# %% [markdown]
# ### Hessian of Lagrangian

# %%
def get_hessL_code(L_x_x, L_xd_x, L_xd_xd):
    code_L_x_x = [] + coord_func_ccode_declarations
    code_L_xd_x = [] 
    code_L_xd_xd = []

    for j in range(dim):
        for k in range(dim):
            code_line = 'L_x_x[%s,%s,i] = %s' % (j, k, to_ccode(L_x_x[j,k]))
            code_L_x_x.append(code_line)
            
            code_line = 'L_xd_x[%s,%s,i] = %s' % (j, k, to_ccode(L_xd_x[j,k]))
            code_L_xd_x.append(code_line)
            
            code_line = 'L_xd_xd[%s,%s,i] = %s' % (j, k, to_ccode(L_xd_xd[j,k]))
            code_L_xd_xd.append(code_line)
            
    return code_L_x_x, code_L_xd_x, code_L_xd_xd
            
code_L_x_x_OM, code_L_xd_x_OM, code_L_xd_xd_OM = get_hessL_code(L_x_x_OM, L_xd_x_OM, L_xd_xd_OM)
code_L_x_x_FW, code_L_xd_x_FW, code_L_xd_xd_FW = get_hessL_code(L_x_x_FW, L_xd_x_FW, L_xd_xd_FW)

# %%
cdef_hessL_OM = get_params_cdef([L_x_x_OM, L_xd_x_OM, L_xd_xd_OM], params, include_beta_gamma=True)
cdef_hessL_FW = get_params_cdef([L_x_x_FW, L_xd_x_FW, L_xd_xd_FW], params, include_beta_gamma=True)

# %% [markdown]
# ### Time derivative of $L_{\dot{x},x}$

# %%
def get_dot_L_xd_x_code(dot_L_xd_x):
    code_dot_L_xd_x = [] + coord_func_ccode_declarations

    for j in range(dim):
        for k in range(dim):
            code_line = 'dot_L_dx_x[%s,%s,i] = %s' % (j, k, to_ccode(dot_L_xd_x[j,k]))
            code_dot_L_xd_x.append(code_line)
            
    return code_dot_L_xd_x
            
code_dot_L_xd_x_OM = get_dot_L_xd_x_code(dot_L_xd_x_OM)
code_dot_L_xd_x_FW = get_dot_L_xd_x_code(dot_L_xd_x_FW)

# %%
cdef_dot_L_xd_x_OM = get_params_cdef([dot_L_xd_x_OM], params, include_beta_gamma=True)
cdef_dot_L_xd_x_FW = get_params_cdef([dot_L_xd_x_FW], params, include_beta_gamma=True)

# %% [markdown]
# ### Cython functions

# %%
function_name = 'cdef DTYPE_t _compute_potential(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:] potential):'

lines = []
lines += cdef_potential
lines += [(1, '')]
lines += [(1, 'for i in range(Nt):')]
lines += [(2, l) for l in code_potential]

_compute_potential = function_formatter(function_name, lines)

# %%
function_name = 'cdef DTYPE_t _compute_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force):'

lines = []
lines += cdef_force
lines += [(1, '')]
lines += [(1, 'for i in range(Nt):')]
lines += [(2, l) for l in code_force]

_compute_force = function_formatter(function_name, lines)

# %%
function_name = 'cdef DTYPE_t _compute_force_and_div_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force, DTYPE_t[:] div_force):'

lines = []
lines += cdef_force_and_div_force
lines += [(1, '')]
lines += [(1, 'for i in range(Nt):')]
lines += [(2, l) for l in code_force]
lines += [(2, code_div_force)]

_compute_force_and_div_force = function_formatter(function_name, lines)

# %%
def get_gradL_function(code_L_x, code_L_xd, cdef_params, func_postfix):
    function_name = 'cdef DTYPE_t _compute_gradL_%s(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:] L_x, DTYPE_t[:,:] L_xd):' % func_postfix

    lines = []
    lines += cdef_params
    lines += [(1, '')]
    lines += [(1, 'for i in range(Nt):')]
    lines += [(2, l) for l in code_L_x]
    lines += [(2, l) for l in code_L_xd]
    
    return function_formatter(function_name, lines)

_compute_gradL_OM = get_gradL_function(code_L_x_OM, code_L_xd_OM, cdef_gradL_OM, 'OM')
_compute_gradL_FW = get_gradL_function(code_L_x_FW, code_L_xd_FW, cdef_gradL_FW, 'FW')

# %%
def get_hessL_function(code_L_x_x, code_L_xd_x, code_L_xd_xd, cdef_params, func_postfix):
    function_name = 'cdef DTYPE_t _compute_hessL_%s(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] L_x_x, DTYPE_t[:,:,:] L_xd_x, DTYPE_t[:,:,:] L_xd_xd):' % func_postfix

    lines = []
    lines += cdef_params
    lines += [(1, '')]
    lines += [(1, 'for i in range(Nt):')]
    lines += [(2, l) for l in code_L_x_x]
    lines += [(2, l) for l in code_L_xd_x]
    lines += [(2, l) for l in code_L_xd_xd]
    
    return function_formatter(function_name, lines)

_compute_hessL_OM = get_hessL_function(code_L_x_x_OM, code_L_xd_x_OM, code_L_xd_xd_OM, cdef_hessL_OM, 'OM')
_compute_hessL_FW = get_hessL_function(code_L_x_x_FW, code_L_xd_x_FW, code_L_xd_xd_FW, cdef_hessL_FW, 'FW')

# %%
def get_dot_L_xd_x_function(code_dot_L_xd_x, cdef_params, func_postfix):
    function_name = 'cdef DTYPE_t _compute_dot_L_xd_x_%s(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] dot_L_dx_x):' % func_postfix

    lines = []
    lines += cdef_params
    lines += [(1, '')]
    lines += [(1, 'for i in range(Nt):')]
    lines += [(2, l) for l in code_dot_L_xd_x]
    
    return function_formatter(function_name, lines)

_compute_dot_L_xd_x_OM = get_dot_L_xd_x_function(code_dot_L_xd_x_OM, cdef_dot_L_xd_x_OM, 'OM')
_compute_dot_L_xd_x_FW = get_dot_L_xd_x_function(code_dot_L_xd_x_FW, cdef_dot_L_xd_x_FW, 'FW')

# %%
print('\n\n'.join([
    _compute_potential,
    _compute_force,
    _compute_force_and_div_force,
    _compute_gradL_OM,
    _compute_gradL_FW,
    _compute_hessL_OM,
    _compute_hessL_FW,
    _compute_dot_L_xd_x_OM,
    _compute_dot_L_xd_x_FW,
]))
# Out:
# cdef DTYPE_t _compute_potential(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:] potential):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         potential[i] = 0.5*pow(r - 1.0, 2)*(3.0*U0*pow(r, 2)*(xip + 2.0 + xim*x[1,i]/r) - 2.0*U0*(r - 1.0)*(3.0*r + 1.0))
#
# cdef DTYPE_t _compute_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         force[0,i] = 0.5*U0*x[0,i]*(r - 1.0)*(-6.0*r*(r*(xip + 2.0) + xim*x[1,i]) + 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(-6.0*r*(xip + 2.0) + 12.0*r - 3.0*xim*x[1,i] - 4.0))/r
#         force[1,i] = 0.5*U0*(r - 1.0)*(2.0*x[1,i]*(-3.0*r*(r*(xip + 2.0) + xim*x[1,i]) + 2.0*(r - 1.0)*(3.0*r + 1.0)) + (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) + 2.0*x[1,i]*(-3.0*r*(xip + 2.0) + 6.0*r - 3.0*xim*x[1,i] - 2.0)))/r
#
# cdef DTYPE_t _compute_force_and_div_force(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] force, DTYPE_t[:] div_force):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         force[0,i] = 0.5*U0*x[0,i]*(r - 1.0)*(-6.0*r*(r*(xip + 2.0) + xim*x[1,i]) + 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(-6.0*r*(xip + 2.0) + 12.0*r - 3.0*xim*x[1,i] - 4.0))/r
#         force[1,i] = 0.5*U0*(r - 1.0)*(2.0*x[1,i]*(-3.0*r*(r*(xip + 2.0) + xim*x[1,i]) + 2.0*(r - 1.0)*(3.0*r + 1.0)) + (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) + 2.0*x[1,i]*(-3.0*r*(xip + 2.0) + 6.0*r - 3.0*xim*x[1,i] - 2.0)))/r
#         div_force[i] = -12.0*U0*pow(r, 2)*xip - 18.0*U0*r*xim*x[1,i] + 18.0*U0*r*xip - 12.0*U0*r - 12.0*U0*pow(x[0,i], 2)*xip + 24.0*U0*xim*x[1,i] - 12.0*U0*xip*pow(x[1,i], 2) - 6.0*U0*xip + 12.0*U0 - 4.5*U0*pow(x[0,i], 2)*xim*x[1,i]/r + 9.0*U0*pow(x[0,i], 2)*xip/r - 6.0*U0*pow(x[0,i], 2)/r - 4.5*U0*xim*pow(x[1,i], 3)/r - 6.0*U0*xim*x[1,i]/r + 9.0*U0*xip*pow(x[1,i], 2)/r - 6.0*U0*pow(x[1,i], 2)/r + 1.5*U0*pow(x[0,i], 2)*xim*x[1,i]/pow(r, 3) + 1.5*U0*xim*pow(x[1,i], 3)/pow(r, 3)
#
# cdef DTYPE_t _compute_gradL_OM(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:] L_x, DTYPE_t[:,:] L_xd):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         L_x[0,i] = 0.0625*(r*(beta*x[0,i]*(4.0*pow(0.5*U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + gamma*r*xd[1,i], 2) + 4.0*pow(0.5*U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + gamma*r*xd[0,i], 2)) + 2.0*r*(-12.0*U0*x[0,i]*(pow(r, 2)*(3.0*xim*x[1,i] - 6.0*xip + 4.0) + 2.0*pow(r, 2)*(8.0*r*xip + 3.0*xim*x[1,i] - 3.0*xip + 2.0) + 6.0*r*(2.0*pow(r, 2)*xip + 3.0*r*xim*x[1,i] - 3.0*r*xip + 2.0*r + 2.0*pow(x[0,i], 2)*xip - 4.0*xim*x[1,i] + 2.0*xip*pow(x[1,i], 2) + xip - 2.0) + 3.0*pow(x[0,i], 2)*xim*x[1,i] - 6.0*pow(x[0,i], 2)*xip + 4.0*pow(x[0,i], 2) + 3.0*xim*pow(x[1,i], 3) + 3.0*xim*x[1,i] - 6.0*xip*pow(x[1,i], 2) + 4.0*pow(x[1,i], 2)) + beta*(x[0,i]*(U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*r*xd[1,i])*(U0*(r - 1.0)*(-3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) + 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0) + 2.0*x[1,i]*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0) + 6.0*(r - 1.0)*(r*xim + xip*x[1,i])) + U0*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*xd[1,i]) + (U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*r*xd[0,i])*(U0*r*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 3.0*U0*pow(x[0,i], 2)*(r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 2.0*xip*(r - 1.0) + 4.0) + U0*pow(x[0,i], 2)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*x[0,i]*xd[0,i])))) + 3.0*x[0,i]*(12.0*U0*(4.0*pow(r, 3)*(2.0*pow(r, 2)*xip + 3.0*r*xim*x[1,i] - 3.0*r*xip + 2.0*r + 2.0*pow(x[0,i], 2)*xip - 4.0*xim*x[1,i] + 2.0*xip*pow(x[1,i], 2) + xip - 2.0) - pow(r, 2)*xim*x[1,i] + pow(r, 2)*(3.0*pow(x[0,i], 2)*xim*x[1,i] - 6.0*pow(x[0,i], 2)*xip + 4.0*pow(x[0,i], 2) + 3.0*xim*pow(x[1,i], 3) + 4.0*xim*x[1,i] - 6.0*xip*pow(x[1,i], 2) + 4.0*pow(x[1,i], 2))) - beta*r*(4.0*pow(0.5*U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + gamma*r*xd[1,i], 2) + 4.0*pow(0.5*U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + gamma*r*xd[0,i], 2))))/(gamma*pow(r, 5))
#         L_x[1,i] = 0.0625*(r*(beta*x[1,i]*(4.0*pow(0.5*U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + gamma*r*xd[1,i], 2) + 4.0*pow(0.5*U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + gamma*r*xd[0,i], 2)) + 2.0*r*(-6.0*U0*(-pow(r, 2)*xim + 4.0*pow(r, 2)*(r*(3.0*r*xim - 4.0*xim + 8.0*xip*x[1,i]) + 3.0*xim*pow(x[1,i], 2) - 3.0*xip*x[1,i] + 2.0*x[1,i]) + pow(r, 2)*(3.0*pow(x[0,i], 2)*xim + 9.0*xim*pow(x[1,i], 2) + 4.0*xim - 12.0*xip*x[1,i] + 8.0*x[1,i]) + 12.0*r*x[1,i]*(2.0*pow(r, 2)*xip + 3.0*r*xim*x[1,i] - 3.0*r*xip + 2.0*r + 2.0*pow(x[0,i], 2)*xip - 4.0*xim*x[1,i] + 2.0*xip*pow(x[1,i], 2) + xip - 2.0) - 2.0*xim*pow(x[1,i], 2) + 2.0*x[1,i]*(3.0*pow(x[0,i], 2)*xim*x[1,i] - 6.0*pow(x[0,i], 2)*xip + 4.0*pow(x[0,i], 2) + 3.0*xim*pow(x[1,i], 3) + 4.0*xim*x[1,i] - 6.0*xip*pow(x[1,i], 2) + 4.0*pow(x[1,i], 2))) + beta*((U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*r*xd[1,i])*(U0*x[1,i]*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + U0*(r - 1.0)*(2.0*r*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - x[1,i]*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0)) + 2.0*x[1,i]*(3.0*r*(r*xim + x[1,i]*(xip + 2.0)) - 6.0*x[1,i]*(r - 1.0) - 2.0*x[1,i]*(3.0*r + 1.0) + 3.0*x[1,i]*(r*(xip + 2.0) + xim*x[1,i])) + 2.0*(r - 1.0)*(r*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0) + 3.0*x[1,i]*(r*xim + x[1,i]*(xip + 2.0) - 2.0*x[1,i]))) + 2.0*gamma*x[1,i]*xd[1,i]) + (U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*r*xd[0,i])*(U0*x[0,i]*x[1,i]*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + U0*x[0,i]*(r - 1.0)*(6.0*r*(r*xim + x[1,i]*(xip + 2.0)) - 12.0*x[1,i]*(r - 1.0) - 4.0*x[1,i]*(3.0*r + 1.0) + 6.0*x[1,i]*(r*(xip + 2.0) + xim*x[1,i]) + x[1,i]*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0) + 3.0*(r - 1.0)*(r*xim + 2.0*x[1,i]*(xip + 2.0) - 4.0*x[1,i])) + 2.0*gamma*xd[0,i]*x[1,i])))) + 3.0*x[1,i]*(12.0*U0*(4.0*pow(r, 3)*(2.0*pow(r, 2)*xip + 3.0*r*xim*x[1,i] - 3.0*r*xip + 2.0*r + 2.0*pow(x[0,i], 2)*xip - 4.0*xim*x[1,i] + 2.0*xip*pow(x[1,i], 2) + xip - 2.0) - pow(r, 2)*xim*x[1,i] + pow(r, 2)*(3.0*pow(x[0,i], 2)*xim*x[1,i] - 6.0*pow(x[0,i], 2)*xip + 4.0*pow(x[0,i], 2) + 3.0*xim*pow(x[1,i], 3) + 4.0*xim*x[1,i] - 6.0*xip*pow(x[1,i], 2) + 4.0*pow(x[1,i], 2))) - beta*r*(4.0*pow(0.5*U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + gamma*r*xd[1,i], 2) + 4.0*pow(0.5*U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + gamma*r*xd[0,i], 2))))/(gamma*pow(r, 5))
#         L_xd[0,i] = 0.25*beta*(U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*r*xd[0,i])/r
#         L_xd[1,i] = 0.25*beta*(U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*r*xd[1,i])/r
#
# cdef DTYPE_t _compute_gradL_FW(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:] L_x, DTYPE_t[:,:] L_xd):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         L_x[0,i] = 0.125*beta*(r*(x[0,i]*(U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*r*xd[1,i])*(U0*(r - 1.0)*(-3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) + 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0) + 2.0*x[1,i]*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0) + 6.0*(r - 1.0)*(r*xim + xip*x[1,i])) + U0*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*xd[1,i]) + (U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*r*xd[0,i])*(U0*r*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 3.0*U0*pow(x[0,i], 2)*(r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 2.0*xip*(r - 1.0) + 4.0) + U0*pow(x[0,i], 2)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*x[0,i]*xd[0,i])) - x[0,i]*(4.0*pow(0.5*U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + gamma*r*xd[1,i], 2) + 4.0*pow(0.5*U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + gamma*r*xd[0,i], 2)))/(gamma*pow(r, 4))
#         L_x[1,i] = 0.125*beta*(r*((U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*r*xd[1,i])*(U0*x[1,i]*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + U0*(r - 1.0)*(2.0*r*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - x[1,i]*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0)) + 2.0*x[1,i]*(3.0*r*(r*xim + x[1,i]*(xip + 2.0)) - 6.0*x[1,i]*(r - 1.0) - 2.0*x[1,i]*(3.0*r + 1.0) + 3.0*x[1,i]*(r*(xip + 2.0) + xim*x[1,i])) + 2.0*(r - 1.0)*(r*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0) + 3.0*x[1,i]*(r*xim + x[1,i]*(xip + 2.0) - 2.0*x[1,i]))) + 2.0*gamma*x[1,i]*xd[1,i]) + (U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*r*xd[0,i])*(U0*x[0,i]*x[1,i]*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + U0*x[0,i]*(r - 1.0)*(6.0*r*(r*xim + x[1,i]*(xip + 2.0)) - 12.0*x[1,i]*(r - 1.0) - 4.0*x[1,i]*(3.0*r + 1.0) + 6.0*x[1,i]*(r*(xip + 2.0) + xim*x[1,i]) + x[1,i]*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0) + 3.0*(r - 1.0)*(r*xim + 2.0*x[1,i]*(xip + 2.0) - 4.0*x[1,i])) + 2.0*gamma*xd[0,i]*x[1,i])) - x[1,i]*(4.0*pow(0.5*U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + gamma*r*xd[1,i], 2) + 4.0*pow(0.5*U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + gamma*r*xd[0,i], 2)))/(gamma*pow(r, 4))
#         L_xd[0,i] = 0.25*beta*(U0*x[0,i]*(r - 1.0)*(6.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 4.0*(r - 1.0)*(3.0*r + 1.0) + (r - 1.0)*(6.0*r*(xip + 2.0) - 12.0*r + 3.0*xim*x[1,i] + 4.0)) + 2.0*gamma*r*xd[0,i])/r
#         L_xd[1,i] = 0.25*beta*(U0*(r - 1.0)*(2.0*x[1,i]*(3.0*r*(r*(xip + 2.0) + xim*x[1,i]) - 2.0*(r - 1.0)*(3.0*r + 1.0)) - (r - 1.0)*(3.0*xim*(-pow(r, 2) + pow(x[1,i], 2)) - 2.0*x[1,i]*(3.0*r*(xip + 2.0) - 6.0*r + 3.0*xim*x[1,i] + 2.0))) + 2.0*gamma*r*xd[1,i])/r
#
# cdef DTYPE_t _compute_hessL_OM(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] L_x_x, DTYPE_t[:,:,:] L_xd_x, DTYPE_t[:,:,:] L_xd_xd):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         L_x_x[0,0,i] = 0.375*U0*(9.0*U0*beta*pow(r, 11)*pow(xim, 2) + 48.0*U0*beta*pow(r, 11)*pow(xip, 2) - 30.0*U0*beta*pow(r, 10)*pow(xim, 2) + 132.0*U0*beta*pow(r, 10)*xim*xip*x[1,i] - 144.0*U0*beta*pow(r, 10)*pow(xip, 2) + 96.0*U0*beta*pow(r, 10)*xip + 36.0*U0*beta*pow(r, 9)*pow(x[0,i], 2)*pow(xim, 2) + 480.0*U0*beta*pow(r, 9)*pow(x[0,i], 2)*pow(xip, 2) + 63.0*U0*beta*pow(r, 9)*pow(xim, 2)*pow(x[1,i], 2) + 36.0*U0*beta*pow(r, 9)*pow(xim, 2) - 372.0*U0*beta*pow(r, 9)*xim*xip*x[1,i] + 120.0*U0*beta*pow(r, 9)*xim*x[1,i] + 96.0*U0*beta*pow(r, 9)*pow(xip, 2)*pow(x[1,i], 2) + 156.0*U0*beta*pow(r, 9)*pow(xip, 2) - 240.0*U0*beta*pow(r, 9)*xip + 48.0*U0*beta*pow(r, 9) - 90.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*pow(xim, 2) + 720.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*xim*xip*x[1,i] - 1080.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*pow(xip, 2) + 720.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*xip - 162.0*U0*beta*pow(r, 8)*pow(xim, 2)*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 8)*pow(xim, 2) + 108.0*U0*beta*pow(r, 8)*xim*xip*pow(x[1,i], 3) + 366.0*U0*beta*pow(r, 8)*xim*xip*x[1,i] - 276.0*U0*beta*pow(r, 8)*xim*x[1,i] - 216.0*U0*beta*pow(r, 8)*pow(xip, 2)*pow(x[1,i], 2) - 72.0*U0*beta*pow(r, 8)*pow(xip, 2) + 144.0*U0*beta*pow(r, 8)*xip*pow(x[1,i], 2) + 192.0*U0*beta*pow(r, 8)*xip - 96.0*U0*beta*pow(r, 8) + 192.0*U0*beta*pow(r, 7)*pow(x[0,i], 4)*pow(xip, 2) + 207.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) + 72.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xim, 2) - 1356.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*xim*xip*x[1,i] + 456.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*xim*x[1,i] + 192.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) + 780.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xip, 2) - 1200.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*xip + 240.0*U0*beta*pow(r, 7)*pow(x[0,i], 2) + 27.0*U0*beta*pow(r, 7)*pow(x[1,i], 4)*pow(xim, 2) + 138.0*U0*beta*pow(r, 7)*pow(xim, 2)*pow(x[1,i], 2) + 3.0*U0*beta*pow(r, 7)*pow(xim, 2) - 204.0*U0*beta*pow(r, 7)*xim*xip*pow(x[1,i], 3) - 144.0*U0*beta*pow(r, 7)*xim*xip*x[1,i] + 72.0*U0*beta*pow(r, 7)*xim*pow(x[1,i], 3) + 192.0*U0*beta*pow(r, 7)*xim*x[1,i] + 156.0*U0*beta*pow(r, 7)*pow(xip, 2)*pow(x[1,i], 2) + 12.0*U0*beta*pow(r, 7)*pow(xip, 2) - 240.0*U0*beta*pow(r, 7)*xip*pow(x[1,i], 2) - 48.0*U0*beta*pow(r, 7)*xip + 48.0*U0*beta*pow(r, 7)*pow(x[1,i], 2) + 48.0*U0*beta*pow(r, 7) + 108.0*U0*beta*pow(r, 6)*pow(x[0,i], 4)*xim*xip*x[1,i] - 216.0*U0*beta*pow(r, 6)*pow(x[0,i], 4)*pow(xip, 2) + 144.0*U0*beta*pow(r, 6)*pow(x[0,i], 4)*xip - 270.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2) + 108.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) + 672.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xim*xip*x[1,i] - 528.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xim*x[1,i] - 216.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 180.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2) + 144.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xip*pow(x[1,i], 2) + 480.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xip - 240.0*U0*beta*pow(r, 6)*pow(x[0,i], 2) - 36.0*U0*beta*pow(r, 6)*pow(x[1,i], 4)*pow(xim, 2) - 42.0*U0*beta*pow(r, 6)*pow(xim, 2)*pow(x[1,i], 2) + 102.0*U0*beta*pow(r, 6)*xim*xip*pow(x[1,i], 3) + 18.0*U0*beta*pow(r, 6)*xim*xip*x[1,i] - 84.0*U0*beta*pow(r, 6)*xim*pow(x[1,i], 3) - 36.0*U0*beta*pow(r, 6)*xim*x[1,i] - 36.0*U0*beta*pow(r, 6)*pow(xip, 2)*pow(x[1,i], 2) + 96.0*U0*beta*pow(r, 6)*xip*pow(x[1,i], 2) - 48.0*U0*beta*pow(r, 6)*pow(x[1,i], 2) + 3.0*U0*beta*pow(r, 5)*pow(xim, 2)*pow(x[1,i], 2) + 36.0*U0*beta*pow(r, 4)*pow(x[0,i], 4)*pow(xim, 2)*pow(x[1,i], 2) - 102.0*U0*beta*pow(r, 4)*pow(x[0,i], 4)*xim*xip*x[1,i] + 84.0*U0*beta*pow(r, 4)*pow(x[0,i], 4)*xim*x[1,i] + 36.0*U0*beta*pow(r, 4)*pow(x[0,i], 4)*pow(xip, 2) - 96.0*U0*beta*pow(r, 4)*pow(x[0,i], 4)*xip + 48.0*U0*beta*pow(r, 4)*pow(x[0,i], 4) + 36.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*pow(x[1,i], 4)*pow(xim, 2) + 78.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 102.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) -  ...
#         L_x_x[0,1,i] = 0.75*U0*(66.0*U0*beta*pow(r, 10)*x[0,i]*xim*xip + 81.0*U0*beta*pow(r, 9)*x[0,i]*pow(xim, 2)*x[1,i] - 186.0*U0*beta*pow(r, 9)*x[0,i]*xim*xip + 60.0*U0*beta*pow(r, 9)*x[0,i]*xim + 192.0*U0*beta*pow(r, 9)*x[0,i]*pow(xip, 2)*x[1,i] + 54.0*U0*beta*pow(r, 8)*pow(x[0,i], 3)*xim*xip - 207.0*U0*beta*pow(r, 8)*x[0,i]*pow(xim, 2)*x[1,i] + 360.0*U0*beta*pow(r, 8)*x[0,i]*xim*xip*pow(x[1,i], 2) + 183.0*U0*beta*pow(r, 8)*x[0,i]*xim*xip - 138.0*U0*beta*pow(r, 8)*x[0,i]*xim - 432.0*U0*beta*pow(r, 8)*x[0,i]*pow(xip, 2)*x[1,i] + 288.0*U0*beta*pow(r, 8)*x[0,i]*xip*x[1,i] + 27.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 102.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*xim*xip + 36.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*xim + 96.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 117.0*U0*beta*pow(r, 7)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) + 174.0*U0*beta*pow(r, 7)*x[0,i]*pow(xim, 2)*x[1,i] - 678.0*U0*beta*pow(r, 7)*x[0,i]*xim*xip*pow(x[1,i], 2) - 72.0*U0*beta*pow(r, 7)*x[0,i]*xim*xip + 228.0*U0*beta*pow(r, 7)*x[0,i]*xim*pow(x[1,i], 2) + 96.0*U0*beta*pow(r, 7)*x[0,i]*xim + 96.0*U0*beta*pow(r, 7)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) + 312.0*U0*beta*pow(r, 7)*x[0,i]*pow(xip, 2)*x[1,i] - 480.0*U0*beta*pow(r, 7)*x[0,i]*xip*x[1,i] + 96.0*U0*beta*pow(r, 7)*x[0,i]*x[1,i] - 36.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] + 54.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) + 51.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xim*xip - 42.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xim - 108.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 72.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xip*x[1,i] - 153.0*U0*beta*pow(r, 6)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*beta*pow(r, 6)*x[0,i]*pow(xim, 2)*x[1,i] + 54.0*U0*beta*pow(r, 6)*x[0,i]*pow(x[1,i], 4)*xim*xip + 336.0*U0*beta*pow(r, 6)*x[0,i]*xim*xip*pow(x[1,i], 2) + 9.0*U0*beta*pow(r, 6)*x[0,i]*xim*xip - 264.0*U0*beta*pow(r, 6)*x[0,i]*xim*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 6)*x[0,i]*xim - 108.0*U0*beta*pow(r, 6)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 72.0*U0*beta*pow(r, 6)*x[0,i]*pow(xip, 2)*x[1,i] + 72.0*U0*beta*pow(r, 6)*x[0,i]*xip*pow(x[1,i], 3) + 192.0*U0*beta*pow(r, 6)*x[0,i]*xip*x[1,i] - 96.0*U0*beta*pow(r, 6)*x[0,i]*x[1,i] + 3.0*U0*beta*pow(r, 5)*x[0,i]*pow(xim, 2)*x[1,i] + 18.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 12.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 51.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 3.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim*xip + 42.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim*pow(x[1,i], 2) + 6.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim + 18.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] - 48.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xip*x[1,i] + 24.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*x[1,i] + 18.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 45.0*U0*beta*pow(r, 4)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*beta*pow(r, 4)*x[0,i]*xim*xip*pow(x[1,i], 2) + 42.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 4)*xim + 36.0*U0*beta*pow(r, 4)*x[0,i]*xim*pow(x[1,i], 2) + 18.0*U0*beta*pow(r, 4)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 48.0*U0*beta*pow(r, 4)*x[0,i]*xip*pow(x[1,i], 3) + 24.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 3) - 3.0*U0*beta*pow(r, 3)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 9.0*U0*beta*pow(r, 3)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 18.0*U0*beta*pow(r, 2)*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 9.0*U0*beta*pow(r, 2)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 2)*pow(x[0,i], 3)*xim*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 2)*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 9.0*U0*beta*pow(r, 2)*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*beta*pow(r, 2)*x[0,i]*pow(x[1,i], 4)*xim + 6.0*U0*beta*r*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 6.0*U0*beta*r*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 3.0*beta*gamma*pow(r, 8)*xd[0,i]*xim + 8.0*beta*gamma*pow(r, 7)*x[0,i]*xip*xd[1,i] - 4.0*beta*gamma*pow(r, 7)*xd[0,i]*xim + 8.0*beta*gamma*pow(r, 7)*xd[0,i]*xip*x[1,i] + 3.0*beta*gamma*pow( ...
#         L_x_x[1,0,i] = 0.75*U0*(66.0*U0*beta*pow(r, 10)*x[0,i]*xim*xip + 81.0*U0*beta*pow(r, 9)*x[0,i]*pow(xim, 2)*x[1,i] - 186.0*U0*beta*pow(r, 9)*x[0,i]*xim*xip + 60.0*U0*beta*pow(r, 9)*x[0,i]*xim + 192.0*U0*beta*pow(r, 9)*x[0,i]*pow(xip, 2)*x[1,i] + 54.0*U0*beta*pow(r, 8)*pow(x[0,i], 3)*xim*xip - 207.0*U0*beta*pow(r, 8)*x[0,i]*pow(xim, 2)*x[1,i] + 360.0*U0*beta*pow(r, 8)*x[0,i]*xim*xip*pow(x[1,i], 2) + 183.0*U0*beta*pow(r, 8)*x[0,i]*xim*xip - 138.0*U0*beta*pow(r, 8)*x[0,i]*xim - 432.0*U0*beta*pow(r, 8)*x[0,i]*pow(xip, 2)*x[1,i] + 288.0*U0*beta*pow(r, 8)*x[0,i]*xip*x[1,i] + 27.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 102.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*xim*xip + 36.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*xim + 96.0*U0*beta*pow(r, 7)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 117.0*U0*beta*pow(r, 7)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) + 174.0*U0*beta*pow(r, 7)*x[0,i]*pow(xim, 2)*x[1,i] - 678.0*U0*beta*pow(r, 7)*x[0,i]*xim*xip*pow(x[1,i], 2) - 72.0*U0*beta*pow(r, 7)*x[0,i]*xim*xip + 228.0*U0*beta*pow(r, 7)*x[0,i]*xim*pow(x[1,i], 2) + 96.0*U0*beta*pow(r, 7)*x[0,i]*xim + 96.0*U0*beta*pow(r, 7)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) + 312.0*U0*beta*pow(r, 7)*x[0,i]*pow(xip, 2)*x[1,i] - 480.0*U0*beta*pow(r, 7)*x[0,i]*xip*x[1,i] + 96.0*U0*beta*pow(r, 7)*x[0,i]*x[1,i] - 36.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] + 54.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) + 51.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xim*xip - 42.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xim - 108.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 72.0*U0*beta*pow(r, 6)*pow(x[0,i], 3)*xip*x[1,i] - 153.0*U0*beta*pow(r, 6)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*beta*pow(r, 6)*x[0,i]*pow(xim, 2)*x[1,i] + 54.0*U0*beta*pow(r, 6)*x[0,i]*pow(x[1,i], 4)*xim*xip + 336.0*U0*beta*pow(r, 6)*x[0,i]*xim*xip*pow(x[1,i], 2) + 9.0*U0*beta*pow(r, 6)*x[0,i]*xim*xip - 264.0*U0*beta*pow(r, 6)*x[0,i]*xim*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 6)*x[0,i]*xim - 108.0*U0*beta*pow(r, 6)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 72.0*U0*beta*pow(r, 6)*x[0,i]*pow(xip, 2)*x[1,i] + 72.0*U0*beta*pow(r, 6)*x[0,i]*xip*pow(x[1,i], 3) + 192.0*U0*beta*pow(r, 6)*x[0,i]*xip*x[1,i] - 96.0*U0*beta*pow(r, 6)*x[0,i]*x[1,i] + 3.0*U0*beta*pow(r, 5)*x[0,i]*pow(xim, 2)*x[1,i] + 18.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 12.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 51.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 3.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim*xip + 42.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim*pow(x[1,i], 2) + 6.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xim + 18.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] - 48.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*xip*x[1,i] + 24.0*U0*beta*pow(r, 4)*pow(x[0,i], 3)*x[1,i] + 18.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 45.0*U0*beta*pow(r, 4)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*beta*pow(r, 4)*x[0,i]*xim*xip*pow(x[1,i], 2) + 42.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 4)*xim + 36.0*U0*beta*pow(r, 4)*x[0,i]*xim*pow(x[1,i], 2) + 18.0*U0*beta*pow(r, 4)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 48.0*U0*beta*pow(r, 4)*x[0,i]*xip*pow(x[1,i], 3) + 24.0*U0*beta*pow(r, 4)*x[0,i]*pow(x[1,i], 3) - 3.0*U0*beta*pow(r, 3)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 9.0*U0*beta*pow(r, 3)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 18.0*U0*beta*pow(r, 2)*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 9.0*U0*beta*pow(r, 2)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 2)*pow(x[0,i], 3)*xim*pow(x[1,i], 2) - 18.0*U0*beta*pow(r, 2)*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 9.0*U0*beta*pow(r, 2)*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*beta*pow(r, 2)*x[0,i]*pow(x[1,i], 4)*xim + 6.0*U0*beta*r*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 6.0*U0*beta*r*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 3.0*beta*gamma*pow(r, 8)*xd[0,i]*xim + 8.0*beta*gamma*pow(r, 7)*x[0,i]*xip*xd[1,i] - 4.0*beta*gamma*pow(r, 7)*xd[0,i]*xim + 8.0*beta*gamma*pow(r, 7)*xd[0,i]*xip*x[1,i] + 3.0*beta*gamma*pow( ...
#         L_x_x[1,1,i] = 0.375*U0*(27.0*U0*beta*pow(r, 11)*pow(xim, 2) + 48.0*U0*beta*pow(r, 11)*pow(xip, 2) - 90.0*U0*beta*pow(r, 10)*pow(xim, 2) + 396.0*U0*beta*pow(r, 10)*xim*xip*x[1,i] - 144.0*U0*beta*pow(r, 10)*pow(xip, 2) + 96.0*U0*beta*pow(r, 10)*xip + 27.0*U0*beta*pow(r, 9)*pow(x[0,i], 2)*pow(xim, 2) + 96.0*U0*beta*pow(r, 9)*pow(x[0,i], 2)*pow(xip, 2) + 378.0*U0*beta*pow(r, 9)*pow(xim, 2)*pow(x[1,i], 2) + 108.0*U0*beta*pow(r, 9)*pow(xim, 2) - 1116.0*U0*beta*pow(r, 9)*xim*xip*x[1,i] + 360.0*U0*beta*pow(r, 9)*xim*x[1,i] + 480.0*U0*beta*pow(r, 9)*pow(xip, 2)*pow(x[1,i], 2) + 156.0*U0*beta*pow(r, 9)*pow(xip, 2) - 240.0*U0*beta*pow(r, 9)*xip + 48.0*U0*beta*pow(r, 9) - 72.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*pow(xim, 2) + 324.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*xim*xip*x[1,i] - 216.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*pow(xip, 2) + 144.0*U0*beta*pow(r, 8)*pow(x[0,i], 2)*xip - 972.0*U0*beta*pow(r, 8)*pow(xim, 2)*pow(x[1,i], 2) - 54.0*U0*beta*pow(r, 8)*pow(xim, 2) + 936.0*U0*beta*pow(r, 8)*xim*xip*pow(x[1,i], 3) + 1098.0*U0*beta*pow(r, 8)*xim*xip*x[1,i] - 828.0*U0*beta*pow(r, 8)*xim*x[1,i] - 1080.0*U0*beta*pow(r, 8)*pow(xip, 2)*pow(x[1,i], 2) - 72.0*U0*beta*pow(r, 8)*pow(xip, 2) + 720.0*U0*beta*pow(r, 8)*xip*pow(x[1,i], 2) + 192.0*U0*beta*pow(r, 8)*xip - 96.0*U0*beta*pow(r, 8) + 135.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) + 66.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xim, 2) - 612.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*xim*xip*x[1,i] + 216.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*xim*x[1,i] + 192.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) + 156.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*pow(xip, 2) - 240.0*U0*beta*pow(r, 7)*pow(x[0,i], 2)*xip + 48.0*U0*beta*pow(r, 7)*pow(x[0,i], 2) + 315.0*U0*beta*pow(r, 7)*pow(x[1,i], 4)*pow(xim, 2) + 828.0*U0*beta*pow(r, 7)*pow(xim, 2)*pow(x[1,i], 2) + 9.0*U0*beta*pow(r, 7)*pow(xim, 2) - 1764.0*U0*beta*pow(r, 7)*xim*xip*pow(x[1,i], 3) - 432.0*U0*beta*pow(r, 7)*xim*xip*x[1,i] + 600.0*U0*beta*pow(r, 7)*xim*pow(x[1,i], 3) + 576.0*U0*beta*pow(r, 7)*xim*x[1,i] + 192.0*U0*beta*pow(r, 7)*pow(x[1,i], 4)*pow(xip, 2) + 780.0*U0*beta*pow(r, 7)*pow(xip, 2)*pow(x[1,i], 2) + 12.0*U0*beta*pow(r, 7)*pow(xip, 2) - 1200.0*U0*beta*pow(r, 7)*xip*pow(x[1,i], 2) - 48.0*U0*beta*pow(r, 7)*xip + 240.0*U0*beta*pow(r, 7)*pow(x[1,i], 2) + 48.0*U0*beta*pow(r, 7) - 180.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 24.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2) + 108.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) + 306.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xim*xip*x[1,i] - 252.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xim*x[1,i] - 216.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 36.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2) + 144.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xip*pow(x[1,i], 2) + 96.0*U0*beta*pow(r, 6)*pow(x[0,i], 2)*xip - 48.0*U0*beta*pow(r, 6)*pow(x[0,i], 2) - 414.0*U0*beta*pow(r, 6)*pow(x[1,i], 4)*pow(xim, 2) - 252.0*U0*beta*pow(r, 6)*pow(xim, 2)*pow(x[1,i], 2) + 108.0*U0*beta*pow(r, 6)*pow(x[1,i], 5)*xim*xip + 876.0*U0*beta*pow(r, 6)*xim*xip*pow(x[1,i], 3) + 54.0*U0*beta*pow(r, 6)*xim*xip*x[1,i] - 696.0*U0*beta*pow(r, 6)*xim*pow(x[1,i], 3) - 108.0*U0*beta*pow(r, 6)*xim*x[1,i] - 216.0*U0*beta*pow(r, 6)*pow(x[1,i], 4)*pow(xip, 2) - 180.0*U0*beta*pow(r, 6)*pow(xip, 2)*pow(x[1,i], 2) + 144.0*U0*beta*pow(r, 6)*pow(x[1,i], 4)*xip + 480.0*U0*beta*pow(r, 6)*xip*pow(x[1,i], 2) - 240.0*U0*beta*pow(r, 6)*pow(x[1,i], 2) + 3.0*U0*beta*pow(r, 5)*pow(x[0,i], 2)*pow(xim, 2) + 18.0*U0*beta*pow(r, 5)*pow(xim, 2)*pow(x[1,i], 2) + 36.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*pow(x[1,i], 4)*pow(xim, 2) + 60.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 102.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) - 18.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*xim*xip*x[1,i] + 84.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*xim*pow(x[1,i], 3) + 36.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*xim*x[1,i] + 36.0*U0*beta*pow(r, 4)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 96.0*U0*beta*pow(r, 4) ...
#         L_xd_x[0,0,i] = 0.75*U0*beta*(4.0*pow(r, 5)*xip + 3.0*pow(r, 4)*xim*x[1,i] - 6.0*pow(r, 4)*xip + 4.0*pow(r, 4) + 8.0*pow(r, 3)*pow(x[0,i], 2)*xip - 4.0*pow(r, 3)*xim*x[1,i] + 2.0*pow(r, 3)*xip - 4.0*pow(r, 3) + 3.0*pow(r, 2)*pow(x[0,i], 2)*xim*x[1,i] - 6.0*pow(r, 2)*pow(x[0,i], 2)*xip + 4.0*pow(r, 2)*pow(x[0,i], 2) + pow(r, 2)*xim*x[1,i] - pow(x[0,i], 2)*xim*x[1,i])/pow(r, 3)
#         L_xd_x[0,1,i] = 0.75*U0*beta*x[0,i]*(3.0*pow(r, 4)*xim - 4.0*pow(r, 3)*xim + 8.0*pow(r, 3)*xip*x[1,i] + 3.0*pow(r, 2)*xim*pow(x[1,i], 2) + pow(r, 2)*xim - 6.0*pow(r, 2)*xip*x[1,i] + 4.0*pow(r, 2)*x[1,i] - xim*pow(x[1,i], 2))/pow(r, 3)
#         L_xd_x[1,0,i] = 0.75*U0*beta*x[0,i]*(3.0*pow(r, 4)*xim - 4.0*pow(r, 3)*xim + 8.0*pow(r, 3)*xip*x[1,i] + 3.0*pow(r, 2)*xim*pow(x[1,i], 2) + pow(r, 2)*xim - 6.0*pow(r, 2)*xip*x[1,i] + 4.0*pow(r, 2)*x[1,i] - xim*pow(x[1,i], 2))/pow(r, 3)
#         L_xd_x[1,1,i] = 0.75*U0*beta*(4.0*pow(r, 5)*xip + 9.0*pow(r, 4)*xim*x[1,i] - 6.0*pow(r, 4)*xip + 4.0*pow(r, 4) - 12.0*pow(r, 3)*xim*x[1,i] + 8.0*pow(r, 3)*xip*pow(x[1,i], 2) + 2.0*pow(r, 3)*xip - 4.0*pow(r, 3) + 3.0*pow(r, 2)*xim*pow(x[1,i], 3) + 3.0*pow(r, 2)*xim*x[1,i] - 6.0*pow(r, 2)*xip*pow(x[1,i], 2) + 4.0*pow(r, 2)*pow(x[1,i], 2) - xim*pow(x[1,i], 3))/pow(r, 3)
#         L_xd_xd[0,0,i] = 0.5*beta*gamma
#         L_xd_xd[0,1,i] = 0
#         L_xd_xd[1,0,i] = 0
#         L_xd_xd[1,1,i] = 0.5*beta*gamma
#
# cdef DTYPE_t _compute_hessL_FW(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] L_x_x, DTYPE_t[:,:,:] L_xd_x, DTYPE_t[:,:,:] L_xd_xd):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         L_x_x[0,0,i] = 0.375*U0*beta*(9.0*U0*pow(r, 10)*pow(xim, 2) + 48.0*U0*pow(r, 10)*pow(xip, 2) - 30.0*U0*pow(r, 9)*pow(xim, 2) + 132.0*U0*pow(r, 9)*xim*xip*x[1,i] - 144.0*U0*pow(r, 9)*pow(xip, 2) + 96.0*U0*pow(r, 9)*xip + 36.0*U0*pow(r, 8)*pow(x[0,i], 2)*pow(xim, 2) + 480.0*U0*pow(r, 8)*pow(x[0,i], 2)*pow(xip, 2) + 63.0*U0*pow(r, 8)*pow(xim, 2)*pow(x[1,i], 2) + 36.0*U0*pow(r, 8)*pow(xim, 2) - 372.0*U0*pow(r, 8)*xim*xip*x[1,i] + 120.0*U0*pow(r, 8)*xim*x[1,i] + 96.0*U0*pow(r, 8)*pow(xip, 2)*pow(x[1,i], 2) + 156.0*U0*pow(r, 8)*pow(xip, 2) - 240.0*U0*pow(r, 8)*xip + 48.0*U0*pow(r, 8) - 90.0*U0*pow(r, 7)*pow(x[0,i], 2)*pow(xim, 2) + 720.0*U0*pow(r, 7)*pow(x[0,i], 2)*xim*xip*x[1,i] - 1080.0*U0*pow(r, 7)*pow(x[0,i], 2)*pow(xip, 2) + 720.0*U0*pow(r, 7)*pow(x[0,i], 2)*xip - 162.0*U0*pow(r, 7)*pow(xim, 2)*pow(x[1,i], 2) - 18.0*U0*pow(r, 7)*pow(xim, 2) + 108.0*U0*pow(r, 7)*xim*xip*pow(x[1,i], 3) + 366.0*U0*pow(r, 7)*xim*xip*x[1,i] - 276.0*U0*pow(r, 7)*xim*x[1,i] - 216.0*U0*pow(r, 7)*pow(xip, 2)*pow(x[1,i], 2) - 72.0*U0*pow(r, 7)*pow(xip, 2) + 144.0*U0*pow(r, 7)*xip*pow(x[1,i], 2) + 192.0*U0*pow(r, 7)*xip - 96.0*U0*pow(r, 7) + 192.0*U0*pow(r, 6)*pow(x[0,i], 4)*pow(xip, 2) + 207.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) + 72.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2) - 1356.0*U0*pow(r, 6)*pow(x[0,i], 2)*xim*xip*x[1,i] + 456.0*U0*pow(r, 6)*pow(x[0,i], 2)*xim*x[1,i] + 192.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) + 780.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2) - 1200.0*U0*pow(r, 6)*pow(x[0,i], 2)*xip + 240.0*U0*pow(r, 6)*pow(x[0,i], 2) + 27.0*U0*pow(r, 6)*pow(x[1,i], 4)*pow(xim, 2) + 138.0*U0*pow(r, 6)*pow(xim, 2)*pow(x[1,i], 2) + 3.0*U0*pow(r, 6)*pow(xim, 2) - 204.0*U0*pow(r, 6)*xim*xip*pow(x[1,i], 3) - 144.0*U0*pow(r, 6)*xim*xip*x[1,i] + 72.0*U0*pow(r, 6)*xim*pow(x[1,i], 3) + 192.0*U0*pow(r, 6)*xim*x[1,i] + 156.0*U0*pow(r, 6)*pow(xip, 2)*pow(x[1,i], 2) + 12.0*U0*pow(r, 6)*pow(xip, 2) - 240.0*U0*pow(r, 6)*xip*pow(x[1,i], 2) - 48.0*U0*pow(r, 6)*xip + 48.0*U0*pow(r, 6)*pow(x[1,i], 2) + 48.0*U0*pow(r, 6) + 108.0*U0*pow(r, 5)*pow(x[0,i], 4)*xim*xip*x[1,i] - 216.0*U0*pow(r, 5)*pow(x[0,i], 4)*pow(xip, 2) + 144.0*U0*pow(r, 5)*pow(x[0,i], 4)*xip - 270.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 18.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xim, 2) + 108.0*U0*pow(r, 5)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) + 672.0*U0*pow(r, 5)*pow(x[0,i], 2)*xim*xip*x[1,i] - 528.0*U0*pow(r, 5)*pow(x[0,i], 2)*xim*x[1,i] - 216.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 180.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xip, 2) + 144.0*U0*pow(r, 5)*pow(x[0,i], 2)*xip*pow(x[1,i], 2) + 480.0*U0*pow(r, 5)*pow(x[0,i], 2)*xip - 240.0*U0*pow(r, 5)*pow(x[0,i], 2) - 36.0*U0*pow(r, 5)*pow(x[1,i], 4)*pow(xim, 2) - 42.0*U0*pow(r, 5)*pow(xim, 2)*pow(x[1,i], 2) + 102.0*U0*pow(r, 5)*xim*xip*pow(x[1,i], 3) + 18.0*U0*pow(r, 5)*xim*xip*x[1,i] - 84.0*U0*pow(r, 5)*xim*pow(x[1,i], 3) - 36.0*U0*pow(r, 5)*xim*x[1,i] - 36.0*U0*pow(r, 5)*pow(xip, 2)*pow(x[1,i], 2) + 96.0*U0*pow(r, 5)*xip*pow(x[1,i], 2) - 48.0*U0*pow(r, 5)*pow(x[1,i], 2) + 3.0*U0*pow(r, 4)*pow(xim, 2)*pow(x[1,i], 2) + 36.0*U0*pow(r, 3)*pow(x[0,i], 4)*pow(xim, 2)*pow(x[1,i], 2) - 102.0*U0*pow(r, 3)*pow(x[0,i], 4)*xim*xip*x[1,i] + 84.0*U0*pow(r, 3)*pow(x[0,i], 4)*xim*x[1,i] + 36.0*U0*pow(r, 3)*pow(x[0,i], 4)*pow(xip, 2) - 96.0*U0*pow(r, 3)*pow(x[0,i], 4)*xip + 48.0*U0*pow(r, 3)*pow(x[0,i], 4) + 36.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(x[1,i], 4)*pow(xim, 2) + 78.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 102.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) - 36.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*xip*x[1,i] + 84.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*pow(x[1,i], 3) + 72.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*x[1,i] + 36.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 96.0*U0*pow(r, 3)*pow(x[0,i], 2)*xip*pow(x[1,i], 2) + 48.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(x[1,i], 2) + 12.0*U0*pow(r, 3)*pow(x[1,i], 4)*pow(xim, 2) - 6.0*U0*pow(r, 3)*xim*xip*pow(x[1,i], 3) + 12.0*U0*pow(r, ...
#         L_x_x[0,1,i] = 0.75*U0*beta*(66.0*U0*pow(r, 9)*x[0,i]*xim*xip + 81.0*U0*pow(r, 8)*x[0,i]*pow(xim, 2)*x[1,i] - 186.0*U0*pow(r, 8)*x[0,i]*xim*xip + 60.0*U0*pow(r, 8)*x[0,i]*xim + 192.0*U0*pow(r, 8)*x[0,i]*pow(xip, 2)*x[1,i] + 54.0*U0*pow(r, 7)*pow(x[0,i], 3)*xim*xip - 207.0*U0*pow(r, 7)*x[0,i]*pow(xim, 2)*x[1,i] + 360.0*U0*pow(r, 7)*x[0,i]*xim*xip*pow(x[1,i], 2) + 183.0*U0*pow(r, 7)*x[0,i]*xim*xip - 138.0*U0*pow(r, 7)*x[0,i]*xim - 432.0*U0*pow(r, 7)*x[0,i]*pow(xip, 2)*x[1,i] + 288.0*U0*pow(r, 7)*x[0,i]*xip*x[1,i] + 27.0*U0*pow(r, 6)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 102.0*U0*pow(r, 6)*pow(x[0,i], 3)*xim*xip + 36.0*U0*pow(r, 6)*pow(x[0,i], 3)*xim + 96.0*U0*pow(r, 6)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 117.0*U0*pow(r, 6)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) + 174.0*U0*pow(r, 6)*x[0,i]*pow(xim, 2)*x[1,i] - 678.0*U0*pow(r, 6)*x[0,i]*xim*xip*pow(x[1,i], 2) - 72.0*U0*pow(r, 6)*x[0,i]*xim*xip + 228.0*U0*pow(r, 6)*x[0,i]*xim*pow(x[1,i], 2) + 96.0*U0*pow(r, 6)*x[0,i]*xim + 96.0*U0*pow(r, 6)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) + 312.0*U0*pow(r, 6)*x[0,i]*pow(xip, 2)*x[1,i] - 480.0*U0*pow(r, 6)*x[0,i]*xip*x[1,i] + 96.0*U0*pow(r, 6)*x[0,i]*x[1,i] - 36.0*U0*pow(r, 5)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] + 54.0*U0*pow(r, 5)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) + 51.0*U0*pow(r, 5)*pow(x[0,i], 3)*xim*xip - 42.0*U0*pow(r, 5)*pow(x[0,i], 3)*xim - 108.0*U0*pow(r, 5)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 72.0*U0*pow(r, 5)*pow(x[0,i], 3)*xip*x[1,i] - 153.0*U0*pow(r, 5)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*pow(r, 5)*x[0,i]*pow(xim, 2)*x[1,i] + 54.0*U0*pow(r, 5)*x[0,i]*pow(x[1,i], 4)*xim*xip + 336.0*U0*pow(r, 5)*x[0,i]*xim*xip*pow(x[1,i], 2) + 9.0*U0*pow(r, 5)*x[0,i]*xim*xip - 264.0*U0*pow(r, 5)*x[0,i]*xim*pow(x[1,i], 2) - 18.0*U0*pow(r, 5)*x[0,i]*xim - 108.0*U0*pow(r, 5)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 72.0*U0*pow(r, 5)*x[0,i]*pow(xip, 2)*x[1,i] + 72.0*U0*pow(r, 5)*x[0,i]*xip*pow(x[1,i], 3) + 192.0*U0*pow(r, 5)*x[0,i]*xip*x[1,i] - 96.0*U0*pow(r, 5)*x[0,i]*x[1,i] + 3.0*U0*pow(r, 4)*x[0,i]*pow(xim, 2)*x[1,i] + 18.0*U0*pow(r, 3)*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 12.0*U0*pow(r, 3)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 51.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 3.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim*xip + 42.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim*pow(x[1,i], 2) + 6.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim + 18.0*U0*pow(r, 3)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] - 48.0*U0*pow(r, 3)*pow(x[0,i], 3)*xip*x[1,i] + 24.0*U0*pow(r, 3)*pow(x[0,i], 3)*x[1,i] + 18.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 45.0*U0*pow(r, 3)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*pow(r, 3)*x[0,i]*xim*xip*pow(x[1,i], 2) + 42.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 4)*xim + 36.0*U0*pow(r, 3)*x[0,i]*xim*pow(x[1,i], 2) + 18.0*U0*pow(r, 3)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 48.0*U0*pow(r, 3)*x[0,i]*xip*pow(x[1,i], 3) + 24.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 3) - 3.0*U0*pow(r, 2)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 9.0*U0*pow(r, 2)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 18.0*U0*r*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 9.0*U0*r*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 18.0*U0*r*pow(x[0,i], 3)*xim*pow(x[1,i], 2) - 18.0*U0*r*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 9.0*U0*r*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*r*x[0,i]*pow(x[1,i], 4)*xim + 6.0*U0*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 6.0*U0*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 3.0*gamma*pow(r, 7)*xd[0,i]*xim + 8.0*gamma*pow(r, 6)*x[0,i]*xip*xd[1,i] - 4.0*gamma*pow(r, 6)*xd[0,i]*xim + 8.0*gamma*pow(r, 6)*xd[0,i]*xip*x[1,i] + 3.0*gamma*pow(r, 5)*pow(x[0,i], 2)*xd[0,i]*xim + 9.0*gamma*pow(r, 5)*x[0,i]*xim*x[1,i]*xd[1,i] - 6.0*gamma*pow(r, 5)*x[0,i]*xip*xd[1,i] + 4.0*gamma*pow(r, 5)*x[0,i]*xd[1,i] + 3.0*gamma*pow(r, 5)*xd[0,i]*xim*pow(x[1,i], 2) + gamma*pow(r, 5)*xd[0,i]*xim - 6.0*gamma*pow(r, 5)*xd[0,i]*xip*x[1,i] + 4.0*gamma*pow(r, 5)*xd[0,i]*x[1,i] - 3.0*gamma*pow(r, 3)*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) - gamma*pow(r, 3)*pow(x[0,i], 2)*xd[0,i]*xim + 6.0*gamma*p ...
#         L_x_x[1,0,i] = 0.75*U0*beta*(66.0*U0*pow(r, 9)*x[0,i]*xim*xip + 81.0*U0*pow(r, 8)*x[0,i]*pow(xim, 2)*x[1,i] - 186.0*U0*pow(r, 8)*x[0,i]*xim*xip + 60.0*U0*pow(r, 8)*x[0,i]*xim + 192.0*U0*pow(r, 8)*x[0,i]*pow(xip, 2)*x[1,i] + 54.0*U0*pow(r, 7)*pow(x[0,i], 3)*xim*xip - 207.0*U0*pow(r, 7)*x[0,i]*pow(xim, 2)*x[1,i] + 360.0*U0*pow(r, 7)*x[0,i]*xim*xip*pow(x[1,i], 2) + 183.0*U0*pow(r, 7)*x[0,i]*xim*xip - 138.0*U0*pow(r, 7)*x[0,i]*xim - 432.0*U0*pow(r, 7)*x[0,i]*pow(xip, 2)*x[1,i] + 288.0*U0*pow(r, 7)*x[0,i]*xip*x[1,i] + 27.0*U0*pow(r, 6)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 102.0*U0*pow(r, 6)*pow(x[0,i], 3)*xim*xip + 36.0*U0*pow(r, 6)*pow(x[0,i], 3)*xim + 96.0*U0*pow(r, 6)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 117.0*U0*pow(r, 6)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) + 174.0*U0*pow(r, 6)*x[0,i]*pow(xim, 2)*x[1,i] - 678.0*U0*pow(r, 6)*x[0,i]*xim*xip*pow(x[1,i], 2) - 72.0*U0*pow(r, 6)*x[0,i]*xim*xip + 228.0*U0*pow(r, 6)*x[0,i]*xim*pow(x[1,i], 2) + 96.0*U0*pow(r, 6)*x[0,i]*xim + 96.0*U0*pow(r, 6)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) + 312.0*U0*pow(r, 6)*x[0,i]*pow(xip, 2)*x[1,i] - 480.0*U0*pow(r, 6)*x[0,i]*xip*x[1,i] + 96.0*U0*pow(r, 6)*x[0,i]*x[1,i] - 36.0*U0*pow(r, 5)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] + 54.0*U0*pow(r, 5)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) + 51.0*U0*pow(r, 5)*pow(x[0,i], 3)*xim*xip - 42.0*U0*pow(r, 5)*pow(x[0,i], 3)*xim - 108.0*U0*pow(r, 5)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] + 72.0*U0*pow(r, 5)*pow(x[0,i], 3)*xip*x[1,i] - 153.0*U0*pow(r, 5)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*pow(r, 5)*x[0,i]*pow(xim, 2)*x[1,i] + 54.0*U0*pow(r, 5)*x[0,i]*pow(x[1,i], 4)*xim*xip + 336.0*U0*pow(r, 5)*x[0,i]*xim*xip*pow(x[1,i], 2) + 9.0*U0*pow(r, 5)*x[0,i]*xim*xip - 264.0*U0*pow(r, 5)*x[0,i]*xim*pow(x[1,i], 2) - 18.0*U0*pow(r, 5)*x[0,i]*xim - 108.0*U0*pow(r, 5)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 72.0*U0*pow(r, 5)*x[0,i]*pow(xip, 2)*x[1,i] + 72.0*U0*pow(r, 5)*x[0,i]*xip*pow(x[1,i], 3) + 192.0*U0*pow(r, 5)*x[0,i]*xip*x[1,i] - 96.0*U0*pow(r, 5)*x[0,i]*x[1,i] + 3.0*U0*pow(r, 4)*x[0,i]*pow(xim, 2)*x[1,i] + 18.0*U0*pow(r, 3)*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 12.0*U0*pow(r, 3)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 51.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 3.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim*xip + 42.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim*pow(x[1,i], 2) + 6.0*U0*pow(r, 3)*pow(x[0,i], 3)*xim + 18.0*U0*pow(r, 3)*pow(x[0,i], 3)*pow(xip, 2)*x[1,i] - 48.0*U0*pow(r, 3)*pow(x[0,i], 3)*xip*x[1,i] + 24.0*U0*pow(r, 3)*pow(x[0,i], 3)*x[1,i] + 18.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 45.0*U0*pow(r, 3)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 51.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*pow(r, 3)*x[0,i]*xim*xip*pow(x[1,i], 2) + 42.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 4)*xim + 36.0*U0*pow(r, 3)*x[0,i]*xim*pow(x[1,i], 2) + 18.0*U0*pow(r, 3)*x[0,i]*pow(xip, 2)*pow(x[1,i], 3) - 48.0*U0*pow(r, 3)*x[0,i]*xip*pow(x[1,i], 3) + 24.0*U0*pow(r, 3)*x[0,i]*pow(x[1,i], 3) - 3.0*U0*pow(r, 2)*pow(x[0,i], 3)*pow(xim, 2)*x[1,i] - 9.0*U0*pow(r, 2)*x[0,i]*pow(xim, 2)*pow(x[1,i], 3) - 18.0*U0*r*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 9.0*U0*r*pow(x[0,i], 3)*xim*xip*pow(x[1,i], 2) - 18.0*U0*r*pow(x[0,i], 3)*xim*pow(x[1,i], 2) - 18.0*U0*r*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 9.0*U0*r*x[0,i]*pow(x[1,i], 4)*xim*xip - 18.0*U0*r*x[0,i]*pow(x[1,i], 4)*xim + 6.0*U0*pow(x[0,i], 3)*pow(xim, 2)*pow(x[1,i], 3) + 6.0*U0*x[0,i]*pow(x[1,i], 5)*pow(xim, 2) + 3.0*gamma*pow(r, 7)*xd[0,i]*xim + 8.0*gamma*pow(r, 6)*x[0,i]*xip*xd[1,i] - 4.0*gamma*pow(r, 6)*xd[0,i]*xim + 8.0*gamma*pow(r, 6)*xd[0,i]*xip*x[1,i] + 3.0*gamma*pow(r, 5)*pow(x[0,i], 2)*xd[0,i]*xim + 9.0*gamma*pow(r, 5)*x[0,i]*xim*x[1,i]*xd[1,i] - 6.0*gamma*pow(r, 5)*x[0,i]*xip*xd[1,i] + 4.0*gamma*pow(r, 5)*x[0,i]*xd[1,i] + 3.0*gamma*pow(r, 5)*xd[0,i]*xim*pow(x[1,i], 2) + gamma*pow(r, 5)*xd[0,i]*xim - 6.0*gamma*pow(r, 5)*xd[0,i]*xip*x[1,i] + 4.0*gamma*pow(r, 5)*xd[0,i]*x[1,i] - 3.0*gamma*pow(r, 3)*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) - gamma*pow(r, 3)*pow(x[0,i], 2)*xd[0,i]*xim + 6.0*gamma*p ...
#         L_x_x[1,1,i] = 0.375*U0*beta*(27.0*U0*pow(r, 10)*pow(xim, 2) + 48.0*U0*pow(r, 10)*pow(xip, 2) - 90.0*U0*pow(r, 9)*pow(xim, 2) + 396.0*U0*pow(r, 9)*xim*xip*x[1,i] - 144.0*U0*pow(r, 9)*pow(xip, 2) + 96.0*U0*pow(r, 9)*xip + 27.0*U0*pow(r, 8)*pow(x[0,i], 2)*pow(xim, 2) + 96.0*U0*pow(r, 8)*pow(x[0,i], 2)*pow(xip, 2) + 378.0*U0*pow(r, 8)*pow(xim, 2)*pow(x[1,i], 2) + 108.0*U0*pow(r, 8)*pow(xim, 2) - 1116.0*U0*pow(r, 8)*xim*xip*x[1,i] + 360.0*U0*pow(r, 8)*xim*x[1,i] + 480.0*U0*pow(r, 8)*pow(xip, 2)*pow(x[1,i], 2) + 156.0*U0*pow(r, 8)*pow(xip, 2) - 240.0*U0*pow(r, 8)*xip + 48.0*U0*pow(r, 8) - 72.0*U0*pow(r, 7)*pow(x[0,i], 2)*pow(xim, 2) + 324.0*U0*pow(r, 7)*pow(x[0,i], 2)*xim*xip*x[1,i] - 216.0*U0*pow(r, 7)*pow(x[0,i], 2)*pow(xip, 2) + 144.0*U0*pow(r, 7)*pow(x[0,i], 2)*xip - 972.0*U0*pow(r, 7)*pow(xim, 2)*pow(x[1,i], 2) - 54.0*U0*pow(r, 7)*pow(xim, 2) + 936.0*U0*pow(r, 7)*xim*xip*pow(x[1,i], 3) + 1098.0*U0*pow(r, 7)*xim*xip*x[1,i] - 828.0*U0*pow(r, 7)*xim*x[1,i] - 1080.0*U0*pow(r, 7)*pow(xip, 2)*pow(x[1,i], 2) - 72.0*U0*pow(r, 7)*pow(xip, 2) + 720.0*U0*pow(r, 7)*xip*pow(x[1,i], 2) + 192.0*U0*pow(r, 7)*xip - 96.0*U0*pow(r, 7) + 135.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) + 66.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xim, 2) - 612.0*U0*pow(r, 6)*pow(x[0,i], 2)*xim*xip*x[1,i] + 216.0*U0*pow(r, 6)*pow(x[0,i], 2)*xim*x[1,i] + 192.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) + 156.0*U0*pow(r, 6)*pow(x[0,i], 2)*pow(xip, 2) - 240.0*U0*pow(r, 6)*pow(x[0,i], 2)*xip + 48.0*U0*pow(r, 6)*pow(x[0,i], 2) + 315.0*U0*pow(r, 6)*pow(x[1,i], 4)*pow(xim, 2) + 828.0*U0*pow(r, 6)*pow(xim, 2)*pow(x[1,i], 2) + 9.0*U0*pow(r, 6)*pow(xim, 2) - 1764.0*U0*pow(r, 6)*xim*xip*pow(x[1,i], 3) - 432.0*U0*pow(r, 6)*xim*xip*x[1,i] + 600.0*U0*pow(r, 6)*xim*pow(x[1,i], 3) + 576.0*U0*pow(r, 6)*xim*x[1,i] + 192.0*U0*pow(r, 6)*pow(x[1,i], 4)*pow(xip, 2) + 780.0*U0*pow(r, 6)*pow(xip, 2)*pow(x[1,i], 2) + 12.0*U0*pow(r, 6)*pow(xip, 2) - 1200.0*U0*pow(r, 6)*xip*pow(x[1,i], 2) - 48.0*U0*pow(r, 6)*xip + 240.0*U0*pow(r, 6)*pow(x[1,i], 2) + 48.0*U0*pow(r, 6) - 180.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 24.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xim, 2) + 108.0*U0*pow(r, 5)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) + 306.0*U0*pow(r, 5)*pow(x[0,i], 2)*xim*xip*x[1,i] - 252.0*U0*pow(r, 5)*pow(x[0,i], 2)*xim*x[1,i] - 216.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 36.0*U0*pow(r, 5)*pow(x[0,i], 2)*pow(xip, 2) + 144.0*U0*pow(r, 5)*pow(x[0,i], 2)*xip*pow(x[1,i], 2) + 96.0*U0*pow(r, 5)*pow(x[0,i], 2)*xip - 48.0*U0*pow(r, 5)*pow(x[0,i], 2) - 414.0*U0*pow(r, 5)*pow(x[1,i], 4)*pow(xim, 2) - 252.0*U0*pow(r, 5)*pow(xim, 2)*pow(x[1,i], 2) + 108.0*U0*pow(r, 5)*pow(x[1,i], 5)*xim*xip + 876.0*U0*pow(r, 5)*xim*xip*pow(x[1,i], 3) + 54.0*U0*pow(r, 5)*xim*xip*x[1,i] - 696.0*U0*pow(r, 5)*xim*pow(x[1,i], 3) - 108.0*U0*pow(r, 5)*xim*x[1,i] - 216.0*U0*pow(r, 5)*pow(x[1,i], 4)*pow(xip, 2) - 180.0*U0*pow(r, 5)*pow(xip, 2)*pow(x[1,i], 2) + 144.0*U0*pow(r, 5)*pow(x[1,i], 4)*xip + 480.0*U0*pow(r, 5)*xip*pow(x[1,i], 2) - 240.0*U0*pow(r, 5)*pow(x[1,i], 2) + 3.0*U0*pow(r, 4)*pow(x[0,i], 2)*pow(xim, 2) + 18.0*U0*pow(r, 4)*pow(xim, 2)*pow(x[1,i], 2) + 36.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(x[1,i], 4)*pow(xim, 2) + 60.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(xim, 2)*pow(x[1,i], 2) - 102.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*xip*pow(x[1,i], 3) - 18.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*xip*x[1,i] + 84.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*pow(x[1,i], 3) + 36.0*U0*pow(r, 3)*pow(x[0,i], 2)*xim*x[1,i] + 36.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(xip, 2)*pow(x[1,i], 2) - 96.0*U0*pow(r, 3)*pow(x[0,i], 2)*xip*pow(x[1,i], 2) + 48.0*U0*pow(r, 3)*pow(x[0,i], 2)*pow(x[1,i], 2) + 36.0*U0*pow(r, 3)*pow(x[1,i], 6)*pow(xim, 2) + 126.0*U0*pow(r, 3)*pow(x[1,i], 4)*pow(xim, 2) - 102.0*U0*pow(r, 3)*pow(x[1,i], 5)*xim*xip - 48.0*U0*pow(r, 3)*xim*xip*pow(x[1,i], 3) + 84.0*U0*pow(r, 3)*pow(x[1,i], 5)*xim + 96.0*U0*pow(r, 3)*xim*pow(x[1,i], 3) + 36.0*U0*pow(r, 3)*pow(x[1,i], 4)*pow(xip, 2) - 96.0*U0*pow(r, 3)*pow(x[1 ...
#         L_xd_x[0,0,i] = 0.75*U0*beta*(4.0*pow(r, 5)*xip + 3.0*pow(r, 4)*xim*x[1,i] - 6.0*pow(r, 4)*xip + 4.0*pow(r, 4) + 8.0*pow(r, 3)*pow(x[0,i], 2)*xip - 4.0*pow(r, 3)*xim*x[1,i] + 2.0*pow(r, 3)*xip - 4.0*pow(r, 3) + 3.0*pow(r, 2)*pow(x[0,i], 2)*xim*x[1,i] - 6.0*pow(r, 2)*pow(x[0,i], 2)*xip + 4.0*pow(r, 2)*pow(x[0,i], 2) + pow(r, 2)*xim*x[1,i] - pow(x[0,i], 2)*xim*x[1,i])/pow(r, 3)
#         L_xd_x[0,1,i] = 0.75*U0*beta*x[0,i]*(3.0*pow(r, 4)*xim - 4.0*pow(r, 3)*xim + 8.0*pow(r, 3)*xip*x[1,i] + 3.0*pow(r, 2)*xim*pow(x[1,i], 2) + pow(r, 2)*xim - 6.0*pow(r, 2)*xip*x[1,i] + 4.0*pow(r, 2)*x[1,i] - xim*pow(x[1,i], 2))/pow(r, 3)
#         L_xd_x[1,0,i] = 0.75*U0*beta*x[0,i]*(3.0*pow(r, 4)*xim - 4.0*pow(r, 3)*xim + 8.0*pow(r, 3)*xip*x[1,i] + 3.0*pow(r, 2)*xim*pow(x[1,i], 2) + pow(r, 2)*xim - 6.0*pow(r, 2)*xip*x[1,i] + 4.0*pow(r, 2)*x[1,i] - xim*pow(x[1,i], 2))/pow(r, 3)
#         L_xd_x[1,1,i] = 0.75*U0*beta*(4.0*pow(r, 5)*xip + 9.0*pow(r, 4)*xim*x[1,i] - 6.0*pow(r, 4)*xip + 4.0*pow(r, 4) - 12.0*pow(r, 3)*xim*x[1,i] + 8.0*pow(r, 3)*xip*pow(x[1,i], 2) + 2.0*pow(r, 3)*xip - 4.0*pow(r, 3) + 3.0*pow(r, 2)*xim*pow(x[1,i], 3) + 3.0*pow(r, 2)*xim*x[1,i] - 6.0*pow(r, 2)*xip*pow(x[1,i], 2) + 4.0*pow(r, 2)*pow(x[1,i], 2) - xim*pow(x[1,i], 3))/pow(r, 3)
#         L_xd_xd[0,0,i] = 0.5*beta*gamma
#         L_xd_xd[0,1,i] = 0
#         L_xd_xd[1,0,i] = 0
#         L_xd_xd[1,1,i] = 0.5*beta*gamma
#
# _compute_dot_L_xd_x_OM(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] dot_L_dx_x):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         dot_L_dx_x[0,0,i] = 0.75*U0*beta*(3.0*pow(r, 6)*xim*xd[1,i] + 24.0*pow(r, 5)*x[0,i]*xd[0,i]*xip - 4.0*pow(r, 5)*xim*xd[1,i] + 8.0*pow(r, 5)*xip*x[1,i]*xd[1,i] + 3.0*pow(r, 4)*pow(x[0,i], 2)*xim*xd[1,i] + 9.0*pow(r, 4)*x[0,i]*xd[0,i]*xim*x[1,i] - 18.0*pow(r, 4)*x[0,i]*xd[0,i]*xip + 12.0*pow(r, 4)*x[0,i]*xd[0,i] + 3.0*pow(r, 4)*xim*pow(x[1,i], 2)*xd[1,i] + pow(r, 4)*xim*xd[1,i] - 6.0*pow(r, 4)*xip*x[1,i]*xd[1,i] + 4.0*pow(r, 4)*x[1,i]*xd[1,i] - 3.0*pow(r, 2)*pow(x[0,i], 3)*xd[0,i]*xim*x[1,i] + 6.0*pow(r, 2)*pow(x[0,i], 3)*xd[0,i]*xip - 4.0*pow(r, 2)*pow(x[0,i], 3)*xd[0,i] - 3.0*pow(r, 2)*pow(x[0,i], 2)*xim*pow(x[1,i], 2)*xd[1,i] - pow(r, 2)*pow(x[0,i], 2)*xim*xd[1,i] + 6.0*pow(r, 2)*pow(x[0,i], 2)*xip*x[1,i]*xd[1,i] - 4.0*pow(r, 2)*pow(x[0,i], 2)*x[1,i]*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xd[0,i]*xim*x[1,i] - pow(r, 2)*xim*pow(x[1,i], 2)*xd[1,i] + 3.0*pow(x[0,i], 3)*xd[0,i]*xim*x[1,i] + 3.0*pow(x[0,i], 2)*xim*pow(x[1,i], 2)*xd[1,i])/pow(r, 5)
#         dot_L_dx_x[0,1,i] = 0.75*U0*beta*(3.0*pow(r, 6)*xd[0,i]*xim + 8.0*pow(r, 5)*x[0,i]*xip*xd[1,i] - 4.0*pow(r, 5)*xd[0,i]*xim + 8.0*pow(r, 5)*xd[0,i]*xip*x[1,i] + 3.0*pow(r, 4)*pow(x[0,i], 2)*xd[0,i]*xim + 9.0*pow(r, 4)*x[0,i]*xim*x[1,i]*xd[1,i] - 6.0*pow(r, 4)*x[0,i]*xip*xd[1,i] + 4.0*pow(r, 4)*x[0,i]*xd[1,i] + 3.0*pow(r, 4)*xd[0,i]*xim*pow(x[1,i], 2) + pow(r, 4)*xd[0,i]*xim - 6.0*pow(r, 4)*xd[0,i]*xip*x[1,i] + 4.0*pow(r, 4)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) - pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim + 6.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xip*x[1,i] - 4.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*x[1,i]*xd[1,i] + 6.0*pow(r, 2)*x[0,i]*xip*pow(x[1,i], 2)*xd[1,i] - 4.0*pow(r, 2)*x[0,i]*pow(x[1,i], 2)*xd[1,i] - pow(r, 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i])/pow(r, 5)
#         dot_L_dx_x[1,0,i] = 0.75*U0*beta*(3.0*pow(r, 6)*xd[0,i]*xim + 8.0*pow(r, 5)*x[0,i]*xip*xd[1,i] - 4.0*pow(r, 5)*xd[0,i]*xim + 8.0*pow(r, 5)*xd[0,i]*xip*x[1,i] + 3.0*pow(r, 4)*pow(x[0,i], 2)*xd[0,i]*xim + 9.0*pow(r, 4)*x[0,i]*xim*x[1,i]*xd[1,i] - 6.0*pow(r, 4)*x[0,i]*xip*xd[1,i] + 4.0*pow(r, 4)*x[0,i]*xd[1,i] + 3.0*pow(r, 4)*xd[0,i]*xim*pow(x[1,i], 2) + pow(r, 4)*xd[0,i]*xim - 6.0*pow(r, 4)*xd[0,i]*xip*x[1,i] + 4.0*pow(r, 4)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) - pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim + 6.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xip*x[1,i] - 4.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*x[1,i]*xd[1,i] + 6.0*pow(r, 2)*x[0,i]*xip*pow(x[1,i], 2)*xd[1,i] - 4.0*pow(r, 2)*x[0,i]*pow(x[1,i], 2)*xd[1,i] - pow(r, 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i])/pow(r, 5)
#         dot_L_dx_x[1,1,i] = 0.75*U0*beta*(9.0*pow(r, 6)*xim*xd[1,i] + 8.0*pow(r, 5)*x[0,i]*xd[0,i]*xip - 12.0*pow(r, 5)*xim*xd[1,i] + 24.0*pow(r, 5)*xip*x[1,i]*xd[1,i] + 9.0*pow(r, 4)*x[0,i]*xd[0,i]*xim*x[1,i] - 6.0*pow(r, 4)*x[0,i]*xd[0,i]*xip + 4.0*pow(r, 4)*x[0,i]*xd[0,i] + 18.0*pow(r, 4)*xim*pow(x[1,i], 2)*xd[1,i] + 3.0*pow(r, 4)*xim*xd[1,i] - 18.0*pow(r, 4)*xip*x[1,i]*xd[1,i] + 12.0*pow(r, 4)*x[1,i]*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xd[0,i]*xim*pow(x[1,i], 3) - 3.0*pow(r, 2)*x[0,i]*xd[0,i]*xim*x[1,i] + 6.0*pow(r, 2)*x[0,i]*xd[0,i]*xip*pow(x[1,i], 2) - 4.0*pow(r, 2)*x[0,i]*xd[0,i]*pow(x[1,i], 2) - 3.0*pow(r, 2)*pow(x[1,i], 4)*xim*xd[1,i] - 6.0*pow(r, 2)*xim*pow(x[1,i], 2)*xd[1,i] + 6.0*pow(r, 2)*xip*pow(x[1,i], 3)*xd[1,i] - 4.0*pow(r, 2)*pow(x[1,i], 3)*xd[1,i] + 3.0*x[0,i]*xd[0,i]*xim*pow(x[1,i], 3) + 3.0*pow(x[1,i], 4)*xim*xd[1,i])/pow(r, 5)
#
# _compute_dot_L_xd_x_FW(self, DTYPE_t[:] ts, DTYPE_t[:,:] x, DTYPE_t[:,:] xd, DTYPE_t[:,:,:] dot_L_dx_x):
#     cdef:
#         int i
#         int dim = x.shape[0]
#         int Nt = x.shape[1]
#         DTYPE_t beta = self.beta
#         DTYPE_t gamma = self.gamma
#         DTYPE_t U0 = self.U0
#         DTYPE_t xip = self.xip
#         DTYPE_t xim = self.xim
#         DTYPE_t r
#
#     for i in range(Nt):
#         r = sqrt(pow(x[0,i], 2) + pow(x[1,i], 2))
#         dot_L_dx_x[0,0,i] = 0.75*U0*beta*(3.0*pow(r, 6)*xim*xd[1,i] + 24.0*pow(r, 5)*x[0,i]*xd[0,i]*xip - 4.0*pow(r, 5)*xim*xd[1,i] + 8.0*pow(r, 5)*xip*x[1,i]*xd[1,i] + 3.0*pow(r, 4)*pow(x[0,i], 2)*xim*xd[1,i] + 9.0*pow(r, 4)*x[0,i]*xd[0,i]*xim*x[1,i] - 18.0*pow(r, 4)*x[0,i]*xd[0,i]*xip + 12.0*pow(r, 4)*x[0,i]*xd[0,i] + 3.0*pow(r, 4)*xim*pow(x[1,i], 2)*xd[1,i] + pow(r, 4)*xim*xd[1,i] - 6.0*pow(r, 4)*xip*x[1,i]*xd[1,i] + 4.0*pow(r, 4)*x[1,i]*xd[1,i] - 3.0*pow(r, 2)*pow(x[0,i], 3)*xd[0,i]*xim*x[1,i] + 6.0*pow(r, 2)*pow(x[0,i], 3)*xd[0,i]*xip - 4.0*pow(r, 2)*pow(x[0,i], 3)*xd[0,i] - 3.0*pow(r, 2)*pow(x[0,i], 2)*xim*pow(x[1,i], 2)*xd[1,i] - pow(r, 2)*pow(x[0,i], 2)*xim*xd[1,i] + 6.0*pow(r, 2)*pow(x[0,i], 2)*xip*x[1,i]*xd[1,i] - 4.0*pow(r, 2)*pow(x[0,i], 2)*x[1,i]*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xd[0,i]*xim*x[1,i] - pow(r, 2)*xim*pow(x[1,i], 2)*xd[1,i] + 3.0*pow(x[0,i], 3)*xd[0,i]*xim*x[1,i] + 3.0*pow(x[0,i], 2)*xim*pow(x[1,i], 2)*xd[1,i])/pow(r, 5)
#         dot_L_dx_x[0,1,i] = 0.75*U0*beta*(3.0*pow(r, 6)*xd[0,i]*xim + 8.0*pow(r, 5)*x[0,i]*xip*xd[1,i] - 4.0*pow(r, 5)*xd[0,i]*xim + 8.0*pow(r, 5)*xd[0,i]*xip*x[1,i] + 3.0*pow(r, 4)*pow(x[0,i], 2)*xd[0,i]*xim + 9.0*pow(r, 4)*x[0,i]*xim*x[1,i]*xd[1,i] - 6.0*pow(r, 4)*x[0,i]*xip*xd[1,i] + 4.0*pow(r, 4)*x[0,i]*xd[1,i] + 3.0*pow(r, 4)*xd[0,i]*xim*pow(x[1,i], 2) + pow(r, 4)*xd[0,i]*xim - 6.0*pow(r, 4)*xd[0,i]*xip*x[1,i] + 4.0*pow(r, 4)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) - pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim + 6.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xip*x[1,i] - 4.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*x[1,i]*xd[1,i] + 6.0*pow(r, 2)*x[0,i]*xip*pow(x[1,i], 2)*xd[1,i] - 4.0*pow(r, 2)*x[0,i]*pow(x[1,i], 2)*xd[1,i] - pow(r, 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i])/pow(r, 5)
#         dot_L_dx_x[1,0,i] = 0.75*U0*beta*(3.0*pow(r, 6)*xd[0,i]*xim + 8.0*pow(r, 5)*x[0,i]*xip*xd[1,i] - 4.0*pow(r, 5)*xd[0,i]*xim + 8.0*pow(r, 5)*xd[0,i]*xip*x[1,i] + 3.0*pow(r, 4)*pow(x[0,i], 2)*xd[0,i]*xim + 9.0*pow(r, 4)*x[0,i]*xim*x[1,i]*xd[1,i] - 6.0*pow(r, 4)*x[0,i]*xip*xd[1,i] + 4.0*pow(r, 4)*x[0,i]*xd[1,i] + 3.0*pow(r, 4)*xd[0,i]*xim*pow(x[1,i], 2) + pow(r, 4)*xd[0,i]*xim - 6.0*pow(r, 4)*xd[0,i]*xip*x[1,i] + 4.0*pow(r, 4)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) - pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xim + 6.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*xip*x[1,i] - 4.0*pow(r, 2)*pow(x[0,i], 2)*xd[0,i]*x[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xim*x[1,i]*xd[1,i] + 6.0*pow(r, 2)*x[0,i]*xip*pow(x[1,i], 2)*xd[1,i] - 4.0*pow(r, 2)*x[0,i]*pow(x[1,i], 2)*xd[1,i] - pow(r, 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*pow(x[0,i], 2)*xd[0,i]*xim*pow(x[1,i], 2) + 3.0*x[0,i]*xim*pow(x[1,i], 3)*xd[1,i])/pow(r, 5)
#         dot_L_dx_x[1,1,i] = 0.75*U0*beta*(9.0*pow(r, 6)*xim*xd[1,i] + 8.0*pow(r, 5)*x[0,i]*xd[0,i]*xip - 12.0*pow(r, 5)*xim*xd[1,i] + 24.0*pow(r, 5)*xip*x[1,i]*xd[1,i] + 9.0*pow(r, 4)*x[0,i]*xd[0,i]*xim*x[1,i] - 6.0*pow(r, 4)*x[0,i]*xd[0,i]*xip + 4.0*pow(r, 4)*x[0,i]*xd[0,i] + 18.0*pow(r, 4)*xim*pow(x[1,i], 2)*xd[1,i] + 3.0*pow(r, 4)*xim*xd[1,i] - 18.0*pow(r, 4)*xip*x[1,i]*xd[1,i] + 12.0*pow(r, 4)*x[1,i]*xd[1,i] - 3.0*pow(r, 2)*x[0,i]*xd[0,i]*xim*pow(x[1,i], 3) - 3.0*pow(r, 2)*x[0,i]*xd[0,i]*xim*x[1,i] + 6.0*pow(r, 2)*x[0,i]*xd[0,i]*xip*pow(x[1,i], 2) - 4.0*pow(r, 2)*x[0,i]*xd[0,i]*pow(x[1,i], 2) - 3.0*pow(r, 2)*pow(x[1,i], 4)*xim*xd[1,i] - 6.0*pow(r, 2)*xim*pow(x[1,i], 2)*xd[1,i] + 6.0*pow(r, 2)*xip*pow(x[1,i], 3)*xd[1,i] - 4.0*pow(r, 2)*pow(x[1,i], 3)*xd[1,i] + 3.0*x[0,i]*xd[0,i]*xim*pow(x[1,i], 3) + 3.0*pow(x[1,i], 4)*xim*xd[1,i])/pow(r, 5)
